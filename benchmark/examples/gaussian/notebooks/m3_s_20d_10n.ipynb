# %% [markdown]
# M3: mu ~ N(0, I), y|mu ~ N(mu, 3I)
# with MMD summary space regularization
# D=20, N=10, S=D

# %%
import numpy as np
import bayesflow as bf
import keras
from pathlib import Path
# Out:
# INFO:jax._src.xla_bridge:Unable to initialize backend 'rocm': module 'jaxlib.xla_extension' has no attribute 'GpuAllocatorConfig'
# INFO:jax._src.xla_bridge:Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: dlopen(libtpu.so, 0x0001): tried: 'libtpu.so' (no such file), '/System/Volumes/Preboot/Cryptexes/OSlibtpu.so' (no such file), '/opt/anaconda3/envs/benchmark2/bin/../lib/libtpu.so' (no such file), '/usr/lib/libtpu.so' (no such file, not in dyld cache), 'libtpu.so' (no such file), '/usr/local/lib/libtpu.so' (no such file), '/usr/lib/libtpu.so' (no such file, not in dyld cache)
# INFO:bayesflow:Using backend 'jax'

# %%
from tqdm.auto import tqdm as original_tqdm
import bayesflow.approximators.helpers.samplers as bf_samplers
import bayesflow.approximators.helpers.conditions as bf_conditions


def quiet_tqdm(*args, **kwargs):
    kwargs["disable"] = True
    return original_tqdm(*args, **kwargs)


bf_samplers.tqdm = quiet_tqdm
bf_conditions.tqdm = quiet_tqdm

# %%
RNG = np.random.default_rng(2025)
num_dims = 20
num_obs = 10
mu_prior_mean = 0
mu_prior_std = 1
likelihood_std = 3

# %%
# simulator
def prior(mu=mu_prior_mean, sigma=mu_prior_std):
    mu = RNG.normal(loc=mu, scale=sigma, size=num_dims)
    return dict(mu=mu)


def likelihood(mu):
    x = RNG.normal(loc=mu, scale=likelihood_std, size=(num_obs, num_dims))
    return dict(x=x)


simulator = bf.make_simulator([prior, likelihood])

# %%
# adapter
adapter = (
    bf.adapters.Adapter()
    .convert_dtype("float64", "float32")
    .rename("mu", "inference_variables")
    .rename("x", "summary_variables")
)

# %%
# networks
summary_net = bf.networks.DeepSet(summary_dim=num_dims, base_distribution="normal")

inference_net = bf.networks.CouplingFlow()

# %%
workflow = bf.BasicWorkflow(
    simulator=simulator,
    adapter=adapter,
    summary_network=summary_net,
    inference_network=inference_net,
    standardize="all",
)
epochs = 100
batch_size = 64
num_batches_per_epoch = 128
learning_rate = keras.optimizers.schedules.CosineDecay(
    initial_learning_rate=1e-4, decay_steps=epochs * num_batches_per_epoch
)
workflow.approximator.compile(
    optimizer=keras.optimizers.Adam(learning_rate=learning_rate)
)

# %%
history = workflow.fit_online(
    epochs=epochs, batch_size=batch_size, num_batches_per_epoch=num_batches_per_epoch
)
# Out:
# INFO:bayesflow:Fitting on dataset instance of OnlineDataset.
# INFO:bayesflow:Building on a test batch.
# Epoch 1/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - loss: 27.2595 - loss/inference_loss: 26.9113 - loss/summary_loss: 0.3482
# Epoch 2/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 25.5368 - loss/inference_loss: 25.1529 - loss/summary_loss: 0.3839
# Epoch 3/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 24.9639 - loss/inference_loss: 24.6465 - loss/summary_loss: 0.3174
# Epoch 4/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 24.9429 - loss/inference_loss: 24.6541 - loss/summary_loss: 0.2888
# Epoch 5/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 24.7693 - loss/inference_loss: 24.4887 - loss/summary_loss: 0.2806
# Epoch 6/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 24.6578 - loss/inference_loss: 24.3844 - loss/summary_loss: 0.2734
# Epoch 7/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 23.6857 - loss/inference_loss: 23.4284 - loss/summary_loss: 0.2573
# Epoch 8/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 24.5214 - loss/inference_loss: 24.2684 - loss/summary_loss: 0.2530
# Epoch 9/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 23.7211 - loss/inference_loss: 23.4724 - loss/summary_loss: 0.2487
# Epoch 10/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 22.9659 - loss/inference_loss: 22.7027 - loss/summary_loss: 0.2632
# Epoch 11/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 22.7522 - loss/inference_loss: 22.4945 - loss/summary_loss: 0.2577
# Epoch 12/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 23.2142 - loss/inference_loss: 22.9631 - loss/summary_loss: 0.2511
# Epoch 13/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 23.1158 - loss/inference_loss: 22.8664 - loss/summary_loss: 0.2494
# Epoch 14/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 23.0991 - loss/inference_loss: 22.8637 - loss/summary_loss: 0.2354
# Epoch 15/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 23.1578 - loss/inference_loss: 22.9350 - loss/summary_loss: 0.2228
# Epoch 16/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 22.6300 - loss/inference_loss: 22.3980 - loss/summary_loss: 0.2321
# Epoch 17/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 23.3855 - loss/inference_loss: 23.1431 - loss/summary_loss: 0.2424
# Epoch 18/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 23.4557 - loss/inference_loss: 23.2247 - loss/summary_loss: 0.2309
# Epoch 19/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 23.1746 - loss/inference_loss: 22.9382 - loss/summary_loss: 0.2364
# Epoch 20/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 22.9668 - loss/inference_loss: 22.7444 - loss/summary_loss: 0.2223
# Epoch 21/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 22.8168 - loss/inference_loss: 22.5918 - loss/summary_loss: 0.2250
# Epoch 22/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 22.5353 - loss/inference_loss: 22.3103 - loss/summary_loss: 0.2250
# Epoch 23/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 22.4545 - loss/inference_loss: 22.2219 - loss/summary_loss: 0.2326
# Epoch 24/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 22.0783 - loss/inference_loss: 21.8454 - loss/summary_loss: 0.2329
# Epoch 25/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 22.5842 - loss/inference_loss: 22.3555 - loss/summary_loss: 0.2287
# Epoch 26/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 22.4892 - loss/inference_loss: 22.2479 - loss/summary_loss: 0.2413
# Epoch 27/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 21.3576 - loss/inference_loss: 21.1237 - loss/summary_loss: 0.2339
# Epoch 28/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 22.3205 - loss/inference_loss: 22.0924 - loss/summary_loss: 0.2281
# Epoch 29/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 22.9311 - loss/inference_loss: 22.7083 - loss/summary_loss: 0.2228
# Epoch 30/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 22.6834 - loss/inference_loss: 22.4668 - loss/summary_loss: 0.2165
# Epoch 31/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 22.7000 - loss/inference_loss: 22.4710 - loss/summary_loss: 0.2289
# Epoch 32/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 22.4822 - loss/inference_loss: 22.2548 - loss/summary_loss: 0.2274
# Epoch 33/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 22.6948 - loss/inference_loss: 22.4742 - loss/summary_loss: 0.2206
# Epoch 34/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 23.0434 - loss/inference_loss: 22.8241 - loss/summary_loss: 0.2194
# Epoch 35/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 21.9766 - loss/inference_loss: 21.7414 - loss/summary_loss: 0.2352
# Epoch 36/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 22.4310 - loss/inference_loss: 22.2068 - loss/summary_loss: 0.2242
# Epoch 37/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 23.0304 - loss/inference_loss: 22.8177 - loss/summary_loss: 0.2127
# Epoch 38/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 22.5437 - loss/inference_loss: 22.3222 - loss/summary_loss: 0.2214
# Epoch 39/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 22.8564 - loss/inference_loss: 22.6324 - loss/summary_loss: 0.2240
# Epoch 40/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 22.4797 - loss/inference_loss: 22.2576 - loss/summary_loss: 0.2221
# Epoch 41/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 23.1570 - loss/inference_loss: 22.9347 - loss/summary_loss: 0.2223
# Epoch 42/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 21.6319 - loss/inference_loss: 21.4161 - loss/summary_loss: 0.2158
# Epoch 43/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 22.7876 - loss/inference_loss: 22.5600 - loss/summary_loss: 0.2275
# Epoch 44/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 21.4807 - loss/inference_loss: 21.2532 - loss/summary_loss: 0.2275
# Epoch 45/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 22.3742 - loss/inference_loss: 22.1390 - loss/summary_loss: 0.2352
# Epoch 46/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 22.4201 - loss/inference_loss: 22.1982 - loss/summary_loss: 0.2219
# Epoch 47/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 21.8882 - loss/inference_loss: 21.6620 - loss/summary_loss: 0.2262
# Epoch 48/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 21.5908 - loss/inference_loss: 21.3693 - loss/summary_loss: 0.2215
# Epoch 49/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 22.0883 - loss/inference_loss: 21.8780 - loss/summary_loss: 0.2103
# Epoch 50/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 21.7037 - loss/inference_loss: 21.4860 - loss/summary_loss: 0.2177
# Epoch 51/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 22.3300 - loss/inference_loss: 22.1072 - loss/summary_loss: 0.2229
# Epoch 52/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 21.4993 - loss/inference_loss: 21.2807 - loss/summary_loss: 0.2185
# Epoch 53/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 21.5387 - loss/inference_loss: 21.3266 - loss/summary_loss: 0.2121
# Epoch 54/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 21.9083 - loss/inference_loss: 21.6871 - loss/summary_loss: 0.2212
# Epoch 55/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 22.0037 - loss/inference_loss: 21.7837 - loss/summary_loss: 0.2200
# Epoch 56/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 21.9313 - loss/inference_loss: 21.7002 - loss/summary_loss: 0.2312
# Epoch 57/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 21.3354 - loss/inference_loss: 21.1148 - loss/summary_loss: 0.2206
# Epoch 58/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 21.3146 - loss/inference_loss: 21.0931 - loss/summary_loss: 0.2215
# Epoch 59/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 21.9784 - loss/inference_loss: 21.7669 - loss/summary_loss: 0.2116
# Epoch 60/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 21.1966 - loss/inference_loss: 20.9826 - loss/summary_loss: 0.2140
# Epoch 61/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 22.1088 - loss/inference_loss: 21.8955 - loss/summary_loss: 0.2133
# Epoch 62/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 21.9126 - loss/inference_loss: 21.6942 - loss/summary_loss: 0.2184
# Epoch 63/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 22.4261 - loss/inference_loss: 22.2090 - loss/summary_loss: 0.2171
# Epoch 64/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 22.2747 - loss/inference_loss: 22.0511 - loss/summary_loss: 0.2236
# Epoch 65/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 22.2640 - loss/inference_loss: 22.0387 - loss/summary_loss: 0.2253
# Epoch 66/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 21.9609 - loss/inference_loss: 21.7354 - loss/summary_loss: 0.2255
# Epoch 67/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 22.2027 - loss/inference_loss: 21.9840 - loss/summary_loss: 0.2186
# Epoch 68/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 21.8442 - loss/inference_loss: 21.6331 - loss/summary_loss: 0.2112
# Epoch 69/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 22.5477 - loss/inference_loss: 22.3348 - loss/summary_loss: 0.2129
# Epoch 70/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 21.6284 - loss/inference_loss: 21.4071 - loss/summary_loss: 0.2213
# Epoch 71/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 21.7919 - loss/inference_loss: 21.5790 - loss/summary_loss: 0.2130
# Epoch 72/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 22.6768 - loss/inference_loss: 22.4623 - loss/summary_loss: 0.2145
# Epoch 73/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 21.8046 - loss/inference_loss: 21.5917 - loss/summary_loss: 0.2128
# Epoch 74/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 22.1024 - loss/inference_loss: 21.8893 - loss/summary_loss: 0.2132
# Epoch 75/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 22.2243 - loss/inference_loss: 22.0107 - loss/summary_loss: 0.2137
# Epoch 76/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 21.5998 - loss/inference_loss: 21.3808 - loss/summary_loss: 0.2190
# Epoch 77/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 22.0201 - loss/inference_loss: 21.8037 - loss/summary_loss: 0.2164
# Epoch 78/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 21.3055 - loss/inference_loss: 21.0889 - loss/summary_loss: 0.2166
# Epoch 79/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 21.5708 - loss/inference_loss: 21.3467 - loss/summary_loss: 0.2240
# Epoch 80/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 21.1173 - loss/inference_loss: 20.9026 - loss/summary_loss: 0.2147
# Epoch 81/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 21.5266 - loss/inference_loss: 21.3147 - loss/summary_loss: 0.2119
# Epoch 82/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 22.4180 - loss/inference_loss: 22.2028 - loss/summary_loss: 0.2152
# Epoch 83/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 22.3048 - loss/inference_loss: 22.0908 - loss/summary_loss: 0.2140
# Epoch 84/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - loss: 21.6869 - loss/inference_loss: 21.4729 - loss/summary_loss: 0.2140
# Epoch 85/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - loss: 22.7803 - loss/inference_loss: 22.5636 - loss/summary_loss: 0.2167
# Epoch 86/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 21.7279 - loss/inference_loss: 21.5162 - loss/summary_loss: 0.2117
# Epoch 87/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 21.7149 - loss/inference_loss: 21.5059 - loss/summary_loss: 0.2089
# Epoch 88/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - loss: 21.9727 - loss/inference_loss: 21.7612 - loss/summary_loss: 0.2115
# Epoch 89/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 21.4680 - loss/inference_loss: 21.2556 - loss/summary_loss: 0.2124
# Epoch 90/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - loss: 21.6422 - loss/inference_loss: 21.4241 - loss/summary_loss: 0.2182
# Epoch 91/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - loss: 21.1861 - loss/inference_loss: 20.9713 - loss/summary_loss: 0.2148
# Epoch 92/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 21.3076 - loss/inference_loss: 21.0939 - loss/summary_loss: 0.2138
# Epoch 93/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - loss: 21.4991 - loss/inference_loss: 21.2909 - loss/summary_loss: 0.2082
# Epoch 94/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - loss: 21.6343 - loss/inference_loss: 21.4184 - loss/summary_loss: 0.2159
# Epoch 95/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 22.5887 - loss/inference_loss: 22.3799 - loss/summary_loss: 0.2088
# Epoch 96/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - loss: 21.4612 - loss/inference_loss: 21.2449 - loss/summary_loss: 0.2164
# Epoch 97/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - loss: 22.3703 - loss/inference_loss: 22.1583 - loss/summary_loss: 0.2119
# Epoch 98/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - loss: 21.9159 - loss/inference_loss: 21.6991 - loss/summary_loss: 0.2168
# Epoch 99/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - loss: 22.4830 - loss/inference_loss: 22.2545 - loss/summary_loss: 0.2285
# Epoch 100/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 22.2143 - loss/inference_loss: 21.9984 - loss/summary_loss: 0.2160
# INFO:bayesflow:Training completed in 5.33 minutes.

# %%
f = bf.diagnostics.plots.loss(history)

# %%
# Generate test datasets and get posterior samples and perform diagnostics
num_samples = 1000  # number of posterior samples
val_sims = simulator.sample(200)  # validation data
post_draws = workflow.sample(conditions=val_sims, num_samples=num_samples)
post_draws.keys()
# Out:
# INFO:bayesflow:Sampling completed in 4.20 seconds.
# dict_keys(['mu'])

# %%
# f1 = bf.diagnostics.plots.calibration_histogram(post_draws, val_sims)
f2 = bf.diagnostics.plots.calibration_ecdf(post_draws, val_sims, difference=True)
f3 = bf.diagnostics.plots.recovery(post_draws, val_sims)

# %%
# Save the trained approximator
filepath = (
    Path(
        "/Users/yimingzang/Documents/Project/benchmark2/benchmark/examples/gaussian/networks"
    )
    / "m3_s_20d_10n.keras"
)
filepath.parent.mkdir(exist_ok=True)
workflow.approximator.save(filepath=filepath)

# %%
# load approximator
filepath = (
    Path(
        "/Users/yimingzang/Documents/Project/benchmark2/benchmark/examples/gaussian/networks"
    )
    / "m3_s_20d_10n.keras"
)
approximator = keras.saving.load_model(filepath)

# %%
post_draws = approximator.sample(conditions=val_sims, num_samples=num_samples)
f3 = bf.diagnostics.plots.recovery(post_draws, val_sims)

# %%
# Gold-standard recovery using samples from the analytical conjugate posterior
prior_precision = 1.0 / mu_prior_std**2
data_precision = num_obs / likelihood_std**2
gold_posterior_var = 1.0 / (prior_precision + data_precision)
gold_posterior_mean = gold_posterior_var * (
    prior_precision * mu_prior_mean + val_sims["x"].sum(axis=1) / likelihood_std**2
)

gold_rng = np.random.default_rng(2026)
gold_posterior_samples = gold_rng.normal(
    loc=gold_posterior_mean[:, None, :],
    scale=np.sqrt(gold_posterior_var),
    size=(gold_posterior_mean.shape[0], num_samples, num_dims),
)

f_gold_recovery = bf.diagnostics.plots.recovery(
    gold_posterior_samples,
    val_sims["mu"],
    variable_names=[f"mu_{i + 1}" for i in range(num_dims)],
    color="#8f2727",
)
