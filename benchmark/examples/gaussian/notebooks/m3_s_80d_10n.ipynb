# %% [markdown]
# M3: mu ~ N(0, I), y|mu ~ N(mu, 3I)
# with MMD summary space regularization
# D=20, N=10, S=4D

# %%
import numpy as np
import bayesflow as bf
import keras
from pathlib import Path
# Out:
# INFO:jax._src.xla_bridge:Unable to initialize backend 'rocm': module 'jaxlib.xla_extension' has no attribute 'GpuAllocatorConfig'
# INFO:jax._src.xla_bridge:Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: dlopen(libtpu.so, 0x0001): tried: 'libtpu.so' (no such file), '/System/Volumes/Preboot/Cryptexes/OSlibtpu.so' (no such file), '/opt/anaconda3/envs/benchmark2/bin/../lib/libtpu.so' (no such file), '/usr/lib/libtpu.so' (no such file, not in dyld cache), 'libtpu.so' (no such file), '/usr/local/lib/libtpu.so' (no such file), '/usr/lib/libtpu.so' (no such file, not in dyld cache)
# INFO:bayesflow:Using backend 'jax'

# %%
from tqdm.auto import tqdm as original_tqdm
import bayesflow.approximators.helpers.samplers as bf_samplers
import bayesflow.approximators.helpers.conditions as bf_conditions


def quiet_tqdm(*args, **kwargs):
    kwargs["disable"] = True
    return original_tqdm(*args, **kwargs)


bf_samplers.tqdm = quiet_tqdm
bf_conditions.tqdm = quiet_tqdm

# %%
RNG = np.random.default_rng(2025)
num_dims = 20
num_obs = 10
mu_prior_mean = 0
mu_prior_std = 1
likelihood_std = 3

# %%
# simulator
def prior(mu=mu_prior_mean, sigma=mu_prior_std):
    mu = RNG.normal(loc=mu, scale=sigma, size=num_dims)
    return dict(mu=mu)


def likelihood(mu):
    x = RNG.normal(loc=mu, scale=likelihood_std, size=(num_obs, num_dims))
    return dict(x=x)


simulator = bf.make_simulator([prior, likelihood])

# %%
# adapter
adapter = (
    bf.adapters.Adapter()
    .convert_dtype("float64", "float32")
    .rename("mu", "inference_variables")
    .rename("x", "summary_variables")
)

# %%
# networks
summary_net = bf.networks.DeepSet(summary_dim=4 * num_dims, base_distribution="normal")

inference_net = bf.networks.CouplingFlow()

# %%
workflow = bf.BasicWorkflow(
    simulator=simulator,
    adapter=adapter,
    summary_network=summary_net,
    inference_network=inference_net,
    standardize="all",
)
epochs = 100
batch_size = 64
num_batches_per_epoch = 128
learning_rate = keras.optimizers.schedules.CosineDecay(
    initial_learning_rate=1e-4, decay_steps=epochs * num_batches_per_epoch
)
workflow.approximator.compile(
    optimizer=keras.optimizers.Adam(learning_rate=learning_rate)
)

# %%
history = workflow.fit_online(
    epochs=epochs, batch_size=batch_size, num_batches_per_epoch=num_batches_per_epoch
)
# Out:
# INFO:bayesflow:Fitting on dataset instance of OnlineDataset.
# INFO:bayesflow:Building on a test batch.
# Epoch 1/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 23s 47ms/step - loss: 26.8287 - loss/inference_loss: 26.4314 - loss/summary_loss: 0.3973
# Epoch 2/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 50ms/step - loss: 24.9838 - loss/inference_loss: 24.6491 - loss/summary_loss: 0.3347
# Epoch 3/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - loss: 24.4621 - loss/inference_loss: 24.1703 - loss/summary_loss: 0.2918
# Epoch 4/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 46ms/step - loss: 24.3805 - loss/inference_loss: 24.1096 - loss/summary_loss: 0.2709
# Epoch 5/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - loss: 24.2215 - loss/inference_loss: 23.9638 - loss/summary_loss: 0.2577
# Epoch 6/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 46ms/step - loss: 24.6309 - loss/inference_loss: 24.3856 - loss/summary_loss: 0.2453
# Epoch 7/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 54ms/step - loss: 23.3854 - loss/inference_loss: 23.1386 - loss/summary_loss: 0.2468
# Epoch 8/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 50ms/step - loss: 23.3765 - loss/inference_loss: 23.1289 - loss/summary_loss: 0.2476
# Epoch 9/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 45ms/step - loss: 23.3468 - loss/inference_loss: 23.0902 - loss/summary_loss: 0.2566
# Epoch 10/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - loss: 22.5791 - loss/inference_loss: 22.3313 - loss/summary_loss: 0.2478
# Epoch 11/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - loss: 21.5320 - loss/inference_loss: 21.2864 - loss/summary_loss: 0.2456
# Epoch 12/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 50ms/step - loss: 21.9582 - loss/inference_loss: 21.7114 - loss/summary_loss: 0.2468
# Epoch 13/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - loss: 22.2143 - loss/inference_loss: 21.9730 - loss/summary_loss: 0.2413
# Epoch 14/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 46ms/step - loss: 22.6831 - loss/inference_loss: 22.4413 - loss/summary_loss: 0.2417
# Epoch 15/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - loss: 22.3760 - loss/inference_loss: 22.1308 - loss/summary_loss: 0.2452
# Epoch 16/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - loss: 21.4124 - loss/inference_loss: 21.1683 - loss/summary_loss: 0.2441
# Epoch 17/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - loss: 22.3061 - loss/inference_loss: 22.0604 - loss/summary_loss: 0.2456
# Epoch 18/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - loss: 22.0017 - loss/inference_loss: 21.7572 - loss/summary_loss: 0.2445
# Epoch 19/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - loss: 22.3511 - loss/inference_loss: 22.1026 - loss/summary_loss: 0.2484
# Epoch 20/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 50ms/step - loss: 22.4441 - loss/inference_loss: 22.2018 - loss/summary_loss: 0.2423
# Epoch 21/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 51ms/step - loss: 22.1987 - loss/inference_loss: 21.9501 - loss/summary_loss: 0.2486
# Epoch 22/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - loss: 21.8368 - loss/inference_loss: 21.5919 - loss/summary_loss: 0.2450
# Epoch 23/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 50ms/step - loss: 21.8735 - loss/inference_loss: 21.6330 - loss/summary_loss: 0.2405
# Epoch 24/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - loss: 21.5390 - loss/inference_loss: 21.2924 - loss/summary_loss: 0.2466
# Epoch 25/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - loss: 21.9250 - loss/inference_loss: 21.6797 - loss/summary_loss: 0.2453
# Epoch 26/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - loss: 21.8365 - loss/inference_loss: 21.5981 - loss/summary_loss: 0.2384
# Epoch 27/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - loss: 20.9372 - loss/inference_loss: 20.6933 - loss/summary_loss: 0.2439
# Epoch 28/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 49ms/step - loss: 21.7614 - loss/inference_loss: 21.5206 - loss/summary_loss: 0.2407
# Epoch 29/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - loss: 22.2871 - loss/inference_loss: 22.0507 - loss/summary_loss: 0.2364
# Epoch 30/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - loss: 21.8902 - loss/inference_loss: 21.6534 - loss/summary_loss: 0.2369
# Epoch 31/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - loss: 22.1001 - loss/inference_loss: 21.8658 - loss/summary_loss: 0.2343
# Epoch 32/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - loss: 22.0811 - loss/inference_loss: 21.8427 - loss/summary_loss: 0.2384
# Epoch 33/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - loss: 22.0383 - loss/inference_loss: 21.8012 - loss/summary_loss: 0.2371
# Epoch 34/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - loss: 22.4764 - loss/inference_loss: 22.2384 - loss/summary_loss: 0.2380
# Epoch 35/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 46ms/step - loss: 21.2058 - loss/inference_loss: 20.9682 - loss/summary_loss: 0.2376
# Epoch 36/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - loss: 21.8046 - loss/inference_loss: 21.5681 - loss/summary_loss: 0.2365
# Epoch 37/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - loss: 22.3763 - loss/inference_loss: 22.1404 - loss/summary_loss: 0.2359
# Epoch 38/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - loss: 22.1158 - loss/inference_loss: 21.8758 - loss/summary_loss: 0.2401
# Epoch 39/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - loss: 22.3272 - loss/inference_loss: 22.0893 - loss/summary_loss: 0.2379
# Epoch 40/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - loss: 21.8752 - loss/inference_loss: 21.6377 - loss/summary_loss: 0.2376
# Epoch 41/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 49ms/step - loss: 22.5166 - loss/inference_loss: 22.2788 - loss/summary_loss: 0.2377
# Epoch 42/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 46ms/step - loss: 21.1950 - loss/inference_loss: 20.9508 - loss/summary_loss: 0.2443
# Epoch 43/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 45ms/step - loss: 22.2419 - loss/inference_loss: 22.0063 - loss/summary_loss: 0.2357
# Epoch 44/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - loss: 21.3356 - loss/inference_loss: 21.0949 - loss/summary_loss: 0.2408
# Epoch 45/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 45ms/step - loss: 21.9683 - loss/inference_loss: 21.7290 - loss/summary_loss: 0.2393
# Epoch 46/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 45ms/step - loss: 22.0617 - loss/inference_loss: 21.8197 - loss/summary_loss: 0.2420
# Epoch 47/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 44ms/step - loss: 21.4220 - loss/inference_loss: 21.1849 - loss/summary_loss: 0.2370
# Epoch 48/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - loss: 21.2989 - loss/inference_loss: 21.0618 - loss/summary_loss: 0.2371
# Epoch 49/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 45ms/step - loss: 21.8293 - loss/inference_loss: 21.5952 - loss/summary_loss: 0.2340
# Epoch 50/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 44ms/step - loss: 21.5271 - loss/inference_loss: 21.2885 - loss/summary_loss: 0.2385
# Epoch 51/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 44ms/step - loss: 21.9496 - loss/inference_loss: 21.7094 - loss/summary_loss: 0.2402
# Epoch 52/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 44ms/step - loss: 21.1710 - loss/inference_loss: 20.9341 - loss/summary_loss: 0.2370
# Epoch 53/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 46ms/step - loss: 20.9785 - loss/inference_loss: 20.7422 - loss/summary_loss: 0.2363
# Epoch 54/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 50ms/step - loss: 21.7302 - loss/inference_loss: 21.4920 - loss/summary_loss: 0.2382
# Epoch 55/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 45ms/step - loss: 21.4575 - loss/inference_loss: 21.2176 - loss/summary_loss: 0.2399
# Epoch 56/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 46ms/step - loss: 21.7005 - loss/inference_loss: 21.4575 - loss/summary_loss: 0.2429
# Epoch 57/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 44ms/step - loss: 20.9944 - loss/inference_loss: 20.7499 - loss/summary_loss: 0.2445
# Epoch 58/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 46ms/step - loss: 21.1413 - loss/inference_loss: 20.9067 - loss/summary_loss: 0.2346
# Epoch 59/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 44ms/step - loss: 21.6277 - loss/inference_loss: 21.3860 - loss/summary_loss: 0.2417
# Epoch 60/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 44ms/step - loss: 21.2435 - loss/inference_loss: 21.0061 - loss/summary_loss: 0.2374
# Epoch 61/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 45ms/step - loss: 21.9455 - loss/inference_loss: 21.7059 - loss/summary_loss: 0.2396
# Epoch 62/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 44ms/step - loss: 21.6305 - loss/inference_loss: 21.3906 - loss/summary_loss: 0.2399
# Epoch 63/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 21.9103 - loss/inference_loss: 21.6740 - loss/summary_loss: 0.2363
# Epoch 64/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - loss: 22.1675 - loss/inference_loss: 21.9327 - loss/summary_loss: 0.2348
# Epoch 65/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - loss: 22.0276 - loss/inference_loss: 21.7872 - loss/summary_loss: 0.2405
# Epoch 66/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 46ms/step - loss: 21.6273 - loss/inference_loss: 21.3880 - loss/summary_loss: 0.2393
# Epoch 67/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 43ms/step - loss: 22.0544 - loss/inference_loss: 21.8219 - loss/summary_loss: 0.2324
# Epoch 68/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 44ms/step - loss: 21.7321 - loss/inference_loss: 21.4990 - loss/summary_loss: 0.2331
# Epoch 69/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 45ms/step - loss: 22.2668 - loss/inference_loss: 22.0327 - loss/summary_loss: 0.2341
# Epoch 70/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 43ms/step - loss: 21.6224 - loss/inference_loss: 21.3870 - loss/summary_loss: 0.2354
# Epoch 71/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 43ms/step - loss: 21.3634 - loss/inference_loss: 21.1279 - loss/summary_loss: 0.2355
# Epoch 72/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - loss: 22.2610 - loss/inference_loss: 22.0216 - loss/summary_loss: 0.2394
# Epoch 73/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - loss: 21.5000 - loss/inference_loss: 21.2667 - loss/summary_loss: 0.2333
# Epoch 74/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 21.6962 - loss/inference_loss: 21.4560 - loss/summary_loss: 0.2402
# Epoch 75/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 21.5984 - loss/inference_loss: 21.3612 - loss/summary_loss: 0.2372
# Epoch 76/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 44ms/step - loss: 21.5331 - loss/inference_loss: 21.2951 - loss/summary_loss: 0.2379
# Epoch 77/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - loss: 21.5694 - loss/inference_loss: 21.3371 - loss/summary_loss: 0.2323
# Epoch 78/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - loss: 20.9781 - loss/inference_loss: 20.7428 - loss/summary_loss: 0.2352
# Epoch 79/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - loss: 21.1419 - loss/inference_loss: 20.9038 - loss/summary_loss: 0.2381
# Epoch 80/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 44ms/step - loss: 20.9831 - loss/inference_loss: 20.7432 - loss/summary_loss: 0.2399
# Epoch 81/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - loss: 21.1341 - loss/inference_loss: 20.8976 - loss/summary_loss: 0.2364
# Epoch 82/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 22.1422 - loss/inference_loss: 21.9031 - loss/summary_loss: 0.2391
# Epoch 83/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - loss: 22.0126 - loss/inference_loss: 21.7772 - loss/summary_loss: 0.2353
# Epoch 84/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 43ms/step - loss: 21.4049 - loss/inference_loss: 21.1654 - loss/summary_loss: 0.2395
# Epoch 85/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 43ms/step - loss: 22.3186 - loss/inference_loss: 22.0847 - loss/summary_loss: 0.2339
# Epoch 86/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 21.4382 - loss/inference_loss: 21.1978 - loss/summary_loss: 0.2404
# Epoch 87/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - loss: 21.4778 - loss/inference_loss: 21.2441 - loss/summary_loss: 0.2336
# Epoch 88/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 21.7136 - loss/inference_loss: 21.4760 - loss/summary_loss: 0.2375
# Epoch 89/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 20.9984 - loss/inference_loss: 20.7644 - loss/summary_loss: 0.2340
# Epoch 90/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 44ms/step - loss: 21.0309 - loss/inference_loss: 20.7963 - loss/summary_loss: 0.2346
# Epoch 91/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 21.0540 - loss/inference_loss: 20.8191 - loss/summary_loss: 0.2349
# Epoch 92/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - loss: 20.8007 - loss/inference_loss: 20.5643 - loss/summary_loss: 0.2363
# Epoch 93/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 43ms/step - loss: 21.2581 - loss/inference_loss: 21.0201 - loss/summary_loss: 0.2380
# Epoch 94/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 43ms/step - loss: 21.0863 - loss/inference_loss: 20.8510 - loss/summary_loss: 0.2353
# Epoch 95/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - loss: 22.1945 - loss/inference_loss: 21.9605 - loss/summary_loss: 0.2340
# Epoch 96/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 43ms/step - loss: 20.9803 - loss/inference_loss: 20.7472 - loss/summary_loss: 0.2332
# Epoch 97/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - loss: 21.8922 - loss/inference_loss: 21.6583 - loss/summary_loss: 0.2339
# Epoch 98/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - loss: 21.6679 - loss/inference_loss: 21.4353 - loss/summary_loss: 0.2327
# Epoch 99/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - loss: 22.1390 - loss/inference_loss: 21.9027 - loss/summary_loss: 0.2363
# Epoch 100/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 43ms/step - loss: 21.8644 - loss/inference_loss: 21.6247 - loss/summary_loss: 0.2397
# INFO:bayesflow:Training completed in 10.08 minutes.

# %%
f = bf.diagnostics.plots.loss(history)

# %%
# Generate test datasets and get posterior samples and perform diagnostics
num_samples = 1000  # number of posterior samples
val_sims = simulator.sample(200)  # validation data
post_draws = workflow.sample(conditions=val_sims, num_samples=num_samples)
post_draws.keys()
# Out:
# INFO:bayesflow:Sampling completed in 5.62 seconds.
# dict_keys(['mu'])

# %%
# f1 = bf.diagnostics.plots.calibration_histogram(post_draws, val_sims)
f2 = bf.diagnostics.plots.calibration_ecdf(post_draws, val_sims, difference=True)
f3 = bf.diagnostics.plots.recovery(post_draws, val_sims)

# %%
# Save the trained approximator
filepath = (
    Path(
        "/Users/yimingzang/Documents/Project/benchmark2/benchmark/examples/gaussian/networks"
    )
    / "m3_s_80d_10n.keras"
)
filepath.parent.mkdir(exist_ok=True)
workflow.approximator.save(filepath=filepath)

# %%
# load approximator
filepath = (
    Path(
        "/Users/yimingzang/Documents/Project/benchmark2/benchmark/examples/gaussian/networks"
    )
    / "m3_s_80d_10n.keras"
)
approximator = keras.saving.load_model(filepath)

# %%
post_draws = approximator.sample(conditions=val_sims, num_samples=num_samples)
f3 = bf.diagnostics.plots.recovery(post_draws, val_sims)

# %%
# Gold-standard recovery using samples from the analytical conjugate posterior
prior_precision = 1.0 / mu_prior_std**2
data_precision = num_obs / likelihood_std**2
gold_posterior_var = 1.0 / (prior_precision + data_precision)
gold_posterior_mean = gold_posterior_var * (
    prior_precision * mu_prior_mean + val_sims["x"].sum(axis=1) / likelihood_std**2
)

gold_rng = np.random.default_rng(2026)
gold_posterior_samples = gold_rng.normal(
    loc=gold_posterior_mean[:, None, :],
    scale=np.sqrt(gold_posterior_var),
    size=(gold_posterior_mean.shape[0], num_samples, num_dims),
)

f_gold_recovery = bf.diagnostics.plots.recovery(
    gold_posterior_samples,
    val_sims["mu"],
    variable_names=[f"mu_{i + 1}" for i in range(num_dims)],
    color="#8f2727",
)
