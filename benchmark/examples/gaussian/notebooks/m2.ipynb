# %%
import numpy as np
import bayesflow as bf
import keras
from pathlib import Path

# %%
# simulator
RNG=np.random.default_rng(2025)
num_dims=5
num_obs=50
mu_prior_mean=5
mu_prior_std=1
likelihood_std=1

# %%
# simulator
def prior():
    mu = RNG.normal(loc=mu_prior_mean, scale=mu_prior_std, size=num_dims)
    return dict(mu=mu)
def likelihood(mu):
    x =RNG.normal(loc=mu, scale=likelihood_std, size=(num_obs, num_dims))
    return dict(x=x)
simulator=bf.make_simulator([prior,likelihood])

# %%
# adapter 
adapter = (bf.adapters.Adapter()
                        .convert_dtype("float64", "float32")
                        .rename('mu', 'inference_variables')
                        .rename('x', 'summary_variables')
                )

# %%
# networks
summary_net = bf.networks.DeepSet(summary_dim=30,activation='relu')
inference_net = bf.networks.CouplingFlow(depth=5,transform="spline",widths=(128,128),activation="relu",dropout=0.05)

# %%
workflow = bf.BasicWorkflow(simulator=simulator,
                                          adapter=adapter,
                                          summary_network=summary_net,
                                          inference_network=inference_net,
                                          standardize=None
                                          )
workflow.approximator.compile(optimizer=keras.optimizers.Adam(learning_rate=5e-4))

# %%
history = workflow.fit_online(epochs=100,batch_size=64,num_batches_per_epoch=200)
# Out:
# INFO:bayesflow:Fitting on dataset instance of OnlineDataset.
# INFO:bayesflow:Building on a test batch.
# Epoch 1/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 16s 41ms/step - loss: 9.0155
# Epoch 2/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - loss: 5.5080
# Epoch 3/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - loss: 4.3312
# Epoch 4/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - loss: 3.4396
# Epoch 5/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 38ms/step - loss: 2.9390
# Epoch 6/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 2.5665
# Epoch 7/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 38ms/step - loss: 2.0758
# Epoch 8/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 38ms/step - loss: 1.8002
# Epoch 9/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 38ms/step - loss: 1.5251
# Epoch 10/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 38ms/step - loss: 1.4420
# Epoch 11/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 37ms/step - loss: 1.3130
# Epoch 12/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 38ms/step - loss: 1.1341
# Epoch 13/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 38ms/step - loss: 1.0332
# Epoch 14/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - loss: 0.8814
# Epoch 15/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 38ms/step - loss: 0.9452
# Epoch 16/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 38ms/step - loss: 0.9162
# Epoch 17/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 38ms/step - loss: 0.8416
# Epoch 18/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.7484
# Epoch 19/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - loss: 0.6741
# Epoch 20/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 58ms/step - loss: 0.6165
# Epoch 21/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 57ms/step - loss: 0.5605
# Epoch 22/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 15s 76ms/step - loss: 0.5290
# Epoch 23/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 15s 74ms/step - loss: 0.4253
# Epoch 24/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 19s 96ms/step - loss: 0.5934
# Epoch 25/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 15s 75ms/step - loss: 0.4373
# Epoch 26/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 15s 77ms/step - loss: 0.5499
# Epoch 27/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 15s 76ms/step - loss: 0.5332
# Epoch 28/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 15s 77ms/step - loss: 0.3721
# Epoch 29/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 15s 76ms/step - loss: 0.3759
# Epoch 30/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 15s 76ms/step - loss: 0.4556
# Epoch 31/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 15s 76ms/step - loss: 0.3986
# Epoch 32/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 15s 76ms/step - loss: 0.3916
# Epoch 33/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 15s 76ms/step - loss: 0.3380
# Epoch 34/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 17s 83ms/step - loss: 0.3001
# Epoch 35/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 16s 81ms/step - loss: 0.2257
# Epoch 36/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 16s 78ms/step - loss: 0.1966
# Epoch 37/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 16s 80ms/step - loss: 0.3004
# Epoch 38/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 16s 80ms/step - loss: 0.2720
# Epoch 39/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 16s 79ms/step - loss: 0.1966
# Epoch 40/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 16s 81ms/step - loss: 0.1634
# Epoch 41/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 16s 80ms/step - loss: 0.1662
# Epoch 42/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 17s 86ms/step - loss: 0.1228
# Epoch 43/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - loss: 0.0989
# Epoch 44/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 18s 91ms/step - loss: -0.0613
# Epoch 45/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - loss: 0.0132
# Epoch 46/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 17s 85ms/step - loss: -0.0071
# Epoch 47/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 18s 89ms/step - loss: -0.0983
# Epoch 48/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 17s 87ms/step - loss: -0.0597
# Epoch 49/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 17s 87ms/step - loss: -0.1458
# Epoch 50/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 19s 93ms/step - loss: -0.1617
# Epoch 51/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 18s 90ms/step - loss: -0.2240
# Epoch 52/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 17s 86ms/step - loss: -0.2170
# Epoch 53/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 18s 90ms/step - loss: -0.2161
# Epoch 54/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 18s 92ms/step - loss: -0.2245
# Epoch 55/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 21s 106ms/step - loss: -0.2450
# Epoch 56/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 19s 95ms/step - loss: -0.2463
# Epoch 57/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 19s 94ms/step - loss: -0.2580
# Epoch 58/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 18s 89ms/step - loss: -0.2853
# Epoch 59/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 18s 90ms/step - loss: -0.3139
# Epoch 60/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 18s 89ms/step - loss: -0.3292
# Epoch 61/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 19s 94ms/step - loss: -0.3537
# Epoch 62/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 19s 96ms/step - loss: -0.3536
# Epoch 63/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 20s 97ms/step - loss: -0.3332
# Epoch 64/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 19s 95ms/step - loss: -0.3929
# Epoch 65/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 18s 91ms/step - loss: -0.4140
# Epoch 66/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 18s 90ms/step - loss: -0.4084
# Epoch 67/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 18s 88ms/step - loss: -0.4058
# Epoch 68/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 18s 90ms/step - loss: -0.4116
# Epoch 69/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 18s 87ms/step - loss: -0.4412
# Epoch 70/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 17s 86ms/step - loss: -0.4520
# Epoch 71/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 19s 93ms/step - loss: -0.4569
# Epoch 72/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 18s 92ms/step - loss: -0.4678
# Epoch 73/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 18s 90ms/step - loss: -0.4960
# Epoch 74/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 19s 93ms/step - loss: -0.5063
# Epoch 75/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 19s 93ms/step - loss: -0.5162
# Epoch 76/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 19s 96ms/step - loss: -0.5056
# Epoch 77/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 19s 93ms/step - loss: -0.5200
# Epoch 78/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 19s 94ms/step - loss: -0.5451
# Epoch 79/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 17s 87ms/step - loss: -0.5371
# Epoch 80/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 18s 89ms/step - loss: -0.5806
# Epoch 81/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 18s 92ms/step - loss: -0.5738
# Epoch 82/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 17s 86ms/step - loss: -0.5776
# Epoch 83/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 18s 89ms/step - loss: -0.6088
# Epoch 84/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 18s 88ms/step - loss: -0.5932
# Epoch 85/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 18s 89ms/step - loss: -0.6105
# Epoch 86/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 18s 90ms/step - loss: -0.6269
# Epoch 87/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 18s 90ms/step - loss: -0.6058
# Epoch 88/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 18s 89ms/step - loss: -0.6351
# Epoch 89/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 18s 89ms/step - loss: -0.6291
# Epoch 90/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 18s 88ms/step - loss: -0.6602
# Epoch 91/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 18s 88ms/step - loss: -0.6311
# Epoch 92/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 18s 88ms/step - loss: -0.6607
# Epoch 93/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 18s 90ms/step - loss: -0.6517
# Epoch 94/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 18s 89ms/step - loss: -0.6725
# Epoch 95/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 18s 91ms/step - loss: -0.6338
# Epoch 96/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 18s 91ms/step - loss: -0.6677
# Epoch 97/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 18s 91ms/step - loss: -0.6650
# Epoch 98/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 19s 94ms/step - loss: -0.6589
# Epoch 99/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 19s 95ms/step - loss: -0.6527
# Epoch 100/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 18s 91ms/step - loss: -0.6573

# %%
f=bf.diagnostics.plots.loss(history)

# %%
# Generate test datasets and get posterior samples and perform diagnostics
num_samples = 1000 #number of posterior samples
val_sims = simulator.sample(200) # validation data
post_draws = workflow.sample(conditions=val_sims, num_samples=num_samples)
post_draws.keys()
# Out:
# dict_keys(['mu'])

# %%
f1 = bf.diagnostics.plots.calibration_histogram(post_draws, val_sims)
f2 = bf.diagnostics.plots.calibration_ecdf(post_draws, val_sims,difference=True)
f3 = bf.diagnostics.plots.recovery(post_draws, val_sims)
# Out:
# WARNING:bayesflow:The ratio of simulations / posterior draws should be > 20 for reliable variance reduction, but your ratio is 0. Confidence intervals might be unreliable!

# %%
# Save the trained approximator
filepath = Path("/Users/mandyking/benchmark/benchmark/examples/gaussian/networks") / "m2.keras"
filepath.parent.mkdir(exist_ok=True)
workflow.approximator.save(filepath=filepath)

# %%
# load approximator
approximator = keras.saving.load_model(filepath)
post_draws = approximator.sample(conditions=val_sims, num_samples=num_samples)
f3 = bf.diagnostics.plots.recovery(post_draws, val_sims)
