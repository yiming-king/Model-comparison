# %%
import numpy as np
import bayesflow as bf
import keras
from pathlib import Path
from benchmark.examples.gaussian.analysis import summry_diagnostic as sd
# Out:
# INFO:jax._src.xla_bridge:Unable to initialize backend 'rocm': module 'jaxlib.xla_extension' has no attribute 'GpuAllocatorConfig'
# INFO:jax._src.xla_bridge:Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: dlopen(libtpu.so, 0x0001): tried: 'libtpu.so' (no such file), '/System/Volumes/Preboot/Cryptexes/OSlibtpu.so' (no such file), '/opt/anaconda3/envs/benchmark2/bin/../lib/libtpu.so' (no such file), '/usr/lib/libtpu.so' (no such file, not in dyld cache), 'libtpu.so' (no such file), '/usr/local/lib/libtpu.so' (no such file), '/usr/lib/libtpu.so' (no such file, not in dyld cache)
# INFO:bayesflow:Using backend 'jax'

# %%
bf.__version__
# Out:
# '2.0.12'

# %%
RNG=np.random.default_rng(2025)
num_dims=20
num_obs=50
mu_prior_mean=0.5
mu_prior_std=1
likelihood_std=1

# %%
# simulator
def prior():
    mu = RNG.normal(loc=mu_prior_mean, scale=mu_prior_std, size=num_dims)
    return dict(mu=mu)
def likelihood(mu):
    x =RNG.normal(loc=mu, scale=likelihood_std, size=(num_obs, num_dims))
    return dict(x=x)
simulator=bf.make_simulator([prior,likelihood])

# %%
# adapter 
adapter = (bf.adapters.Adapter()
                        .convert_dtype("float64", "float32")
                        .rename('mu', 'inference_variables')
                        .rename('x', 'summary_variables')
                )

# %%
# networks
summary_net = bf.networks.DeepSet(
    summary_dim=6 * num_dims,
)

inference_net = bf.networks.CouplingFlow()

# %%
workflow = bf.BasicWorkflow(simulator=simulator,
                                          adapter=adapter,
                                          summary_network=summary_net,
                                          inference_network=inference_net,
                                          standardize="all"
                                          )
epochs=100
batch_size=64
num_batches_per_epoch=128
learning_rate=keras.optimizers.schedules.CosineDecay(
            initial_learning_rate=1e-4, 
            decay_steps=epochs * num_batches_per_epoch
            )
workflow.approximator.compile(optimizer=keras.optimizers.Adam(learning_rate=learning_rate))

# %%
history = workflow.fit_online(epochs=epochs,batch_size=batch_size,num_batches_per_epoch=num_batches_per_epoch)
# Out:
# INFO:bayesflow:Fitting on dataset instance of OnlineDataset.
# INFO:bayesflow:Building on a test batch.
# Epoch 1/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 9s 35ms/step - loss: 25.0517
# Epoch 2/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: 18.2160
# Epoch 3/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - loss: 13.3172
# Epoch 4/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - loss: 9.5468
# Epoch 5/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - loss: 6.5307
# Epoch 6/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - loss: 3.8968
# Epoch 7/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - loss: 2.2237
# Epoch 8/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - loss: 0.7988
# Epoch 9/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - loss: -0.1824
# Epoch 10/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - loss: -0.9034
# Epoch 11/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - loss: -1.6200
# Epoch 12/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: -2.0149
# Epoch 13/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - loss: -2.5903
# Epoch 14/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: -2.8408
# Epoch 15/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: -3.3197
# Epoch 16/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: -3.5668
# Epoch 17/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: -3.8658
# Epoch 18/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: -4.0584
# Epoch 19/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: -4.1968
# Epoch 20/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: -4.4448
# Epoch 21/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: -4.6337
# Epoch 22/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: -4.8411
# Epoch 23/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: -4.9304
# Epoch 24/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: -5.0540
# Epoch 25/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: -5.2041
# Epoch 26/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - loss: -5.2421
# Epoch 27/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: -5.4928
# Epoch 28/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: -5.5841
# Epoch 29/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - loss: -5.6729
# Epoch 30/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - loss: -5.7203
# Epoch 31/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: -5.8961
# Epoch 32/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: -5.9855
# Epoch 33/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: -6.0669
# Epoch 34/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: -6.1061
# Epoch 35/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: -6.2275
# Epoch 36/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: -6.2776
# Epoch 37/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: -6.4062
# Epoch 38/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: -6.4052
# Epoch 39/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: -6.4825
# Epoch 40/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: -6.5578
# Epoch 41/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: -6.6277
# Epoch 42/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: -6.7338
# Epoch 43/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: -6.7459
# Epoch 44/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - loss: -6.8250
# Epoch 45/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: -6.8903
# Epoch 46/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - loss: -7.0190
# Epoch 47/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - loss: -7.0149
# Epoch 48/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: -7.1851
# Epoch 49/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: -7.1673
# Epoch 50/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: -7.1583
# Epoch 51/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - loss: -7.2256
# Epoch 52/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: -7.4307
# Epoch 53/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: -7.3524
# Epoch 54/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: -7.5039
# Epoch 55/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: -7.5032
# Epoch 56/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - loss: -7.6359
# Epoch 57/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: -7.6054
# Epoch 58/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: -7.6638
# Epoch 59/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: -7.7385
# Epoch 60/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - loss: -7.7948
# Epoch 61/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: -7.8157
# Epoch 62/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - loss: -7.8706
# Epoch 63/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: -7.8749
# Epoch 64/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - loss: -7.9548
# Epoch 65/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - loss: -7.9917
# Epoch 66/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: -8.0291
# Epoch 67/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: -8.1423
# Epoch 68/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: -8.1858
# Epoch 69/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - loss: -8.1966
# Epoch 70/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: -8.2876
# Epoch 71/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - loss: -8.3406
# Epoch 72/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: -8.3358
# Epoch 73/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - loss: -8.4071
# Epoch 74/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - loss: -8.4696
# Epoch 75/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - loss: -8.5564
# Epoch 76/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - loss: -8.5619
# Epoch 77/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: -8.5566
# Epoch 78/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - loss: -8.5402
# Epoch 79/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - loss: -8.6040
# Epoch 80/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - loss: -8.6013
# Epoch 81/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - loss: -8.6850
# Epoch 82/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: -8.7213
# Epoch 83/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - loss: -8.7190
# Epoch 84/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - loss: -8.6988
# Epoch 85/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - loss: -8.7859
# Epoch 86/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - loss: -8.8060
# Epoch 87/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - loss: -8.8020
# Epoch 88/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - loss: -8.8581
# Epoch 89/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - loss: -8.8547
# Epoch 90/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - loss: -8.9509
# Epoch 91/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - loss: -8.9007
# Epoch 92/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - loss: -8.8883
# Epoch 93/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - loss: -8.9763
# Epoch 94/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - loss: -8.9577
# Epoch 95/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - loss: -9.0066
# Epoch 96/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: -8.9860
# Epoch 97/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - loss: -9.0408
# Epoch 98/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - loss: -8.9710
# Epoch 99/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - loss: -8.9757
# Epoch 100/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: -8.9830
# INFO:bayesflow:Training completed in 7.83 minutes.

# %%
f=bf.diagnostics.plots.loss(history)

# %%
# Generate test datasets and get posterior samples and perform diagnostics
num_samples = 1000 #number of posterior samples
val_sims = simulator.sample(200) # validation data
post_draws = workflow.sample(conditions=val_sims, num_samples=num_samples)
post_draws.keys()
# Out:
# Summarizing:   0%|          | 0/1 [00:00<?, ?batch/s]
# Sampling:   0%|          | 0/1 [00:00<?, ?batch/s]
# INFO:bayesflow:Sampling completed in 1.32 seconds.
# dict_keys(['mu'])

# %%
#f1 = bf.diagnostics.plots.calibration_histogram(post_draws, val_sims)
f2 = bf.diagnostics.plots.calibration_ecdf(post_draws, val_sims,difference=True)
f3 = bf.diagnostics.plots.recovery(post_draws, val_sims)

# %%
# Save the trained approximator
filepath = Path("/Users/yimingzang/Documents/thesis/benchmark2/benchmark/examples/gaussian/networks") / "m2.keras"
filepath.parent.mkdir(exist_ok=True)
workflow.approximator.save(filepath=filepath)

# %%
# load approximator
filepath = Path("/Users/yimingzang/Documents/thesis/benchmark2/benchmark/examples/gaussian/networks") / "m2.keras"
approximator = keras.saving.load_model(filepath)

# %%
post_draws = approximator.sample(conditions=val_sims, num_samples=num_samples)
f3 = bf.diagnostics.plots.recovery(post_draws, val_sims)
# Out:
# Summarizing:   0%|          | 0/1 [00:00<?, ?batch/s]
# Sampling:   0%|          | 0/1 [00:00<?, ?batch/s]

# %%
dataset_dir = Path("/Users/yimingzang/Documents/thesis/benchmark2/benchmark/examples/gaussian/results/datasets")
ref = sd.fit_reference(approximator, simulator, n_ref=2000)

sd.plot_reference(ref)
df_logml = sd.collect_metric_relation(
    approximator,
    dataset_dir,
    ref,
    sources=["m1", "m2", "m3", "m4"],
    metric_fn=sd.signed_logml_error("m1"),
    metric_name="signed_logml_error_m1",
)
labels = {
    "m1": "M1 (well_specified)",
    "m2": "M2 (prior misspecification)",
    "m3": "M3 (likelihood misspecification)",
    "m4": "M4 (open_world)",
}
summary = sd.empirical_summary(df_logml, "signed_logml_error_m1", labels=labels)
display(sd.format_summary(summary, "signed_logml_error_m1"))

sd.plot_metric_relation(df_logml, summary, "signed_logml_error_m1", ref, labels=labels)
# Out:
# Summarizing:   0%|          | 0/1 [00:00<?, ?batch/s]
# Summarizing:   0%|          | 0/1 [00:00<?, ?batch/s]
# Summarizing:   0%|          | 0/1 [00:00<?, ?batch/s]
# Summarizing:   0%|          | 0/1 [00:00<?, ?batch/s]
# Summarizing:   0%|          | 0/1 [00:00<?, ?batch/s]
#                               label    n  ood_rate Median d_M [2.5%, 97.5%]  \
# 0               M1 (well_specified)  256  0.203125   10.950 [7.566, 16.736]
# 1       M2 (prior misspecification)  256  0.082031    9.665 [7.019, 14.093]
# 2  M3 (likelihood misspecification)  256  0.296875   11.717 [7.717, 17.171]
# 3                   M4 (open_world)  256  0.984375  20.460 [14.540, 29.096]
#
#   Median signed_logml_error_m1 [2.5%, 97.5%]
# 0                     -0.000 [-0.048, 0.044]
# 1                     -0.001 [-0.060, 0.064]
# 2                     -0.025 [-0.628, 0.374]
# 3                    -3.551 [-21.831, 0.575]
# (<Figure size 1400x500 with 2 Axes>,
#  array([<Axes: title={'center': 'Per-dataset relationship'}, xlabel='Summary-space OOD score $d_M$', ylabel='signed_logml_error_m1'>,
#         <Axes: title={'center': 'Group-level relationship'}, xlabel='Median $d_M$ with empirical 95% interval', ylabel='Median signed_logml_error_m1 with empirical 95% interval'>],
#        dtype=object))
