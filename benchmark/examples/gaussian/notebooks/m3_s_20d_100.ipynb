# %% [markdown]
# M3: mu ~ N(0, I), y|mu ~ N(mu, 3I)
# with MMD summary space regularization
# D=20
# N=100

# %%
import numpy as np
import bayesflow as bf
import keras
from pathlib import Path

import pickle
import pandas as pd
import matplotlib.pyplot as plt
from benchmark.examples.gaussian.analysis import summry_diagnostic as sd
from benchmark.examples.gaussian.analysis import summry_diagnostic as sd
from benchmark.examples.gaussian.analytic.analytic import GaussianAnalytical
from benchmark.examples.gaussian.npe.estimation import MarginalLikelihoodEstimator
# Out:
# INFO:jax._src.xla_bridge:Unable to initialize backend 'rocm': module 'jaxlib.xla_extension' has no attribute 'GpuAllocatorConfig'
# INFO:jax._src.xla_bridge:Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: dlopen(libtpu.so, 0x0001): tried: 'libtpu.so' (no such file), '/System/Volumes/Preboot/Cryptexes/OSlibtpu.so' (no such file), '/opt/anaconda3/envs/benchmark2/bin/../lib/libtpu.so' (no such file), '/usr/lib/libtpu.so' (no such file, not in dyld cache), 'libtpu.so' (no such file), '/usr/local/lib/libtpu.so' (no such file), '/usr/lib/libtpu.so' (no such file, not in dyld cache)
# INFO:bayesflow:Using backend 'jax'

# %%
from tqdm.auto import tqdm as original_tqdm
import bayesflow.approximators.helpers.samplers as bf_samplers
import bayesflow.approximators.helpers.conditions as bf_conditions

def quiet_tqdm(*args, **kwargs):
    kwargs["disable"] = True
    return original_tqdm(*args, **kwargs)

bf_samplers.tqdm = quiet_tqdm
bf_conditions.tqdm = quiet_tqdm

# %%
RNG=np.random.default_rng(2025)
num_dims=20
num_obs=100
mu_prior_mean=0
mu_prior_std=1
likelihood_std=3

# %%
# simulator
def prior(mu=mu_prior_mean, sigma=mu_prior_std):
    mu = RNG.normal(loc=mu, scale=sigma, size=num_dims)
    return dict(mu=mu)
def likelihood(mu):
    x =RNG.normal(loc=mu, scale=likelihood_std, size=(num_obs, num_dims))
    return dict(x=x)
simulator=bf.make_simulator([prior,likelihood])

# %%
# adapter 
adapter = (bf.adapters.Adapter()
                        .convert_dtype("float64", "float32")
                        .rename('mu', 'inference_variables')
                        .rename('x', 'summary_variables')
                )

# %%
# networks
summary_net = bf.networks.DeepSet(
    summary_dim=6 * num_dims, base_distribution="normal"
)

inference_net = bf.networks.CouplingFlow()

# %%
workflow = bf.BasicWorkflow(simulator=simulator,
                                          adapter=adapter,
                                          summary_network=summary_net,
                                          inference_network=inference_net,
                                          standardize="all"
                                          )
epochs=100
batch_size=64
num_batches_per_epoch=128
learning_rate=keras.optimizers.schedules.CosineDecay(
            initial_learning_rate=1e-4, 
            decay_steps=epochs * num_batches_per_epoch
            )
workflow.approximator.compile(optimizer=keras.optimizers.Adam(learning_rate=learning_rate))

# %%
history = workflow.fit_online(epochs=epochs,batch_size=batch_size,num_batches_per_epoch=num_batches_per_epoch)
# Out:
# INFO:bayesflow:Fitting on dataset instance of OnlineDataset.
# INFO:bayesflow:Building on a test batch.
# Epoch 1/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 70ms/step - loss: 24.0016 - loss/inference_loss: 23.3786 - loss/summary_loss: 0.6230
# Epoch 2/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 64ms/step - loss: 19.4704 - loss/inference_loss: 18.9186 - loss/summary_loss: 0.5518
# Epoch 3/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 64ms/step - loss: 15.9693 - loss/inference_loss: 15.4900 - loss/summary_loss: 0.4794
# Epoch 4/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 64ms/step - loss: 14.0663 - loss/inference_loss: 13.6620 - loss/summary_loss: 0.4043
# Epoch 5/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 64ms/step - loss: 11.9414 - loss/inference_loss: 11.5850 - loss/summary_loss: 0.3564
# Epoch 6/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 64ms/step - loss: 11.0293 - loss/inference_loss: 10.7150 - loss/summary_loss: 0.3143
# Epoch 7/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 64ms/step - loss: 10.4356 - loss/inference_loss: 10.1241 - loss/summary_loss: 0.3116
# Epoch 8/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 9s 68ms/step - loss: 9.4129 - loss/inference_loss: 9.1210 - loss/summary_loss: 0.2919
# Epoch 9/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - loss: 9.3123 - loss/inference_loss: 9.0295 - loss/summary_loss: 0.2828
# Epoch 10/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - loss: 8.6778 - loss/inference_loss: 8.4098 - loss/summary_loss: 0.2680
# Epoch 11/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 9s 68ms/step - loss: 8.5891 - loss/inference_loss: 8.3210 - loss/summary_loss: 0.2680
# Epoch 12/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - loss: 8.3690 - loss/inference_loss: 8.1020 - loss/summary_loss: 0.2670
# Epoch 13/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - loss: 7.8525 - loss/inference_loss: 7.5892 - loss/summary_loss: 0.2633
# Epoch 14/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: 7.5849 - loss/inference_loss: 7.3167 - loss/summary_loss: 0.2683
# Epoch 15/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - loss: 7.0608 - loss/inference_loss: 6.8020 - loss/summary_loss: 0.2587
# Epoch 16/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: 7.5417 - loss/inference_loss: 7.2849 - loss/summary_loss: 0.2568
# Epoch 17/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - loss: 7.9985 - loss/inference_loss: 7.7295 - loss/summary_loss: 0.2689
# Epoch 18/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - loss: 6.7713 - loss/inference_loss: 6.5120 - loss/summary_loss: 0.2593
# Epoch 19/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: 7.3132 - loss/inference_loss: 7.0539 - loss/summary_loss: 0.2594
# Epoch 20/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - loss: 6.5804 - loss/inference_loss: 6.3154 - loss/summary_loss: 0.2651
# Epoch 21/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: 6.7864 - loss/inference_loss: 6.5313 - loss/summary_loss: 0.2551
# Epoch 22/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: 6.9708 - loss/inference_loss: 6.7163 - loss/summary_loss: 0.2544
# Epoch 23/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: 5.9103 - loss/inference_loss: 5.6527 - loss/summary_loss: 0.2576
# Epoch 24/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - loss: 7.5007 - loss/inference_loss: 7.2383 - loss/summary_loss: 0.2624
# Epoch 25/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: 6.6775 - loss/inference_loss: 6.4154 - loss/summary_loss: 0.2621
# Epoch 26/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - loss: 6.8167 - loss/inference_loss: 6.5570 - loss/summary_loss: 0.2597
# Epoch 27/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: 5.7438 - loss/inference_loss: 5.4841 - loss/summary_loss: 0.2597
# Epoch 28/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: 5.8436 - loss/inference_loss: 5.5785 - loss/summary_loss: 0.2652
# Epoch 29/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - loss: 5.8005 - loss/inference_loss: 5.5363 - loss/summary_loss: 0.2642
# Epoch 30/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - loss: 5.5239 - loss/inference_loss: 5.2657 - loss/summary_loss: 0.2583
# Epoch 31/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - loss: 5.8315 - loss/inference_loss: 5.5742 - loss/summary_loss: 0.2573
# Epoch 32/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - loss: 6.0788 - loss/inference_loss: 5.8186 - loss/summary_loss: 0.2602
# Epoch 33/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - loss: 6.0572 - loss/inference_loss: 5.8001 - loss/summary_loss: 0.2571
# Epoch 34/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - loss: 6.2880 - loss/inference_loss: 6.0354 - loss/summary_loss: 0.2526
# Epoch 35/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - loss: 5.3700 - loss/inference_loss: 5.1129 - loss/summary_loss: 0.2571
# Epoch 36/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - loss: 5.4858 - loss/inference_loss: 5.2332 - loss/summary_loss: 0.2526
# Epoch 37/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - loss: 5.9618 - loss/inference_loss: 5.7059 - loss/summary_loss: 0.2560
# Epoch 38/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - loss: 5.7028 - loss/inference_loss: 5.4479 - loss/summary_loss: 0.2548
# Epoch 39/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - loss: 5.8701 - loss/inference_loss: 5.6206 - loss/summary_loss: 0.2495
# Epoch 40/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - loss: 6.2238 - loss/inference_loss: 5.9636 - loss/summary_loss: 0.2603
# Epoch 41/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - loss: 5.7421 - loss/inference_loss: 5.4845 - loss/summary_loss: 0.2576
# Epoch 42/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - loss: 5.8936 - loss/inference_loss: 5.6397 - loss/summary_loss: 0.2539
# Epoch 43/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: 5.3471 - loss/inference_loss: 5.0859 - loss/summary_loss: 0.2613
# Epoch 44/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 9s 68ms/step - loss: 5.3761 - loss/inference_loss: 5.1174 - loss/summary_loss: 0.2587
# Epoch 45/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: 5.4023 - loss/inference_loss: 5.1516 - loss/summary_loss: 0.2507
# Epoch 46/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - loss: 5.1391 - loss/inference_loss: 4.8815 - loss/summary_loss: 0.2576
# Epoch 47/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - loss: 5.5125 - loss/inference_loss: 5.2495 - loss/summary_loss: 0.2631
# Epoch 48/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: 4.9408 - loss/inference_loss: 4.6871 - loss/summary_loss: 0.2537
# Epoch 49/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - loss: 5.3590 - loss/inference_loss: 5.1044 - loss/summary_loss: 0.2546
# Epoch 50/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: 5.2038 - loss/inference_loss: 4.9537 - loss/summary_loss: 0.2501
# Epoch 51/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: 5.7622 - loss/inference_loss: 5.5129 - loss/summary_loss: 0.2493
# Epoch 52/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - loss: 5.8854 - loss/inference_loss: 5.6363 - loss/summary_loss: 0.2491
# Epoch 53/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - loss: 5.8269 - loss/inference_loss: 5.5751 - loss/summary_loss: 0.2518
# Epoch 54/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: 5.6023 - loss/inference_loss: 5.3545 - loss/summary_loss: 0.2478
# Epoch 55/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: 5.6296 - loss/inference_loss: 5.3748 - loss/summary_loss: 0.2547
# Epoch 56/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - loss: 5.3390 - loss/inference_loss: 5.0840 - loss/summary_loss: 0.2550
# Epoch 57/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - loss: 5.1326 - loss/inference_loss: 4.8779 - loss/summary_loss: 0.2547
# Epoch 58/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: 5.4962 - loss/inference_loss: 5.2371 - loss/summary_loss: 0.2591
# Epoch 59/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: 5.8778 - loss/inference_loss: 5.6277 - loss/summary_loss: 0.2501
# Epoch 60/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: 4.5117 - loss/inference_loss: 4.2641 - loss/summary_loss: 0.2476
# Epoch 61/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - loss: 5.5144 - loss/inference_loss: 5.2676 - loss/summary_loss: 0.2468
# Epoch 62/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - loss: 4.6865 - loss/inference_loss: 4.4342 - loss/summary_loss: 0.2523
# Epoch 63/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: 5.0086 - loss/inference_loss: 4.7581 - loss/summary_loss: 0.2505
# Epoch 64/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: 4.8333 - loss/inference_loss: 4.5829 - loss/summary_loss: 0.2504
# Epoch 65/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: 4.3417 - loss/inference_loss: 4.0859 - loss/summary_loss: 0.2559
# Epoch 66/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: 4.9610 - loss/inference_loss: 4.7080 - loss/summary_loss: 0.2530
# Epoch 67/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: 4.5711 - loss/inference_loss: 4.3166 - loss/summary_loss: 0.2544
# Epoch 68/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: 5.7324 - loss/inference_loss: 5.4749 - loss/summary_loss: 0.2575
# Epoch 69/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: 4.9264 - loss/inference_loss: 4.6752 - loss/summary_loss: 0.2512
# Epoch 70/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: 4.7238 - loss/inference_loss: 4.4715 - loss/summary_loss: 0.2523
# Epoch 71/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: 5.2049 - loss/inference_loss: 4.9519 - loss/summary_loss: 0.2531
# Epoch 72/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: 4.4154 - loss/inference_loss: 4.1677 - loss/summary_loss: 0.2477
# Epoch 73/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 9s 68ms/step - loss: 4.9556 - loss/inference_loss: 4.7039 - loss/summary_loss: 0.2518
# Epoch 74/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 62ms/step - loss: 5.4186 - loss/inference_loss: 5.1678 - loss/summary_loss: 0.2509
# Epoch 75/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - loss: 4.8853 - loss/inference_loss: 4.6373 - loss/summary_loss: 0.2479
# Epoch 76/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - loss: 4.1305 - loss/inference_loss: 3.8784 - loss/summary_loss: 0.2522
# Epoch 77/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - loss: 4.6573 - loss/inference_loss: 4.4081 - loss/summary_loss: 0.2492
# Epoch 78/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - loss: 4.6849 - loss/inference_loss: 4.4362 - loss/summary_loss: 0.2488
# Epoch 79/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - loss: 4.4065 - loss/inference_loss: 4.1494 - loss/summary_loss: 0.2571
# Epoch 80/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - loss: 4.2082 - loss/inference_loss: 3.9586 - loss/summary_loss: 0.2496
# Epoch 81/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - loss: 4.9698 - loss/inference_loss: 4.7156 - loss/summary_loss: 0.2542
# Epoch 82/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - loss: 4.3694 - loss/inference_loss: 4.1156 - loss/summary_loss: 0.2538
# Epoch 83/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - loss: 4.4953 - loss/inference_loss: 4.2456 - loss/summary_loss: 0.2496
# Epoch 84/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - loss: 4.3742 - loss/inference_loss: 4.1261 - loss/summary_loss: 0.2481
# Epoch 85/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - loss: 4.0282 - loss/inference_loss: 3.7748 - loss/summary_loss: 0.2533
# Epoch 86/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - loss: 4.5344 - loss/inference_loss: 4.2823 - loss/summary_loss: 0.2522
# Epoch 87/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - loss: 4.8967 - loss/inference_loss: 4.6507 - loss/summary_loss: 0.2460
# Epoch 88/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 4.8944 - loss/inference_loss: 4.6388 - loss/summary_loss: 0.2556
# Epoch 89/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 4.3559 - loss/inference_loss: 4.1037 - loss/summary_loss: 0.2522
# Epoch 90/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 4.9100 - loss/inference_loss: 4.6659 - loss/summary_loss: 0.2441
# Epoch 91/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 4.0728 - loss/inference_loss: 3.8272 - loss/summary_loss: 0.2455
# Epoch 92/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 4.1038 - loss/inference_loss: 3.8502 - loss/summary_loss: 0.2535
# Epoch 93/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 4.6439 - loss/inference_loss: 4.3949 - loss/summary_loss: 0.2490
# Epoch 94/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 4.1557 - loss/inference_loss: 3.9087 - loss/summary_loss: 0.2470
# Epoch 95/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 4.6090 - loss/inference_loss: 4.3626 - loss/summary_loss: 0.2463
# Epoch 96/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 4.1095 - loss/inference_loss: 3.8600 - loss/summary_loss: 0.2495
# Epoch 97/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 4.5049 - loss/inference_loss: 4.2559 - loss/summary_loss: 0.2490
# Epoch 98/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 4.6285 - loss/inference_loss: 4.3786 - loss/summary_loss: 0.2499
# Epoch 99/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 4.6898 - loss/inference_loss: 4.4379 - loss/summary_loss: 0.2519
# Epoch 100/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 4.7278 - loss/inference_loss: 4.4738 - loss/summary_loss: 0.2540
# INFO:bayesflow:Training completed in 12.99 minutes.

# %%
f=bf.diagnostics.plots.loss(history)

# %%
# Generate test datasets and get posterior samples and perform diagnostics
num_samples = 1000 #number of posterior samples
val_sims = simulator.sample(200) # validation data
post_draws = workflow.sample(conditions=val_sims, num_samples=num_samples)
post_draws.keys()
# Out:
# INFO:bayesflow:Sampling completed in 1.55 seconds.
# dict_keys(['mu'])

# %%
# f1 = bf.diagnostics.plots.calibration_histogram(post_draws, val_sims)
f2 = bf.diagnostics.plots.calibration_ecdf(post_draws, val_sims,difference=True)
f3 = bf.diagnostics.plots.recovery(post_draws, val_sims)

# %%
# Save the trained approximator
filepath = Path("/Users/yimingzang/Documents/thesis/benchmark2/benchmark/examples/gaussian/networks") / "m3_s_20d_100n.keras"
filepath.parent.mkdir(exist_ok=True)
workflow.approximator.save(filepath=filepath)

# %%
# load approximator
filepath = Path("/Users/yimingzang/Documents/thesis/benchmark2/benchmark/examples/gaussian/networks") / "m3_s_20d_100n.keras"
approximator = keras.saving.load_model(filepath)

# %%
post_draws = approximator.sample(conditions=val_sims, num_samples=num_samples)
f3 = bf.diagnostics.plots.recovery(post_draws, val_sims)

# %%
model_path = Path("/Users/yimingzang/Documents/thesis/benchmark2/benchmark/examples/gaussian/networks/m3_s_20d_100n.keras")
dataset_dir = Path("/Users/yimingzang/Documents/thesis/benchmark2/benchmark/examples/gaussian/results/datasets")

approximator = sd.load_approximator(model_path)
ref = sd.fit_reference(approximator, simulator, n_ref=2000)

sd.plot_reference(ref)
# Out:
# (<Figure size 800x500 with 1 Axes>,
#  <Axes: title={'center': 'Reference distribution of summary-space Mahalanobis distance'}, xlabel='Mahalanobis distance $d_M$', ylabel='Density'>)

# %%
# df_logml = sd.collect_metric_relation(
#     approximator,
#     dataset_dir,
#     ref,
#     sources=["m1", "m2", "m3", "m4"],
#     metric_fn=sd.signed_logml_error("m1"),
#     metric_name="signed_logml_error_m1",
# )
# labels = {
#     "m1": "M1 (well_specified)",
#     "m2": "M2 (prior misspecification)",
#     "m3": "M3 (likelihood misspecification)",
#     "m4": "M4 (open_world)",
# }
# summary = sd.empirical_summary(df_logml, "signed_logml_error_m1", labels=labels)
# display(sd.format_summary(summary, "signed_logml_error_m1"))

# sd.plot_metric_relation(df_logml, summary, "signed_logml_error_m1", ref, labels=labels)
