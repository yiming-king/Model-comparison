# %% [markdown]
# M3: mu ~ N(0, I), y|mu ~ N(mu, 3I)
# with MMD summary space regularization
# D=20, N=10, S=2D

# %%
import numpy as np
import bayesflow as bf
import keras
from pathlib import Path
# Out:
# INFO:jax._src.xla_bridge:Unable to initialize backend 'rocm': module 'jaxlib.xla_extension' has no attribute 'GpuAllocatorConfig'
# INFO:jax._src.xla_bridge:Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: dlopen(libtpu.so, 0x0001): tried: 'libtpu.so' (no such file), '/System/Volumes/Preboot/Cryptexes/OSlibtpu.so' (no such file), '/opt/anaconda3/envs/benchmark2/bin/../lib/libtpu.so' (no such file), '/usr/lib/libtpu.so' (no such file, not in dyld cache), 'libtpu.so' (no such file), '/usr/local/lib/libtpu.so' (no such file), '/usr/lib/libtpu.so' (no such file, not in dyld cache)
# INFO:bayesflow:Using backend 'jax'

# %%
from tqdm.auto import tqdm as original_tqdm
import bayesflow.approximators.helpers.samplers as bf_samplers
import bayesflow.approximators.helpers.conditions as bf_conditions


def quiet_tqdm(*args, **kwargs):
    kwargs["disable"] = True
    return original_tqdm(*args, **kwargs)


bf_samplers.tqdm = quiet_tqdm
bf_conditions.tqdm = quiet_tqdm

# %%
RNG = np.random.default_rng(2025)
num_dims = 20
num_obs = 10
mu_prior_mean = 0
mu_prior_std = 1
likelihood_std = 3

# %%
# simulator
def prior(mu=mu_prior_mean, sigma=mu_prior_std):
    mu = RNG.normal(loc=mu, scale=sigma, size=num_dims)
    return dict(mu=mu)


def likelihood(mu):
    x = RNG.normal(loc=mu, scale=likelihood_std, size=(num_obs, num_dims))
    return dict(x=x)


simulator = bf.make_simulator([prior, likelihood])

# %%
# adapter
adapter = (
    bf.adapters.Adapter()
    .convert_dtype("float64", "float32")
    .rename("mu", "inference_variables")
    .rename("x", "summary_variables")
)

# %%
# networks
summary_net = bf.networks.DeepSet(summary_dim=2 * num_dims, base_distribution="normal")

inference_net = bf.networks.CouplingFlow()

# %%
workflow = bf.BasicWorkflow(
    simulator=simulator,
    adapter=adapter,
    summary_network=summary_net,
    inference_network=inference_net,
    standardize="all",
)
epochs = 100
batch_size = 64
num_batches_per_epoch = 128
learning_rate = keras.optimizers.schedules.CosineDecay(
    initial_learning_rate=1e-4, decay_steps=epochs * num_batches_per_epoch
)
workflow.approximator.compile(
    optimizer=keras.optimizers.Adam(learning_rate=learning_rate)
)

# %%
history = workflow.fit_online(
    epochs=epochs, batch_size=batch_size, num_batches_per_epoch=num_batches_per_epoch
)
# Out:
# INFO:bayesflow:Fitting on dataset instance of OnlineDataset.
# INFO:bayesflow:Building on a test batch.
# Epoch 1/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 26.7902 - loss/inference_loss: 26.3439 - loss/summary_loss: 0.4464
# Epoch 2/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 25.8234 - loss/inference_loss: 25.4742 - loss/summary_loss: 0.3492
# Epoch 3/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 24.9889 - loss/inference_loss: 24.6633 - loss/summary_loss: 0.3256
# Epoch 4/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 24.7369 - loss/inference_loss: 24.4493 - loss/summary_loss: 0.2877
# Epoch 5/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 24.6814 - loss/inference_loss: 24.4073 - loss/summary_loss: 0.2741
# Epoch 6/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 24.9929 - loss/inference_loss: 24.7300 - loss/summary_loss: 0.2629
# Epoch 7/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 24.0221 - loss/inference_loss: 23.7789 - loss/summary_loss: 0.2432
# Epoch 8/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 23.7743 - loss/inference_loss: 23.5276 - loss/summary_loss: 0.2468
# Epoch 9/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 23.7828 - loss/inference_loss: 23.5358 - loss/summary_loss: 0.2469
# Epoch 10/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 23.4346 - loss/inference_loss: 23.1924 - loss/summary_loss: 0.2422
# Epoch 11/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 21.9399 - loss/inference_loss: 21.6988 - loss/summary_loss: 0.2411
# Epoch 12/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 22.5447 - loss/inference_loss: 22.3008 - loss/summary_loss: 0.2439
# Epoch 13/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 22.4037 - loss/inference_loss: 22.1695 - loss/summary_loss: 0.2342
# Epoch 14/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 23.2819 - loss/inference_loss: 23.0498 - loss/summary_loss: 0.2321
# Epoch 15/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 22.5726 - loss/inference_loss: 22.3351 - loss/summary_loss: 0.2375
# Epoch 16/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 21.8619 - loss/inference_loss: 21.6330 - loss/summary_loss: 0.2288
# Epoch 17/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 22.8640 - loss/inference_loss: 22.6258 - loss/summary_loss: 0.2382
# Epoch 18/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 22.4558 - loss/inference_loss: 22.2157 - loss/summary_loss: 0.2401
# Epoch 19/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 22.3303 - loss/inference_loss: 22.0943 - loss/summary_loss: 0.2360
# Epoch 20/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 22.4687 - loss/inference_loss: 22.2405 - loss/summary_loss: 0.2282
# Epoch 21/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 22.1631 - loss/inference_loss: 21.9328 - loss/summary_loss: 0.2303
# Epoch 22/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 21.8656 - loss/inference_loss: 21.6344 - loss/summary_loss: 0.2312
# Epoch 23/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 21.7618 - loss/inference_loss: 21.5366 - loss/summary_loss: 0.2253
# Epoch 24/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 21.7244 - loss/inference_loss: 21.4909 - loss/summary_loss: 0.2335
# Epoch 25/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 21.8711 - loss/inference_loss: 21.6377 - loss/summary_loss: 0.2334
# Epoch 26/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 21.6862 - loss/inference_loss: 21.4572 - loss/summary_loss: 0.2290
# Epoch 27/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 21.0493 - loss/inference_loss: 20.8138 - loss/summary_loss: 0.2356
# Epoch 28/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 21.6631 - loss/inference_loss: 21.4332 - loss/summary_loss: 0.2298
# Epoch 29/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 22.2441 - loss/inference_loss: 22.0141 - loss/summary_loss: 0.2300
# Epoch 30/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 22.0996 - loss/inference_loss: 21.8713 - loss/summary_loss: 0.2283
# Epoch 31/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 22.0892 - loss/inference_loss: 21.8624 - loss/summary_loss: 0.2267
# Epoch 32/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 21.9133 - loss/inference_loss: 21.6810 - loss/summary_loss: 0.2323
# Epoch 33/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 21.8464 - loss/inference_loss: 21.6156 - loss/summary_loss: 0.2308
# Epoch 34/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 22.3638 - loss/inference_loss: 22.1359 - loss/summary_loss: 0.2279
# Epoch 35/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 21.2233 - loss/inference_loss: 20.9907 - loss/summary_loss: 0.2325
# Epoch 36/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 21.9690 - loss/inference_loss: 21.7420 - loss/summary_loss: 0.2270
# Epoch 37/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 22.2767 - loss/inference_loss: 22.0550 - loss/summary_loss: 0.2216
# Epoch 38/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 22.0004 - loss/inference_loss: 21.7672 - loss/summary_loss: 0.2332
# Epoch 39/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 22.5408 - loss/inference_loss: 22.3171 - loss/summary_loss: 0.2237
# Epoch 40/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 22.0275 - loss/inference_loss: 21.8005 - loss/summary_loss: 0.2270
# Epoch 41/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 22.3111 - loss/inference_loss: 22.0842 - loss/summary_loss: 0.2270
# Epoch 42/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 21.0446 - loss/inference_loss: 20.8162 - loss/summary_loss: 0.2284
# Epoch 43/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 22.2797 - loss/inference_loss: 22.0523 - loss/summary_loss: 0.2274
# Epoch 44/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 21.5207 - loss/inference_loss: 21.2842 - loss/summary_loss: 0.2365
# Epoch 45/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 22.0371 - loss/inference_loss: 21.8048 - loss/summary_loss: 0.2323
# Epoch 46/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 22.0964 - loss/inference_loss: 21.8653 - loss/summary_loss: 0.2311
# Epoch 47/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 21.4131 - loss/inference_loss: 21.1853 - loss/summary_loss: 0.2279
# Epoch 48/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 21.3348 - loss/inference_loss: 21.1073 - loss/summary_loss: 0.2276
# Epoch 49/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 21.9015 - loss/inference_loss: 21.6791 - loss/summary_loss: 0.2224
# Epoch 50/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 21.6065 - loss/inference_loss: 21.3785 - loss/summary_loss: 0.2281
# Epoch 51/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 21.7530 - loss/inference_loss: 21.5215 - loss/summary_loss: 0.2315
# Epoch 52/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 21.4187 - loss/inference_loss: 21.1956 - loss/summary_loss: 0.2230
# Epoch 53/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 21.2201 - loss/inference_loss: 20.9972 - loss/summary_loss: 0.2229
# Epoch 54/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 21.7112 - loss/inference_loss: 21.4899 - loss/summary_loss: 0.2214
# Epoch 55/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 21.3751 - loss/inference_loss: 21.1480 - loss/summary_loss: 0.2271
# Epoch 56/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 21.6101 - loss/inference_loss: 21.3794 - loss/summary_loss: 0.2306
# Epoch 57/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 21.1117 - loss/inference_loss: 20.8791 - loss/summary_loss: 0.2326
# Epoch 58/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 21.0915 - loss/inference_loss: 20.8602 - loss/summary_loss: 0.2313
# Epoch 59/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 21.6836 - loss/inference_loss: 21.4549 - loss/summary_loss: 0.2287
# Epoch 60/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 21.2308 - loss/inference_loss: 21.0028 - loss/summary_loss: 0.2279
# Epoch 61/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 21.7143 - loss/inference_loss: 21.4881 - loss/summary_loss: 0.2262
# Epoch 62/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 21.6177 - loss/inference_loss: 21.3940 - loss/summary_loss: 0.2236
# Epoch 63/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 21.8837 - loss/inference_loss: 21.6546 - loss/summary_loss: 0.2290
# Epoch 64/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 22.0493 - loss/inference_loss: 21.8218 - loss/summary_loss: 0.2275
# Epoch 65/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 22.0603 - loss/inference_loss: 21.8352 - loss/summary_loss: 0.2251
# Epoch 66/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 21.5680 - loss/inference_loss: 21.3369 - loss/summary_loss: 0.2311
# Epoch 67/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 21.7670 - loss/inference_loss: 21.5415 - loss/summary_loss: 0.2255
# Epoch 68/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 21.5549 - loss/inference_loss: 21.3318 - loss/summary_loss: 0.2231
# Epoch 69/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 22.2502 - loss/inference_loss: 22.0256 - loss/summary_loss: 0.2246
# Epoch 70/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 21.6372 - loss/inference_loss: 21.4090 - loss/summary_loss: 0.2282
# Epoch 71/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 21.3338 - loss/inference_loss: 21.1085 - loss/summary_loss: 0.2253
# Epoch 72/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 22.3980 - loss/inference_loss: 22.1737 - loss/summary_loss: 0.2243
# Epoch 73/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 21.4744 - loss/inference_loss: 21.2536 - loss/summary_loss: 0.2208
# Epoch 74/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 21.6500 - loss/inference_loss: 21.4196 - loss/summary_loss: 0.2304
# Epoch 75/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 21.6556 - loss/inference_loss: 21.4296 - loss/summary_loss: 0.2261
# Epoch 76/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 21.4149 - loss/inference_loss: 21.1883 - loss/summary_loss: 0.2266
# Epoch 77/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 21.4597 - loss/inference_loss: 21.2329 - loss/summary_loss: 0.2269
# Epoch 78/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 21.2032 - loss/inference_loss: 20.9800 - loss/summary_loss: 0.2232
# Epoch 79/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 21.2569 - loss/inference_loss: 21.0298 - loss/summary_loss: 0.2271
# Epoch 80/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 20.9801 - loss/inference_loss: 20.7518 - loss/summary_loss: 0.2283
# Epoch 81/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 20.9626 - loss/inference_loss: 20.7378 - loss/summary_loss: 0.2248
# Epoch 82/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 22.1602 - loss/inference_loss: 21.9290 - loss/summary_loss: 0.2311
# Epoch 83/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 21.9241 - loss/inference_loss: 21.6953 - loss/summary_loss: 0.2288
# Epoch 84/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 21.3538 - loss/inference_loss: 21.1267 - loss/summary_loss: 0.2272
# Epoch 85/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 22.2306 - loss/inference_loss: 22.0079 - loss/summary_loss: 0.2227
# Epoch 86/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 21.4419 - loss/inference_loss: 21.2108 - loss/summary_loss: 0.2310
# Epoch 87/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 21.5214 - loss/inference_loss: 21.2974 - loss/summary_loss: 0.2241
# Epoch 88/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 21.7243 - loss/inference_loss: 21.5010 - loss/summary_loss: 0.2233
# Epoch 89/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 21.0478 - loss/inference_loss: 20.8281 - loss/summary_loss: 0.2197
# Epoch 90/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 21.0184 - loss/inference_loss: 20.7923 - loss/summary_loss: 0.2261
# Epoch 91/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 20.8578 - loss/inference_loss: 20.6297 - loss/summary_loss: 0.2281
# Epoch 92/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 20.9874 - loss/inference_loss: 20.7658 - loss/summary_loss: 0.2216
# Epoch 93/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 21.0048 - loss/inference_loss: 20.7841 - loss/summary_loss: 0.2206
# Epoch 94/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 21.1941 - loss/inference_loss: 20.9723 - loss/summary_loss: 0.2218
# Epoch 95/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 22.0611 - loss/inference_loss: 21.8397 - loss/summary_loss: 0.2214
# Epoch 96/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 21.0619 - loss/inference_loss: 20.8357 - loss/summary_loss: 0.2262
# Epoch 97/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 21.9606 - loss/inference_loss: 21.7364 - loss/summary_loss: 0.2242
# Epoch 98/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 21.7665 - loss/inference_loss: 21.5424 - loss/summary_loss: 0.2240
# Epoch 99/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 22.1555 - loss/inference_loss: 21.9301 - loss/summary_loss: 0.2254
# Epoch 100/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 21.9302 - loss/inference_loss: 21.7047 - loss/summary_loss: 0.2255
# INFO:bayesflow:Training completed in 3.40 minutes.

# %%
f = bf.diagnostics.plots.loss(history)

# %%
# Generate test datasets and get posterior samples and perform diagnostics
num_samples = 1000  # number of posterior samples
val_sims = simulator.sample(200)  # validation data
post_draws = workflow.sample(conditions=val_sims, num_samples=num_samples)
post_draws.keys()
# Out:
# INFO:bayesflow:Sampling completed in 1.59 seconds.
# dict_keys(['mu'])

# %%
# f1 = bf.diagnostics.plots.calibration_histogram(post_draws, val_sims)
f2 = bf.diagnostics.plots.calibration_ecdf(post_draws, val_sims, difference=True)
f3 = bf.diagnostics.plots.recovery(post_draws, val_sims)

# %%
# Save the trained approximator
filepath = (
    Path(
        "/Users/yimingzang/Documents/Project/benchmark2/benchmark/examples/gaussian/networks"
    )
    / "m3_s_40d_10n.keras"
)
filepath.parent.mkdir(exist_ok=True)
workflow.approximator.save(filepath=filepath)

# %%
# load approximator
filepath = (
    Path(
        "/Users/yimingzang/Documents/Project/benchmark2/benchmark/examples/gaussian/networks"
    )
    / "m3_s_40d_10n.keras"
)
approximator = keras.saving.load_model(filepath)

# %%
post_draws = approximator.sample(conditions=val_sims, num_samples=num_samples)
f3 = bf.diagnostics.plots.recovery(post_draws, val_sims)

# %%
# Gold-standard recovery using samples from the analytical conjugate posterior
prior_precision = 1.0 / mu_prior_std**2
data_precision = num_obs / likelihood_std**2
gold_posterior_var = 1.0 / (prior_precision + data_precision)
gold_posterior_mean = gold_posterior_var * (
    prior_precision * mu_prior_mean + val_sims["x"].sum(axis=1) / likelihood_std**2
)

gold_rng = np.random.default_rng(2026)
gold_posterior_samples = gold_rng.normal(
    loc=gold_posterior_mean[:, None, :],
    scale=np.sqrt(gold_posterior_var),
    size=(gold_posterior_mean.shape[0], num_samples, num_dims),
)

f_gold_recovery = bf.diagnostics.plots.recovery(
    gold_posterior_samples,
    val_sims["mu"],
    variable_names=[f"mu_{i + 1}" for i in range(num_dims)],
    color="#8f2727",
)
