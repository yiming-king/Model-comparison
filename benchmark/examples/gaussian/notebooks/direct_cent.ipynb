# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from numba import njit
import bayesflow as bf
from pathlib import Path

import pickle
import pandas as pd

from benchmark.examples.gaussian.config import (
    ASSUMED_MODELS,
    SOURCE_MODELS,
)
# Out:
# INFO:bayesflow:Using backend 'tensorflow'

# %%
rng = np.random.default_rng(seed=2026)

# %%
N_OBS = 10
N_DIM = 20
# Each dimension has an independent mean drawn from the model's prior.
PRIOR_PARAMS = [
    (0.0, 1.0),
    (3.0, 1.0),
    (0.0, 1.0),
    (0.1, 1.0),
]
LIKELIHOOD_STDS = [1.0, 1.0, 3.0, 1.0]

# %%
def prior_1():
    return dict(mu=rng.normal(*PRIOR_PARAMS[0], size=N_DIM))


def prior_2():
    return dict(mu=rng.normal(*PRIOR_PARAMS[1], size=N_DIM))


def prior_3():
    return dict(mu=rng.normal(*PRIOR_PARAMS[2], size=N_DIM))


def prior_4():
    return dict(mu=rng.normal(*PRIOR_PARAMS[3], size=N_DIM))


def likelihood_1(mu, **kwargs):
    x = rng.normal(loc=mu, scale=1.0, size=(N_OBS, N_DIM)).astype(np.float32)
    return dict(x=x)


def likelihood_2(mu, **kwargs):
    x = rng.normal(loc=mu, scale=3.0, size=(N_OBS, N_DIM)).astype(np.float32)
    return dict(x=x)


simulators = [
    bf.make_simulator([prior_1, likelihood_1]),
    bf.make_simulator([prior_2, likelihood_1]),
    bf.make_simulator([prior_3, likelihood_2]),
    bf.make_simulator([prior_4, likelihood_1]),
]

# %%
def log_marginal_likelihood(x, mu0, tau, sigma):
    x = np.asarray(x, dtype=np.float64)
    n = x.shape[0]
    sig2, tau2 = sigma**2, tau**2
    x_bar = x.mean(axis=0)
    ss_within = np.sum((x - x_bar) ** 2, axis=0)

    logdet = (n - 1) * np.log(sig2) + np.log(sig2 + n * tau2)
    quad = ss_within / sig2 + n * (x_bar - mu0) ** 2 / (sig2 + n * tau2)
    logp_per_dim = -0.5 * (n * np.log(2 * np.pi) + logdet + quad)
    return float(np.sum(logp_per_dim))


def compute_true_log_bfs(test_data, reference=0):
    x_batch = np.asarray(test_data["x"], dtype=np.float64)
    num_models = len(PRIOR_PARAMS)
    log_ml = np.empty((x_batch.shape[0], num_models), dtype=np.float64)

    for k, (mu0, tau) in enumerate(PRIOR_PARAMS):
        sigma = LIKELIHOOD_STDS[k]
        for b, x in enumerate(x_batch):
            log_ml[b, k] = log_marginal_likelihood(x, mu0, tau, sigma)

    competing = [k for k in range(num_models) if k != reference]
    return log_ml[:, competing] - log_ml[:, [reference]]

# %%
workflow = bf.ModelComparisonWorkflow(
    simulator=simulators,
    summary_variables="x",
    summary_network=bf.networks.DeepSet(summary_dim=12),
    scoring_rules="cross_entropy",
    initial_learning_rate=1e-3,
)

# %%
val_data = workflow.simulate(1000)

# %%
history = workflow.fit_online(
    epochs=200, num_batches_per_epoch=64, batch_size=256, validation_data=val_data
)
# Out:
# INFO:bayesflow:Fitting on dataset instance of OnlineDataset.
# INFO:bayesflow:Building on a test batch.
# Epoch 1/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 9s 44ms/step - ScoringRuleNetwork/scoring_rule: 0.7741 - loss: 0.7741 - val_ScoringRuleNetwork/scoring_rule: 0.4204 - val_loss: 0.4204
# Epoch 2/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - ScoringRuleNetwork/scoring_rule: 0.4209 - loss: 0.4209 - val_ScoringRuleNetwork/scoring_rule: 0.3359 - val_loss: 0.3359
# Epoch 3/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - ScoringRuleNetwork/scoring_rule: 0.3758 - loss: 0.3758 - val_ScoringRuleNetwork/scoring_rule: 0.3289 - val_loss: 0.3289
# Epoch 4/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - ScoringRuleNetwork/scoring_rule: 0.3591 - loss: 0.3591 - val_ScoringRuleNetwork/scoring_rule: 0.3271 - val_loss: 0.3271
# Epoch 5/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - ScoringRuleNetwork/scoring_rule: 0.3511 - loss: 0.3511 - val_ScoringRuleNetwork/scoring_rule: 0.3257 - val_loss: 0.3257
# Epoch 6/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - ScoringRuleNetwork/scoring_rule: 0.3483 - loss: 0.3483 - val_ScoringRuleNetwork/scoring_rule: 0.3293 - val_loss: 0.3293
# Epoch 7/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - ScoringRuleNetwork/scoring_rule: 0.3455 - loss: 0.3455 - val_ScoringRuleNetwork/scoring_rule: 0.3390 - val_loss: 0.3390
# Epoch 8/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - ScoringRuleNetwork/scoring_rule: 0.3454 - loss: 0.3454 - val_ScoringRuleNetwork/scoring_rule: 0.3441 - val_loss: 0.3441
# Epoch 9/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - ScoringRuleNetwork/scoring_rule: 0.3551 - loss: 0.3551 - val_ScoringRuleNetwork/scoring_rule: 0.3265 - val_loss: 0.3265
# Epoch 10/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - ScoringRuleNetwork/scoring_rule: 0.3455 - loss: 0.3455 - val_ScoringRuleNetwork/scoring_rule: 0.3279 - val_loss: 0.3279
# Epoch 11/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - ScoringRuleNetwork/scoring_rule: 0.3413 - loss: 0.3413 - val_ScoringRuleNetwork/scoring_rule: 0.3336 - val_loss: 0.3336
# Epoch 12/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - ScoringRuleNetwork/scoring_rule: 0.3456 - loss: 0.3456 - val_ScoringRuleNetwork/scoring_rule: 0.3271 - val_loss: 0.3271
# Epoch 13/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - ScoringRuleNetwork/scoring_rule: 0.3445 - loss: 0.3445 - val_ScoringRuleNetwork/scoring_rule: 0.3227 - val_loss: 0.3227
# Epoch 14/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - ScoringRuleNetwork/scoring_rule: 0.3378 - loss: 0.3378 - val_ScoringRuleNetwork/scoring_rule: 0.3221 - val_loss: 0.3221
# Epoch 15/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - ScoringRuleNetwork/scoring_rule: 0.3377 - loss: 0.3377 - val_ScoringRuleNetwork/scoring_rule: 0.3238 - val_loss: 0.3238
# Epoch 16/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - ScoringRuleNetwork/scoring_rule: 0.3429 - loss: 0.3429 - val_ScoringRuleNetwork/scoring_rule: 0.3219 - val_loss: 0.3219
# Epoch 17/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - ScoringRuleNetwork/scoring_rule: 0.3400 - loss: 0.3400 - val_ScoringRuleNetwork/scoring_rule: 0.3234 - val_loss: 0.3234
# Epoch 18/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - ScoringRuleNetwork/scoring_rule: 0.3359 - loss: 0.3359 - val_ScoringRuleNetwork/scoring_rule: 0.3371 - val_loss: 0.3371
# Epoch 19/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - ScoringRuleNetwork/scoring_rule: 0.3462 - loss: 0.3462 - val_ScoringRuleNetwork/scoring_rule: 0.3232 - val_loss: 0.3232
# Epoch 20/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - ScoringRuleNetwork/scoring_rule: 0.3397 - loss: 0.3397 - val_ScoringRuleNetwork/scoring_rule: 0.3261 - val_loss: 0.3261
# Epoch 21/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - ScoringRuleNetwork/scoring_rule: 0.3421 - loss: 0.3421 - val_ScoringRuleNetwork/scoring_rule: 0.3284 - val_loss: 0.3284
# Epoch 22/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - ScoringRuleNetwork/scoring_rule: 0.3378 - loss: 0.3378 - val_ScoringRuleNetwork/scoring_rule: 0.3256 - val_loss: 0.3256
# Epoch 23/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - ScoringRuleNetwork/scoring_rule: 0.3451 - loss: 0.3451 - val_ScoringRuleNetwork/scoring_rule: 0.3242 - val_loss: 0.3242
# Epoch 24/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - ScoringRuleNetwork/scoring_rule: 0.3401 - loss: 0.3401 - val_ScoringRuleNetwork/scoring_rule: 0.3251 - val_loss: 0.3251
# Epoch 25/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - ScoringRuleNetwork/scoring_rule: 0.3448 - loss: 0.3448 - val_ScoringRuleNetwork/scoring_rule: 0.3245 - val_loss: 0.3245
# Epoch 26/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - ScoringRuleNetwork/scoring_rule: 0.3398 - loss: 0.3398 - val_ScoringRuleNetwork/scoring_rule: 0.3261 - val_loss: 0.3261
# Epoch 27/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - ScoringRuleNetwork/scoring_rule: 0.3364 - loss: 0.3364 - val_ScoringRuleNetwork/scoring_rule: 0.3283 - val_loss: 0.3283
# Epoch 28/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - ScoringRuleNetwork/scoring_rule: 0.3420 - loss: 0.3420 - val_ScoringRuleNetwork/scoring_rule: 0.3268 - val_loss: 0.3268
# Epoch 29/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - ScoringRuleNetwork/scoring_rule: 0.3435 - loss: 0.3435 - val_ScoringRuleNetwork/scoring_rule: 0.3258 - val_loss: 0.3258
# Epoch 30/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - ScoringRuleNetwork/scoring_rule: 0.3386 - loss: 0.3386 - val_ScoringRuleNetwork/scoring_rule: 0.3296 - val_loss: 0.3296
# Epoch 31/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - ScoringRuleNetwork/scoring_rule: 0.3409 - loss: 0.3409 - val_ScoringRuleNetwork/scoring_rule: 0.3243 - val_loss: 0.3243
# Epoch 32/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - ScoringRuleNetwork/scoring_rule: 0.3363 - loss: 0.3363 - val_ScoringRuleNetwork/scoring_rule: 0.3229 - val_loss: 0.3229
# Epoch 33/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - ScoringRuleNetwork/scoring_rule: 0.3403 - loss: 0.3403 - val_ScoringRuleNetwork/scoring_rule: 0.3239 - val_loss: 0.3239
# Epoch 34/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - ScoringRuleNetwork/scoring_rule: 0.3425 - loss: 0.3425 - val_ScoringRuleNetwork/scoring_rule: 0.3257 - val_loss: 0.3257
# Epoch 35/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - ScoringRuleNetwork/scoring_rule: 0.3430 - loss: 0.3430 - val_ScoringRuleNetwork/scoring_rule: 0.3234 - val_loss: 0.3234
# Epoch 36/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - ScoringRuleNetwork/scoring_rule: 0.3473 - loss: 0.3473 - val_ScoringRuleNetwork/scoring_rule: 0.3253 - val_loss: 0.3253
# Epoch 37/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - ScoringRuleNetwork/scoring_rule: 0.3466 - loss: 0.3466 - val_ScoringRuleNetwork/scoring_rule: 0.3243 - val_loss: 0.3243
# Epoch 38/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - ScoringRuleNetwork/scoring_rule: 0.3393 - loss: 0.3393 - val_ScoringRuleNetwork/scoring_rule: 0.3246 - val_loss: 0.3246
# Epoch 39/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - ScoringRuleNetwork/scoring_rule: 0.3378 - loss: 0.3378 - val_ScoringRuleNetwork/scoring_rule: 0.3218 - val_loss: 0.3218
# Epoch 40/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - ScoringRuleNetwork/scoring_rule: 0.3416 - loss: 0.3416 - val_ScoringRuleNetwork/scoring_rule: 0.3280 - val_loss: 0.3280
# Epoch 41/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - ScoringRuleNetwork/scoring_rule: 0.3343 - loss: 0.3343 - val_ScoringRuleNetwork/scoring_rule: 0.3246 - val_loss: 0.3246
# Epoch 42/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - ScoringRuleNetwork/scoring_rule: 0.3417 - loss: 0.3417 - val_ScoringRuleNetwork/scoring_rule: 0.3228 - val_loss: 0.3228
# Epoch 43/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - ScoringRuleNetwork/scoring_rule: 0.3415 - loss: 0.3415 - val_ScoringRuleNetwork/scoring_rule: 0.3305 - val_loss: 0.3305
# Epoch 44/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - ScoringRuleNetwork/scoring_rule: 0.3364 - loss: 0.3364 - val_ScoringRuleNetwork/scoring_rule: 0.3271 - val_loss: 0.3271
# Epoch 45/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - ScoringRuleNetwork/scoring_rule: 0.3455 - loss: 0.3455 - val_ScoringRuleNetwork/scoring_rule: 0.3306 - val_loss: 0.3306
# Epoch 46/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - ScoringRuleNetwork/scoring_rule: 0.3401 - loss: 0.3401 - val_ScoringRuleNetwork/scoring_rule: 0.3264 - val_loss: 0.3264
# Epoch 47/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - ScoringRuleNetwork/scoring_rule: 0.3372 - loss: 0.3372 - val_ScoringRuleNetwork/scoring_rule: 0.3240 - val_loss: 0.3240
# Epoch 48/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - ScoringRuleNetwork/scoring_rule: 0.3422 - loss: 0.3422 - val_ScoringRuleNetwork/scoring_rule: 0.3229 - val_loss: 0.3229
# Epoch 49/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - ScoringRuleNetwork/scoring_rule: 0.3360 - loss: 0.3360 - val_ScoringRuleNetwork/scoring_rule: 0.3284 - val_loss: 0.3284
# Epoch 50/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - ScoringRuleNetwork/scoring_rule: 0.3367 - loss: 0.3367 - val_ScoringRuleNetwork/scoring_rule: 0.3220 - val_loss: 0.3220
# Epoch 51/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - ScoringRuleNetwork/scoring_rule: 0.3324 - loss: 0.3324 - val_ScoringRuleNetwork/scoring_rule: 0.3219 - val_loss: 0.3219
# Epoch 52/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - ScoringRuleNetwork/scoring_rule: 0.3346 - loss: 0.3346 - val_ScoringRuleNetwork/scoring_rule: 0.3231 - val_loss: 0.3231
# Epoch 53/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - ScoringRuleNetwork/scoring_rule: 0.3378 - loss: 0.3378 - val_ScoringRuleNetwork/scoring_rule: 0.3219 - val_loss: 0.3219
# Epoch 54/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - ScoringRuleNetwork/scoring_rule: 0.3399 - loss: 0.3399 - val_ScoringRuleNetwork/scoring_rule: 0.3336 - val_loss: 0.3336
# Epoch 55/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - ScoringRuleNetwork/scoring_rule: 0.3403 - loss: 0.3403 - val_ScoringRuleNetwork/scoring_rule: 0.3221 - val_loss: 0.3221
# Epoch 56/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - ScoringRuleNetwork/scoring_rule: 0.3379 - loss: 0.3379 - val_ScoringRuleNetwork/scoring_rule: 0.3246 - val_loss: 0.3246
# Epoch 57/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - ScoringRuleNetwork/scoring_rule: 0.3372 - loss: 0.3372 - val_ScoringRuleNetwork/scoring_rule: 0.3238 - val_loss: 0.3238
# Epoch 58/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - ScoringRuleNetwork/scoring_rule: 0.3359 - loss: 0.3359 - val_ScoringRuleNetwork/scoring_rule: 0.3270 - val_loss: 0.3270
# Epoch 59/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - ScoringRuleNetwork/scoring_rule: 0.3371 - loss: 0.3371 - val_ScoringRuleNetwork/scoring_rule: 0.3232 - val_loss: 0.3232
# Epoch 60/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - ScoringRuleNetwork/scoring_rule: 0.3409 - loss: 0.3409 - val_ScoringRuleNetwork/scoring_rule: 0.3233 - val_loss: 0.3233
# Epoch 61/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - ScoringRuleNetwork/scoring_rule: 0.3362 - loss: 0.3362 - val_ScoringRuleNetwork/scoring_rule: 0.3232 - val_loss: 0.3232
# Epoch 62/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - ScoringRuleNetwork/scoring_rule: 0.3335 - loss: 0.3335 - val_ScoringRuleNetwork/scoring_rule: 0.3223 - val_loss: 0.3223
# Epoch 63/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - ScoringRuleNetwork/scoring_rule: 0.3349 - loss: 0.3349 - val_ScoringRuleNetwork/scoring_rule: 0.3228 - val_loss: 0.3228
# Epoch 64/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - ScoringRuleNetwork/scoring_rule: 0.3424 - loss: 0.3424 - val_ScoringRuleNetwork/scoring_rule: 0.3215 - val_loss: 0.3215
# Epoch 65/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - ScoringRuleNetwork/scoring_rule: 0.3340 - loss: 0.3340 - val_ScoringRuleNetwork/scoring_rule: 0.3222 - val_loss: 0.3222
# Epoch 66/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - ScoringRuleNetwork/scoring_rule: 0.3359 - loss: 0.3359 - val_ScoringRuleNetwork/scoring_rule: 0.3239 - val_loss: 0.3239
# Epoch 67/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - ScoringRuleNetwork/scoring_rule: 0.3372 - loss: 0.3372 - val_ScoringRuleNetwork/scoring_rule: 0.3226 - val_loss: 0.3226
# Epoch 68/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - ScoringRuleNetwork/scoring_rule: 0.3393 - loss: 0.3393 - val_ScoringRuleNetwork/scoring_rule: 0.3233 - val_loss: 0.3233
# Epoch 69/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - ScoringRuleNetwork/scoring_rule: 0.3338 - loss: 0.3338 - val_ScoringRuleNetwork/scoring_rule: 0.3223 - val_loss: 0.3223
# Epoch 70/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - ScoringRuleNetwork/scoring_rule: 0.3609 - loss: 0.3609 - val_ScoringRuleNetwork/scoring_rule: 0.3246 - val_loss: 0.3246
# Epoch 71/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - ScoringRuleNetwork/scoring_rule: 0.3382 - loss: 0.3382 - val_ScoringRuleNetwork/scoring_rule: 0.3235 - val_loss: 0.3235
# Epoch 72/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - ScoringRuleNetwork/scoring_rule: 0.3399 - loss: 0.3399 - val_ScoringRuleNetwork/scoring_rule: 0.3250 - val_loss: 0.3250
# Epoch 73/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - ScoringRuleNetwork/scoring_rule: 0.3408 - loss: 0.3408 - val_ScoringRuleNetwork/scoring_rule: 0.3266 - val_loss: 0.3266
# Epoch 74/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - ScoringRuleNetwork/scoring_rule: 0.3346 - loss: 0.3346 - val_ScoringRuleNetwork/scoring_rule: 0.3224 - val_loss: 0.3224
# Epoch 75/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - ScoringRuleNetwork/scoring_rule: 0.3336 - loss: 0.3336 - val_ScoringRuleNetwork/scoring_rule: 0.3237 - val_loss: 0.3237
# Epoch 76/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - ScoringRuleNetwork/scoring_rule: 0.3296 - loss: 0.3296 - val_ScoringRuleNetwork/scoring_rule: 0.3222 - val_loss: 0.3222
# Epoch 77/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - ScoringRuleNetwork/scoring_rule: 0.3335 - loss: 0.3335 - val_ScoringRuleNetwork/scoring_rule: 0.3240 - val_loss: 0.3240
# Epoch 78/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - ScoringRuleNetwork/scoring_rule: 0.3393 - loss: 0.3393 - val_ScoringRuleNetwork/scoring_rule: 0.3230 - val_loss: 0.3230
# Epoch 79/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - ScoringRuleNetwork/scoring_rule: 0.3373 - loss: 0.3373 - val_ScoringRuleNetwork/scoring_rule: 0.3294 - val_loss: 0.3294
# Epoch 80/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - ScoringRuleNetwork/scoring_rule: 0.3395 - loss: 0.3395 - val_ScoringRuleNetwork/scoring_rule: 0.3230 - val_loss: 0.3230
# Epoch 81/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - ScoringRuleNetwork/scoring_rule: 0.3339 - loss: 0.3339 - val_ScoringRuleNetwork/scoring_rule: 0.3232 - val_loss: 0.3232
# Epoch 82/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - ScoringRuleNetwork/scoring_rule: 0.3353 - loss: 0.3353 - val_ScoringRuleNetwork/scoring_rule: 0.3252 - val_loss: 0.3252
# Epoch 83/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - ScoringRuleNetwork/scoring_rule: 0.3367 - loss: 0.3367 - val_ScoringRuleNetwork/scoring_rule: 0.3235 - val_loss: 0.3235
# Epoch 84/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - ScoringRuleNetwork/scoring_rule: 0.3333 - loss: 0.3333 - val_ScoringRuleNetwork/scoring_rule: 0.3225 - val_loss: 0.3225
# Epoch 85/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - ScoringRuleNetwork/scoring_rule: 0.3359 - loss: 0.3359 - val_ScoringRuleNetwork/scoring_rule: 0.3236 - val_loss: 0.3236
# Epoch 86/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - ScoringRuleNetwork/scoring_rule: 0.3389 - loss: 0.3389 - val_ScoringRuleNetwork/scoring_rule: 0.3328 - val_loss: 0.3328
# Epoch 87/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - ScoringRuleNetwork/scoring_rule: 0.3355 - loss: 0.3355 - val_ScoringRuleNetwork/scoring_rule: 0.3235 - val_loss: 0.3235
# Epoch 88/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - ScoringRuleNetwork/scoring_rule: 0.3433 - loss: 0.3433 - val_ScoringRuleNetwork/scoring_rule: 0.3272 - val_loss: 0.3272
# Epoch 89/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - ScoringRuleNetwork/scoring_rule: 0.3394 - loss: 0.3394 - val_ScoringRuleNetwork/scoring_rule: 0.3242 - val_loss: 0.3242
# Epoch 90/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - ScoringRuleNetwork/scoring_rule: 0.3407 - loss: 0.3407 - val_ScoringRuleNetwork/scoring_rule: 0.3259 - val_loss: 0.3259
# Epoch 91/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - ScoringRuleNetwork/scoring_rule: 0.3364 - loss: 0.3364 - val_ScoringRuleNetwork/scoring_rule: 0.3230 - val_loss: 0.3230
# Epoch 92/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - ScoringRuleNetwork/scoring_rule: 0.3349 - loss: 0.3349 - val_ScoringRuleNetwork/scoring_rule: 0.3220 - val_loss: 0.3220
# Epoch 93/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - ScoringRuleNetwork/scoring_rule: 0.3414 - loss: 0.3414 - val_ScoringRuleNetwork/scoring_rule: 0.3253 - val_loss: 0.3253
# Epoch 94/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - ScoringRuleNetwork/scoring_rule: 0.3378 - loss: 0.3378 - val_ScoringRuleNetwork/scoring_rule: 0.3220 - val_loss: 0.3220
# Epoch 95/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - ScoringRuleNetwork/scoring_rule: 0.3365 - loss: 0.3365 - val_ScoringRuleNetwork/scoring_rule: 0.3313 - val_loss: 0.3313
# Epoch 96/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - ScoringRuleNetwork/scoring_rule: 0.3382 - loss: 0.3382 - val_ScoringRuleNetwork/scoring_rule: 0.3257 - val_loss: 0.3257
# Epoch 97/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - ScoringRuleNetwork/scoring_rule: 0.3415 - loss: 0.3415 - val_ScoringRuleNetwork/scoring_rule: 0.3227 - val_loss: 0.3227
# Epoch 98/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - ScoringRuleNetwork/scoring_rule: 0.3357 - loss: 0.3357 - val_ScoringRuleNetwork/scoring_rule: 0.3241 - val_loss: 0.3241
# Epoch 99/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - ScoringRuleNetwork/scoring_rule: 0.3391 - loss: 0.3391 - val_ScoringRuleNetwork/scoring_rule: 0.3274 - val_loss: 0.3274
# Epoch 100/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - ScoringRuleNetwork/scoring_rule: 0.3354 - loss: 0.3354 - val_ScoringRuleNetwork/scoring_rule: 0.3243 - val_loss: 0.3243
# Epoch 101/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - ScoringRuleNetwork/scoring_rule: 0.3353 - loss: 0.3353 - val_ScoringRuleNetwork/scoring_rule: 0.3230 - val_loss: 0.3230
# Epoch 102/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - ScoringRuleNetwork/scoring_rule: 0.3392 - loss: 0.3392 - val_ScoringRuleNetwork/scoring_rule: 0.3224 - val_loss: 0.3224
# Epoch 103/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - ScoringRuleNetwork/scoring_rule: 0.3391 - loss: 0.3391 - val_ScoringRuleNetwork/scoring_rule: 0.3229 - val_loss: 0.3229
# Epoch 104/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - ScoringRuleNetwork/scoring_rule: 0.3330 - loss: 0.3330 - val_ScoringRuleNetwork/scoring_rule: 0.3263 - val_loss: 0.3263
# Epoch 105/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - ScoringRuleNetwork/scoring_rule: 0.3311 - loss: 0.3311 - val_ScoringRuleNetwork/scoring_rule: 0.3223 - val_loss: 0.3223
# Epoch 106/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - ScoringRuleNetwork/scoring_rule: 0.3311 - loss: 0.3311 - val_ScoringRuleNetwork/scoring_rule: 0.3219 - val_loss: 0.3219
# Epoch 107/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - ScoringRuleNetwork/scoring_rule: 0.3320 - loss: 0.3320 - val_ScoringRuleNetwork/scoring_rule: 0.3249 - val_loss: 0.3249
# Epoch 108/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - ScoringRuleNetwork/scoring_rule: 0.3331 - loss: 0.3331 - val_ScoringRuleNetwork/scoring_rule: 0.3227 - val_loss: 0.3227
# Epoch 109/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - ScoringRuleNetwork/scoring_rule: 0.3348 - loss: 0.3348 - val_ScoringRuleNetwork/scoring_rule: 0.3224 - val_loss: 0.3224
# Epoch 110/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - ScoringRuleNetwork/scoring_rule: 0.3409 - loss: 0.3409 - val_ScoringRuleNetwork/scoring_rule: 0.3228 - val_loss: 0.3228
# Epoch 111/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - ScoringRuleNetwork/scoring_rule: 0.3333 - loss: 0.3333 - val_ScoringRuleNetwork/scoring_rule: 0.3231 - val_loss: 0.3231
# Epoch 112/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - ScoringRuleNetwork/scoring_rule: 0.3325 - loss: 0.3325 - val_ScoringRuleNetwork/scoring_rule: 0.3231 - val_loss: 0.3231
# Epoch 113/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - ScoringRuleNetwork/scoring_rule: 0.3343 - loss: 0.3343 - val_ScoringRuleNetwork/scoring_rule: 0.3252 - val_loss: 0.3252
# Epoch 114/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - ScoringRuleNetwork/scoring_rule: 0.3408 - loss: 0.3408 - val_ScoringRuleNetwork/scoring_rule: 0.3255 - val_loss: 0.3255
# Epoch 115/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - ScoringRuleNetwork/scoring_rule: 0.3407 - loss: 0.3407 - val_ScoringRuleNetwork/scoring_rule: 0.3227 - val_loss: 0.3227
# Epoch 116/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - ScoringRuleNetwork/scoring_rule: 0.3376 - loss: 0.3376 - val_ScoringRuleNetwork/scoring_rule: 0.3236 - val_loss: 0.3236
# Epoch 117/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - ScoringRuleNetwork/scoring_rule: 0.3314 - loss: 0.3314 - val_ScoringRuleNetwork/scoring_rule: 0.3233 - val_loss: 0.3233
# Epoch 118/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - ScoringRuleNetwork/scoring_rule: 0.3393 - loss: 0.3393 - val_ScoringRuleNetwork/scoring_rule: 0.3217 - val_loss: 0.3217
# Epoch 119/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - ScoringRuleNetwork/scoring_rule: 0.3396 - loss: 0.3396 - val_ScoringRuleNetwork/scoring_rule: 0.3222 - val_loss: 0.3222
# Epoch 120/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - ScoringRuleNetwork/scoring_rule: 0.3405 - loss: 0.3405 - val_ScoringRuleNetwork/scoring_rule: 0.3230 - val_loss: 0.3230
# Epoch 121/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - ScoringRuleNetwork/scoring_rule: 0.3335 - loss: 0.3335 - val_ScoringRuleNetwork/scoring_rule: 0.3242 - val_loss: 0.3242
# Epoch 122/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - ScoringRuleNetwork/scoring_rule: 0.3363 - loss: 0.3363 - val_ScoringRuleNetwork/scoring_rule: 0.3226 - val_loss: 0.3226
# Epoch 123/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - ScoringRuleNetwork/scoring_rule: 0.3375 - loss: 0.3375 - val_ScoringRuleNetwork/scoring_rule: 0.3220 - val_loss: 0.3220
# Epoch 124/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - ScoringRuleNetwork/scoring_rule: 0.3333 - loss: 0.3333 - val_ScoringRuleNetwork/scoring_rule: 0.3221 - val_loss: 0.3221
# Epoch 125/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - ScoringRuleNetwork/scoring_rule: 0.3404 - loss: 0.3404 - val_ScoringRuleNetwork/scoring_rule: 0.3228 - val_loss: 0.3228
# Epoch 126/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - ScoringRuleNetwork/scoring_rule: 0.3420 - loss: 0.3420 - val_ScoringRuleNetwork/scoring_rule: 0.3241 - val_loss: 0.3241
# Epoch 127/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - ScoringRuleNetwork/scoring_rule: 0.3366 - loss: 0.3366 - val_ScoringRuleNetwork/scoring_rule: 0.3221 - val_loss: 0.3221
# Epoch 128/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - ScoringRuleNetwork/scoring_rule: 0.3368 - loss: 0.3368 - val_ScoringRuleNetwork/scoring_rule: 0.3256 - val_loss: 0.3256
# Epoch 129/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - ScoringRuleNetwork/scoring_rule: 0.3375 - loss: 0.3375 - val_ScoringRuleNetwork/scoring_rule: 0.3226 - val_loss: 0.3226
# Epoch 130/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - ScoringRuleNetwork/scoring_rule: 0.3385 - loss: 0.3385 - val_ScoringRuleNetwork/scoring_rule: 0.3231 - val_loss: 0.3231
# Epoch 131/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - ScoringRuleNetwork/scoring_rule: 0.3337 - loss: 0.3337 - val_ScoringRuleNetwork/scoring_rule: 0.3249 - val_loss: 0.3249
# Epoch 132/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - ScoringRuleNetwork/scoring_rule: 0.3369 - loss: 0.3369 - val_ScoringRuleNetwork/scoring_rule: 0.3230 - val_loss: 0.3230
# Epoch 133/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - ScoringRuleNetwork/scoring_rule: 0.3383 - loss: 0.3383 - val_ScoringRuleNetwork/scoring_rule: 0.3230 - val_loss: 0.3230
# Epoch 134/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - ScoringRuleNetwork/scoring_rule: 0.3386 - loss: 0.3386 - val_ScoringRuleNetwork/scoring_rule: 0.3227 - val_loss: 0.3227
# Epoch 135/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - ScoringRuleNetwork/scoring_rule: 0.3329 - loss: 0.3329 - val_ScoringRuleNetwork/scoring_rule: 0.3224 - val_loss: 0.3224
# Epoch 136/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - ScoringRuleNetwork/scoring_rule: 0.3379 - loss: 0.3379 - val_ScoringRuleNetwork/scoring_rule: 0.3254 - val_loss: 0.3254
# Epoch 137/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - ScoringRuleNetwork/scoring_rule: 0.3354 - loss: 0.3354 - val_ScoringRuleNetwork/scoring_rule: 0.3243 - val_loss: 0.3243
# Epoch 138/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - ScoringRuleNetwork/scoring_rule: 0.3379 - loss: 0.3379 - val_ScoringRuleNetwork/scoring_rule: 0.3239 - val_loss: 0.3239
# Epoch 139/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - ScoringRuleNetwork/scoring_rule: 0.3329 - loss: 0.3329 - val_ScoringRuleNetwork/scoring_rule: 0.3221 - val_loss: 0.3221
# Epoch 140/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - ScoringRuleNetwork/scoring_rule: 0.3382 - loss: 0.3382 - val_ScoringRuleNetwork/scoring_rule: 0.3230 - val_loss: 0.3230
# Epoch 141/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - ScoringRuleNetwork/scoring_rule: 0.3323 - loss: 0.3323 - val_ScoringRuleNetwork/scoring_rule: 0.3217 - val_loss: 0.3217
# Epoch 142/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - ScoringRuleNetwork/scoring_rule: 0.3405 - loss: 0.3405 - val_ScoringRuleNetwork/scoring_rule: 0.3223 - val_loss: 0.3223
# Epoch 143/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - ScoringRuleNetwork/scoring_rule: 0.3359 - loss: 0.3359 - val_ScoringRuleNetwork/scoring_rule: 0.3223 - val_loss: 0.3223
# Epoch 144/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - ScoringRuleNetwork/scoring_rule: 0.3373 - loss: 0.3373 - val_ScoringRuleNetwork/scoring_rule: 0.3266 - val_loss: 0.3266
# Epoch 145/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - ScoringRuleNetwork/scoring_rule: 0.3361 - loss: 0.3361 - val_ScoringRuleNetwork/scoring_rule: 0.3223 - val_loss: 0.3223
# Epoch 146/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - ScoringRuleNetwork/scoring_rule: 0.3396 - loss: 0.3396 - val_ScoringRuleNetwork/scoring_rule: 0.3220 - val_loss: 0.3220
# Epoch 147/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - ScoringRuleNetwork/scoring_rule: 0.3375 - loss: 0.3375 - val_ScoringRuleNetwork/scoring_rule: 0.3227 - val_loss: 0.3227
# Epoch 148/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - ScoringRuleNetwork/scoring_rule: 0.3354 - loss: 0.3354 - val_ScoringRuleNetwork/scoring_rule: 0.3216 - val_loss: 0.3216
# Epoch 149/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - ScoringRuleNetwork/scoring_rule: 0.3347 - loss: 0.3347 - val_ScoringRuleNetwork/scoring_rule: 0.3220 - val_loss: 0.3220
# Epoch 150/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - ScoringRuleNetwork/scoring_rule: 0.3367 - loss: 0.3367 - val_ScoringRuleNetwork/scoring_rule: 0.3225 - val_loss: 0.3225
# Epoch 151/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - ScoringRuleNetwork/scoring_rule: 0.3359 - loss: 0.3359 - val_ScoringRuleNetwork/scoring_rule: 0.3232 - val_loss: 0.3232
# Epoch 152/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - ScoringRuleNetwork/scoring_rule: 0.3358 - loss: 0.3358 - val_ScoringRuleNetwork/scoring_rule: 0.3226 - val_loss: 0.3226
# Epoch 153/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - ScoringRuleNetwork/scoring_rule: 0.3354 - loss: 0.3354 - val_ScoringRuleNetwork/scoring_rule: 0.3235 - val_loss: 0.3235
# Epoch 154/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - ScoringRuleNetwork/scoring_rule: 0.3385 - loss: 0.3385 - val_ScoringRuleNetwork/scoring_rule: 0.3234 - val_loss: 0.3234
# Epoch 155/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - ScoringRuleNetwork/scoring_rule: 0.3404 - loss: 0.3404 - val_ScoringRuleNetwork/scoring_rule: 0.3233 - val_loss: 0.3233
# Epoch 156/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - ScoringRuleNetwork/scoring_rule: 0.3331 - loss: 0.3331 - val_ScoringRuleNetwork/scoring_rule: 0.3240 - val_loss: 0.3240
# Epoch 157/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - ScoringRuleNetwork/scoring_rule: 0.3337 - loss: 0.3337 - val_ScoringRuleNetwork/scoring_rule: 0.3237 - val_loss: 0.3237
# Epoch 158/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - ScoringRuleNetwork/scoring_rule: 0.3374 - loss: 0.3374 - val_ScoringRuleNetwork/scoring_rule: 0.3230 - val_loss: 0.3230
# Epoch 159/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - ScoringRuleNetwork/scoring_rule: 0.3361 - loss: 0.3361 - val_ScoringRuleNetwork/scoring_rule: 0.3242 - val_loss: 0.3242
# Epoch 160/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - ScoringRuleNetwork/scoring_rule: 0.3383 - loss: 0.3383 - val_ScoringRuleNetwork/scoring_rule: 0.3236 - val_loss: 0.3236
# Epoch 161/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - ScoringRuleNetwork/scoring_rule: 0.3320 - loss: 0.3320 - val_ScoringRuleNetwork/scoring_rule: 0.3224 - val_loss: 0.3224
# Epoch 162/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - ScoringRuleNetwork/scoring_rule: 0.3392 - loss: 0.3392 - val_ScoringRuleNetwork/scoring_rule: 0.3231 - val_loss: 0.3231
# Epoch 163/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - ScoringRuleNetwork/scoring_rule: 0.3354 - loss: 0.3354 - val_ScoringRuleNetwork/scoring_rule: 0.3222 - val_loss: 0.3222
# Epoch 164/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - ScoringRuleNetwork/scoring_rule: 0.3393 - loss: 0.3393 - val_ScoringRuleNetwork/scoring_rule: 0.3237 - val_loss: 0.3237
# Epoch 165/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - ScoringRuleNetwork/scoring_rule: 0.3381 - loss: 0.3381 - val_ScoringRuleNetwork/scoring_rule: 0.3230 - val_loss: 0.3230
# Epoch 166/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - ScoringRuleNetwork/scoring_rule: 0.3371 - loss: 0.3371 - val_ScoringRuleNetwork/scoring_rule: 0.3220 - val_loss: 0.3220
# Epoch 167/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - ScoringRuleNetwork/scoring_rule: 0.3299 - loss: 0.3299 - val_ScoringRuleNetwork/scoring_rule: 0.3220 - val_loss: 0.3220
# Epoch 168/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - ScoringRuleNetwork/scoring_rule: 0.3367 - loss: 0.3367 - val_ScoringRuleNetwork/scoring_rule: 0.3219 - val_loss: 0.3219
# Epoch 169/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - ScoringRuleNetwork/scoring_rule: 0.3370 - loss: 0.3370 - val_ScoringRuleNetwork/scoring_rule: 0.3233 - val_loss: 0.3233
# Epoch 170/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - ScoringRuleNetwork/scoring_rule: 0.3381 - loss: 0.3381 - val_ScoringRuleNetwork/scoring_rule: 0.3220 - val_loss: 0.3220
# Epoch 171/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - ScoringRuleNetwork/scoring_rule: 0.3311 - loss: 0.3311 - val_ScoringRuleNetwork/scoring_rule: 0.3228 - val_loss: 0.3228
# Epoch 172/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - ScoringRuleNetwork/scoring_rule: 0.3374 - loss: 0.3374 - val_ScoringRuleNetwork/scoring_rule: 0.3220 - val_loss: 0.3220
# Epoch 173/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - ScoringRuleNetwork/scoring_rule: 0.3387 - loss: 0.3387 - val_ScoringRuleNetwork/scoring_rule: 0.3225 - val_loss: 0.3225
# Epoch 174/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - ScoringRuleNetwork/scoring_rule: 0.3325 - loss: 0.3325 - val_ScoringRuleNetwork/scoring_rule: 0.3220 - val_loss: 0.3220
# Epoch 175/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - ScoringRuleNetwork/scoring_rule: 0.3386 - loss: 0.3386 - val_ScoringRuleNetwork/scoring_rule: 0.3219 - val_loss: 0.3219
# Epoch 176/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - ScoringRuleNetwork/scoring_rule: 0.3400 - loss: 0.3400 - val_ScoringRuleNetwork/scoring_rule: 0.3224 - val_loss: 0.3224
# Epoch 177/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - ScoringRuleNetwork/scoring_rule: 0.3333 - loss: 0.3333 - val_ScoringRuleNetwork/scoring_rule: 0.3225 - val_loss: 0.3225
# Epoch 178/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - ScoringRuleNetwork/scoring_rule: 0.3304 - loss: 0.3304 - val_ScoringRuleNetwork/scoring_rule: 0.3222 - val_loss: 0.3222
# Epoch 179/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - ScoringRuleNetwork/scoring_rule: 0.3343 - loss: 0.3343 - val_ScoringRuleNetwork/scoring_rule: 0.3221 - val_loss: 0.3221
# Epoch 180/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - ScoringRuleNetwork/scoring_rule: 0.3348 - loss: 0.3348 - val_ScoringRuleNetwork/scoring_rule: 0.3227 - val_loss: 0.3227
# Epoch 181/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - ScoringRuleNetwork/scoring_rule: 0.3334 - loss: 0.3334 - val_ScoringRuleNetwork/scoring_rule: 0.3223 - val_loss: 0.3223
# Epoch 182/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - ScoringRuleNetwork/scoring_rule: 0.3359 - loss: 0.3359 - val_ScoringRuleNetwork/scoring_rule: 0.3226 - val_loss: 0.3226
# Epoch 183/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - ScoringRuleNetwork/scoring_rule: 0.3376 - loss: 0.3376 - val_ScoringRuleNetwork/scoring_rule: 0.3226 - val_loss: 0.3226
# Epoch 184/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - ScoringRuleNetwork/scoring_rule: 0.3360 - loss: 0.3360 - val_ScoringRuleNetwork/scoring_rule: 0.3224 - val_loss: 0.3224
# Epoch 185/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - ScoringRuleNetwork/scoring_rule: 0.3398 - loss: 0.3398 - val_ScoringRuleNetwork/scoring_rule: 0.3229 - val_loss: 0.3229
# Epoch 186/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - ScoringRuleNetwork/scoring_rule: 0.3334 - loss: 0.3334 - val_ScoringRuleNetwork/scoring_rule: 0.3226 - val_loss: 0.3226
# Epoch 187/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - ScoringRuleNetwork/scoring_rule: 0.3346 - loss: 0.3346 - val_ScoringRuleNetwork/scoring_rule: 0.3227 - val_loss: 0.3227
# Epoch 188/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - ScoringRuleNetwork/scoring_rule: 0.3440 - loss: 0.3440 - val_ScoringRuleNetwork/scoring_rule: 0.3226 - val_loss: 0.3226
# Epoch 189/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - ScoringRuleNetwork/scoring_rule: 0.3373 - loss: 0.3373 - val_ScoringRuleNetwork/scoring_rule: 0.3226 - val_loss: 0.3226
# Epoch 190/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - ScoringRuleNetwork/scoring_rule: 0.3353 - loss: 0.3353 - val_ScoringRuleNetwork/scoring_rule: 0.3226 - val_loss: 0.3226
# Epoch 191/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - ScoringRuleNetwork/scoring_rule: 0.3366 - loss: 0.3366 - val_ScoringRuleNetwork/scoring_rule: 0.3225 - val_loss: 0.3225
# Epoch 192/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - ScoringRuleNetwork/scoring_rule: 0.3395 - loss: 0.3395 - val_ScoringRuleNetwork/scoring_rule: 0.3224 - val_loss: 0.3224
# Epoch 193/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - ScoringRuleNetwork/scoring_rule: 0.3312 - loss: 0.3312 - val_ScoringRuleNetwork/scoring_rule: 0.3224 - val_loss: 0.3224
# Epoch 194/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - ScoringRuleNetwork/scoring_rule: 0.3355 - loss: 0.3355 - val_ScoringRuleNetwork/scoring_rule: 0.3224 - val_loss: 0.3224
# Epoch 195/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - ScoringRuleNetwork/scoring_rule: 0.3345 - loss: 0.3345 - val_ScoringRuleNetwork/scoring_rule: 0.3225 - val_loss: 0.3225
# Epoch 196/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - ScoringRuleNetwork/scoring_rule: 0.3353 - loss: 0.3353 - val_ScoringRuleNetwork/scoring_rule: 0.3225 - val_loss: 0.3225
# Epoch 197/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - ScoringRuleNetwork/scoring_rule: 0.3391 - loss: 0.3391 - val_ScoringRuleNetwork/scoring_rule: 0.3225 - val_loss: 0.3225
# Epoch 198/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - ScoringRuleNetwork/scoring_rule: 0.3327 - loss: 0.3327 - val_ScoringRuleNetwork/scoring_rule: 0.3225 - val_loss: 0.3225
# Epoch 199/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - ScoringRuleNetwork/scoring_rule: 0.3349 - loss: 0.3349 - val_ScoringRuleNetwork/scoring_rule: 0.3225 - val_loss: 0.3225
# Epoch 200/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - ScoringRuleNetwork/scoring_rule: 0.3367 - loss: 0.3367 - val_ScoringRuleNetwork/scoring_rule: 0.3225 - val_loss: 0.3225
# INFO:bayesflow:Training completed in 12.55 minutes.

# %%
figures = workflow.plot_default_diagnostics(
    test_data=2000, true_log_bfs_fn=compute_true_log_bfs
)
# Out:
# Summarizing:   0%|          | 0/1 [00:00<?, ?batch/s]
# INFO:bayesflow:Estimating completed in 0.18 seconds.

# %%
# Save the trained approximator
filepath = Path(
    "/Users/yimingzang/Documents/Project/benchmark2/benchmark/examples/gaussian/networks/direct_cross_entropy.keras"
)
filepath.parent.mkdir(exist_ok=True)
workflow.approximator.save(filepath=filepath)

# %%
# Indirect S=4D caches supply the shared observations and reference PMPs.
# Direct predictions have their own output root, independent of this input path.
RESULTS_DIR = Path(
    "/Users/yimingzang/Documents/Project/benchmark2/benchmark/examples/gaussian/results"
)
INDIRECT_DATASET_DIR = RESULTS_DIR / "ood_80d_10n" / "datasets"
DIRECT_RESULTS_DIR = RESULTS_DIR / "direct"

# %%
all_items = []

for source in SOURCE_MODELS:
    with open(INDIRECT_DATASET_DIR / f"{source}_logml_pmp.pkl", "rb") as f:
        items = pickle.load(f)

    for item in items:
        all_items.append((source, item))

x_batch = np.stack(
    [item["x"] for source, item in all_items],
    axis=0,
).astype(np.float32)

print(x_batch.shape)

# %%
estimates = workflow.estimate(conditions={"x": x_batch})

p_direct = np.asarray(estimates["model_probs"])

# %%
# Export all 600 predictions together with the matching gold / indirect PMPs.
# Run the two preceding data-loading and prediction cells before this cell.
import json
import pathlib
from datetime import datetime, timezone
from scipy.special import softmax

model_order = tuple(ASSUMED_MODELS)
assert model_order == ("m1", "m2", "m3", "m4")
assert len(all_items) == 600
assert x_batch.shape == (600, 10, 20)
np.testing.assert_array_equal(
    x_batch,
    np.stack([item["x"] for source, item in all_items]).astype(np.float32),
)

p_gold = softmax(
    np.array(
        [
            [item[f"gold_log_marginal_{model}"] for model in model_order]
            for source, item in all_items
        ],
        dtype=np.float64,
    ),
    axis=1,
)
p_indirect = softmax(
    np.array(
        [
            [item[f"npe_log_marginal_{model}"] for model in model_order]
            for source, item in all_items
        ],
        dtype=np.float64,
    ),
    axis=1,
)
p_direct = np.asarray(p_direct, dtype=np.float64)

for method, probabilities in {
    "gold": p_gold,
    "indirect": p_indirect,
    "direct": p_direct,
}.items():
    assert probabilities.shape == (600, 4), method
    assert np.isfinite(probabilities).all(), method
    assert ((probabilities >= 0) & (probabilities <= 1)).all(), method
    np.testing.assert_allclose(probabilities.sum(axis=1), 1.0, rtol=0, atol=1e-6)

comparison = pd.DataFrame(
    {
        "source_model": [source for source, item in all_items],
        "id": [int(item["id"]) for source, item in all_items],
    }
)
assert not comparison.duplicated(["source_model", "id"]).any()
source_counts = comparison.groupby("source_model").size().reindex(SOURCE_MODELS)
assert source_counts.eq(50).all()

for j, model in enumerate(model_order):
    comparison[f"p_gold_{model}"] = p_gold[:, j]
    comparison[f"p_indirect_{model}"] = p_indirect[:, j]
    comparison[f"p_direct_{model}"] = p_direct[:, j]
comparison["l1_indirect"] = np.abs(p_indirect - p_gold).sum(axis=1)
comparison["l1_direct"] = np.abs(p_direct - p_gold).sum(axis=1)

COMPARISON_DIR = DIRECT_RESULTS_DIR / "direct_cross_entropy"
COMPARISON_DIR.mkdir(parents=True, exist_ok=True)
CSV_PATH = COMPARISON_DIR / "pmp_comparison.csv"
comparison.to_csv(CSV_PATH, index=False)
metadata = {
    "created_at_utc": datetime.now(timezone.utc).isoformat(),
    "num_datasets": len(comparison),
    "input_shape": list(x_batch.shape),
    "model_order": list(model_order),
    "model_prior": [0.25] * 4,
    "source_counts": {source: int(count) for source, count in source_counts.items()},
    "loss_function": "cross_entropy",
    "direct_checkpoint": str(filepath.resolve()),
    "direct_source": "p_direct from the preceding workflow.estimate cell",
    "indirect_source": "S=4D: softmax of existing npe_log_marginal_m1..m4 in ood_80d_10n; NPE inference was not rerun",
    "indirect_summary_dimension": 80,
    "indirect_summary_multiplier": 4,
    "gold_source": "softmax of existing analytical gold_log_marginal_m1..m4",
    "dataset_directory": str(pathlib.Path(INDIRECT_DATASET_DIR).resolve()),
    "input_files": [f"{source}_logml_pmp.pkl" for source in SOURCE_MODELS],
}
CSV_PATH.with_suffix(".metadata.json").write_text(
    json.dumps(metadata, ensure_ascii=False, indent=2) + "\n",
    encoding="utf-8",
)
print(f"Saved {len(comparison)} datasets with four PMPs per method: {CSV_PATH}")
comparison.head()
