# %% [markdown]
# M2: mu ~ N(3, I), y|mu ~ N(mu, I)
# with MMD summary space regularization
# D=20, N=100, S=D

# %%
import numpy as np
import bayesflow as bf
import keras
from pathlib import Path
# Out:
# INFO:bayesflow:Using backend 'tensorflow'

# %%
from tqdm.auto import tqdm as original_tqdm
import bayesflow.approximators.helpers.samplers as bf_samplers
import bayesflow.approximators.helpers.conditions as bf_conditions


def quiet_tqdm(*args, **kwargs):
    kwargs["disable"] = True
    return original_tqdm(*args, **kwargs)


bf_samplers.tqdm = quiet_tqdm
bf_conditions.tqdm = quiet_tqdm

# %%
RNG = np.random.default_rng(2025)
num_dims = 20
num_obs = 100
mu_prior_mean = 3
mu_prior_std = 1
likelihood_std = 1

# %%
# simulator
def prior(mu=mu_prior_mean, sigma=mu_prior_std):
    mu = RNG.normal(loc=mu, scale=sigma, size=num_dims)
    return dict(mu=mu)


def likelihood(mu):
    x = RNG.normal(loc=mu, scale=likelihood_std, size=(num_obs, num_dims))
    return dict(x=x)


simulator = bf.make_simulator([prior, likelihood])

# %%
# adapter
adapter = (
    bf.adapters.Adapter()
    .convert_dtype("float64", "float32")
    .rename("mu", "inference_variables")
    .rename("x", "summary_variables")
)

# %%
# networks
summary_net = bf.networks.DeepSet(summary_dim=num_dims, base_distribution="normal")

inference_net = bf.networks.CouplingFlow()

# %%
workflow = bf.BasicWorkflow(
    simulator=simulator,
    adapter=adapter,
    summary_network=summary_net,
    inference_network=inference_net,
    standardize="all",
)
epochs = 100
batch_size = 64
num_batches_per_epoch = 128
learning_rate = keras.optimizers.schedules.CosineDecay(
    initial_learning_rate=1e-4, decay_steps=epochs * num_batches_per_epoch
)
workflow.approximator.compile(
    optimizer=keras.optimizers.Adam(learning_rate=learning_rate)
)

# %%
history = workflow.fit_online(
    epochs=epochs, batch_size=batch_size, num_batches_per_epoch=num_batches_per_epoch
)
# Out:
# INFO:bayesflow:Fitting on dataset instance of OnlineDataset.
# INFO:bayesflow:Building on a test batch.
# Epoch 1/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 21s 76ms/step - CouplingFlow/loss: 27.1283 - DeepSet/loss: 0.3795 - loss: 27.5078
# Epoch 2/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 11s 82ms/step - CouplingFlow/loss: 19.3360 - DeepSet/loss: 0.4049 - loss: 19.7409
# Epoch 3/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 12s 91ms/step - CouplingFlow/loss: 10.7150 - DeepSet/loss: 0.4675 - loss: 11.1825
# Epoch 4/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 12s 94ms/step - CouplingFlow/loss: 6.4218 - DeepSet/loss: 0.4684 - loss: 6.8902
# Epoch 5/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 14s 108ms/step - CouplingFlow/loss: 3.7509 - DeepSet/loss: 0.4237 - loss: 4.1746
# Epoch 6/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 14s 109ms/step - CouplingFlow/loss: 1.4519 - DeepSet/loss: 0.3947 - loss: 1.8466
# Epoch 7/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 14s 106ms/step - CouplingFlow/loss: -0.1212 - DeepSet/loss: 0.3699 - loss: 0.2487
# Epoch 8/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 14s 108ms/step - CouplingFlow/loss: -1.6992 - DeepSet/loss: 0.3501 - loss: -1.3492
# Epoch 9/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 14s 108ms/step - CouplingFlow/loss: -2.4581 - DeepSet/loss: 0.3373 - loss: -2.1208
# Epoch 10/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 14s 110ms/step - CouplingFlow/loss: -3.5365 - DeepSet/loss: 0.3225 - loss: -3.2140
# Epoch 11/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 14s 112ms/step - CouplingFlow/loss: -4.7993 - DeepSet/loss: 0.3104 - loss: -4.4889
# Epoch 12/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 14s 112ms/step - CouplingFlow/loss: -5.7090 - DeepSet/loss: 0.3037 - loss: -5.4052
# Epoch 13/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 103ms/step - CouplingFlow/loss: -6.5665 - DeepSet/loss: 0.2984 - loss: -6.2682
# Epoch 14/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 14s 112ms/step - CouplingFlow/loss: -6.9218 - DeepSet/loss: 0.2920 - loss: -6.6298
# Epoch 15/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 14s 106ms/step - CouplingFlow/loss: -7.1344 - DeepSet/loss: 0.2884 - loss: -6.8460
# Epoch 16/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━
# Epoch 81/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 79s 620ms/step - CouplingFlow/loss: -14.8140 - DeepSet/loss: 0.2277 - loss: -14.5863
# Epoch 82/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 184s 1s/step - CouplingFlow/loss: -14.8473 - DeepSet/loss: 0.2276 - loss: -14.6197
# Epoch 83/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 33s 260ms/step - CouplingFlow/loss: -14.8509 - DeepSet/loss: 0.2262 - loss: -14.6247
# Epoch 84/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 14s 108ms/step - CouplingFlow/loss: -14.9405 - DeepSet/loss: 0.2279 - loss: -14.7127
# Epoch 85/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2463s 19s/step - CouplingFlow/loss: -14.9976 - DeepSet/loss: 0.2270 - loss: -14.7707
# Epoch 86/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3059s 24s/step - CouplingFlow/loss: -14.8861 - DeepSet/loss: 0.2284 - loss: -14.6577
# Epoch 87/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2647s 21s/step - CouplingFlow/loss: -14.9526 - DeepSet/loss: 0.2280 - loss: -14.7246
# Epoch 88/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 1027s 8s/step - CouplingFlow/loss: -14.9844 - DeepSet/loss: 0.2281 - loss: -14.7563
# Epoch 89/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3370s 27s/step - CouplingFlow/loss: -15.0387 - DeepSet/loss: 0.2262 - loss: -14.8125
# Epoch 90/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 1087s 9s/step - CouplingFlow/loss: -14.9905 - DeepSet/loss: 0.2267 - loss: -14.7637
# Epoch 91/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 895s 7s/step - CouplingFlow/loss: -15.0420 - DeepSet/loss: 0.2267 - loss: -14.8153
# Epoch 92/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 523s 4s/step - CouplingFlow/loss: -15.1059 - DeepSet/loss: 0.2282 - loss: -14.8777
# Epoch 93/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 47s 371ms/step - CouplingFlow/loss: -15.0630 - DeepSet/loss: 0.2271 - loss: -14.8359
# Epoch 94/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 42s 328ms/step - CouplingFlow/loss: -15.0665 - DeepSet/loss: 0.2264 - loss: -14.8401
# Epoch 95/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 42s 327ms/step - CouplingFlow/loss: -15.1175 - DeepSet/loss: 0.2278 - loss: -14.8897
# Epoch 96/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 367s 3s/step - CouplingFlow/loss: -15.1254 - DeepSet/loss: 0.2274 - loss: -14.8980
# Epoch 97/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 1849s 15s/step - CouplingFlow/loss: -15.1369 - DeepSet/loss: 0.2280 - loss: -14.9088
# Epoch 98/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 1278s 10s/step - CouplingFlow/loss: -15.0613 - DeepSet/loss: 0.2275 - loss: -14.8337
# Epoch 99/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 762s 6s/step - CouplingFlow/loss: -15.1051 - DeepSet/loss: 0.2272 - loss: -14.8779
# Epoch 100/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 11s 84ms/step - CouplingFlow/loss: -15.1183 - DeepSet/loss: 0.2265 - loss: -14.8918
# INFO:bayesflow:Training completed in 46.44 minutes.

# %%
f = bf.diagnostics.plots.loss(history)

# %%
# Generate test datasets and get posterior samples and perform diagnostics
num_samples = 1000  # number of posterior samples
val_sims = simulator.sample(200)  # validation data
post_draws = workflow.sample(conditions=val_sims, num_samples=num_samples)
post_draws.keys()
# Out:
# INFO:bayesflow:Sampling completed in 1.29 seconds.
# dict_keys(['mu'])

# %%
# f1 = bf.diagnostics.plots.calibration_histogram(post_draws, val_sims)
f2 = bf.diagnostics.plots.calibration_ecdf(post_draws, val_sims, difference=True)
f3 = bf.diagnostics.plots.recovery(post_draws, val_sims)

# %%
# Save the trained approximator
filepath = (
    Path(
        "/Users/yimingzang/Documents/Project/benchmark2/benchmark/examples/gaussian/networks"
    )
    / "m2_s_20d_100n.keras"
)
filepath.parent.mkdir(exist_ok=True)
workflow.approximator.save(filepath=filepath)

# %%
# load approximator
filepath = (
    Path(
        "/Users/yimingzang/Documents/Project/benchmark2/benchmark/examples/gaussian/networks"
    )
    / "m2_s_20d_100n.keras"
)
approximator = keras.saving.load_model(filepath)

# %%
post_draws = approximator.sample(conditions=val_sims, num_samples=num_samples)
f3 = bf.diagnostics.plots.recovery(post_draws, val_sims)
