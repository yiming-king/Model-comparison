# %% [markdown]
# M2: mu ~ N(3, I), y|mu ~ N(mu, I)
# with MMD summary space regularization
# D=20, N=100, S=2D

# %%
import numpy as np
import bayesflow as bf
import keras
from pathlib import Path

# %%
from tqdm.auto import tqdm as original_tqdm
import bayesflow.approximators.helpers.samplers as bf_samplers
import bayesflow.approximators.helpers.conditions as bf_conditions

def quiet_tqdm(*args, **kwargs):
    kwargs["disable"] = True
    return original_tqdm(*args, **kwargs)

bf_samplers.tqdm = quiet_tqdm
bf_conditions.tqdm = quiet_tqdm

# %%
RNG=np.random.default_rng(2025)
num_dims=20
num_obs=100
mu_prior_mean=3
mu_prior_std=1
likelihood_std=1

# %%
# simulator
def prior(mu=mu_prior_mean, sigma=mu_prior_std):
    mu = RNG.normal(loc=mu, scale=sigma, size=num_dims)
    return dict(mu=mu)
def likelihood(mu):
    x =RNG.normal(loc=mu, scale=likelihood_std, size=(num_obs, num_dims))
    return dict(x=x)
simulator=bf.make_simulator([prior,likelihood])

# %%
# adapter 
adapter = (bf.adapters.Adapter()
                        .convert_dtype("float64", "float32")
                        .rename('mu', 'inference_variables')
                        .rename('x', 'summary_variables')
                )

# %%
# networks
summary_net = bf.networks.DeepSet(
    summary_dim=2*num_dims, base_distribution="normal"
)

inference_net = bf.networks.CouplingFlow(depth=8,
                                         subnet_kwargs={"widths":(256,256,256),
                                                        "norm": "layer",},
                                                        )

# %%
workflow = bf.BasicWorkflow(simulator=simulator,
                                          adapter=adapter,
                                          summary_network=summary_net,
                                          inference_network=inference_net,
                                          standardize="all"
                                          )
epochs=100
batch_size=64
num_batches_per_epoch=128
learning_rate=keras.optimizers.schedules.CosineDecay(
            initial_learning_rate=1e-4, 
            decay_steps=epochs * num_batches_per_epoch
            )
workflow.approximator.compile(optimizer=keras.optimizers.Adam(learning_rate=learning_rate))

# %%
history = workflow.fit_online(epochs=epochs,batch_size=batch_size,num_batches_per_epoch=num_batches_per_epoch)
# Out:
# INFO:bayesflow:Fitting on dataset instance of OnlineDataset.
# INFO:bayesflow:Building on a test batch.
# Epoch 1/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 23s 97ms/step - loss: 17.4528 - loss/inference_loss: 17.1597 - loss/summary_loss: 0.2931
# Epoch 2/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 14s 111ms/step - loss: 11.0957 - loss/inference_loss: 10.7757 - loss/summary_loss: 0.3200
# Epoch 3/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 15s 121ms/step - loss: 8.1977 - loss/inference_loss: 7.8670 - loss/summary_loss: 0.3306
# Epoch 4/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 18s 137ms/step - loss: 4.9083 - loss/inference_loss: 4.5658 - loss/summary_loss: 0.3425
# Epoch 5/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 17s 130ms/step - loss: 2.4611 - loss/inference_loss: 2.1005 - loss/summary_loss: 0.3606
# Epoch 6/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 17s 132ms/step - loss: 0.2838 - loss/inference_loss: -0.0731 - loss/summary_loss: 0.3569
# Epoch 7/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 18s 142ms/step - loss: -0.3233 - loss/inference_loss: -0.6865 - loss/summary_loss: 0.3632
# Epoch 8/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 18s 141ms/step - loss: -1.8102 - loss/inference_loss: -2.1788 - loss/summary_loss: 0.3685
# Epoch 9/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 21s 167ms/step - loss: -2.4972 - loss/inference_loss: -2.8843 - loss/summary_loss: 0.3871
# Epoch 10/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 21s 162ms/step - loss: -3.7610 - loss/inference_loss: -4.1309 - loss/summary_loss: 0.3699
# Epoch 11/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 22s 169ms/step - loss: -3.3373 - loss/inference_loss: -3.7248 - loss/summary_loss: 0.3875
# Epoch 12/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 22s 174ms/step - loss: -4.5400 - loss/inference_loss: -4.9278 - loss/summary_loss: 0.3878
# Epoch 13/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 22s 171ms/step - loss: -5.5429 - loss/inference_loss: -5.9277 - loss/summary_loss: 0.3848
# Epoch 14/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 24s 186ms/step - loss: -5.4620 - loss/inference_loss: -5.8553 - loss/summary_loss: 0.3932
# Epoch 15/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 25s 194ms/step - loss: -6.2041 - loss/inference_loss: -6.6059 - loss/summary_loss: 0.4018
# Epoch 16/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 20s 154ms/step - loss: -7.4953 - loss/inference_loss: -7.8717 - loss/summary_loss: 0.3764
# Epoch 17/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 20s 159ms/step - loss: -6.4966 - loss/inference_loss: -6.8746 - loss/summary_loss: 0.3780
# Epoch 18/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 20s 154ms/step - loss: -7.7962 - loss/inference_loss: -8.1882 - loss/summary_loss: 0.3920
# Epoch 19/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 19s 149ms/step - loss: -6.9397 - loss/inference_loss: -7.3446 - loss/summary_loss: 0.4049
# Epoch 20/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 19s 152ms/step - loss: -6.9250 - loss/inference_loss: -7.3148 - loss/summary_loss: 0.3898
# Epoch 21/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 20s 154ms/step - loss: -6.9925 - loss/inference_loss: -7.3983 - loss/summary_loss: 0.4059
# Epoch 22/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 22s 173ms/step - loss: -8.6597 - loss/inference_loss: -9.0654 - loss/summary_loss: 0.4057
# Epoch 23/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 21s 162ms/step - loss: -8.5613 - loss/inference_loss: -8.9511 - loss/summary_loss: 0.3898
# Epoch 24/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 21s 165ms/step - loss: -8.6161 - loss/inference_loss: -9.0302 - loss/summary_loss: 0.4141
# Epoch 25/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 21s 164ms/step - loss: -8.1641 - loss/inference_loss: -8.5740 - loss/summary_loss: 0.4099
# Epoch 26/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 22s 169ms/step - loss: -8.7212 - loss/inference_loss: -9.1433 - loss/summary_loss: 0.4222
# Epoch 27/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 24s 190ms/step - loss: -9.5136 - loss/inference_loss: -9.9240 - loss/summary_loss: 0.4103
# Epoch 28/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 20s 154ms/step - loss: -8.4122 - loss/inference_loss: -8.8279 - loss/summary_loss: 0.4156
# Epoch 29/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 20s 159ms/step - loss: -9.3923 - loss/inference_loss: -9.8207 - loss/summary_loss: 0.4284
# Epoch 30/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 19s 150ms/step - loss: -9.6357 - loss/inference_loss: -10.0466 - loss/summary_loss: 0.4109
# Epoch 31/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 19s 147ms/step - loss: -10.7312 - loss/inference_loss: -11.1437 - loss/summary_loss: 0.4124
# Epoch 32/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 19s 145ms/step - loss: -9.7622 - loss/inference_loss: -10.1712 - loss/summary_loss: 0.4089
# Epoch 33/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 19s 145ms/step - loss: -10.3040 - loss/inference_loss: -10.7325 - loss/summary_loss: 0.4285
# Epoch 34/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 19s 151ms/step - loss: -9.9761 - loss/inference_loss: -10.3829 - loss/summary_loss: 0.4067
# Epoch 35/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 20s 159ms/step - loss: -9.4000 - loss/inference_loss: -9.8073 - loss/summary_loss: 0.4073
# Epoch 36/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 19s 151ms/step - loss: -10.1422 - loss/inference_loss: -10.5743 - loss/summary_loss: 0.4321
# Epoch 37/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 19s 152ms/step - loss: -10.4778 - loss/inference_loss: -10.9136 - loss/summary_loss: 0.4359
# Epoch 38/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 18s 144ms/step - loss: -9.9827 - loss/inference_loss: -10.4208 - loss/summary_loss: 0.4381
# Epoch 39/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 19s 147ms/step - loss: -9.8737 - loss/inference_loss: -10.3035 - loss/summary_loss: 0.4298
# Epoch 40/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 19s 149ms/step - loss: -10.4026 - loss/inference_loss: -10.8214 - loss/summary_loss: 0.4188
# Epoch 41/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 20s 154ms/step - loss: -10.5334 - loss/inference_loss: -10.9663 - loss/summary_loss: 0.4330
# Epoch 42/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 18s 142ms/step - loss: -10.4770 - loss/inference_loss: -10.9179 - loss/summary_loss: 0.4408
# Epoch 43/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 18s 139ms/step - loss: -11.4636 - loss/inference_loss: -11.8800 - loss/summary_loss: 0.4163
# Epoch 44/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 18s 144ms/step - loss: -11.2767 - loss/inference_loss: -11.7063 - loss/summary_loss: 0.4296
# Epoch 45/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 18s 143ms/step - loss: -11.0820 - loss/inference_loss: -11.5064 - loss/summary_loss: 0.4245
# Epoch 46/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 18s 144ms/step - loss: -11.4392 - loss/inference_loss: -11.8538 - loss/summary_loss: 0.4147
# Epoch 47/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 19s 149ms/step - loss: -11.0791 - loss/inference_loss: -11.4876 - loss/summary_loss: 0.4085
# Epoch 48/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 19s 149ms/step - loss: -11.7027 - loss/inference_loss: -12.1135 - loss/summary_loss: 0.4108
# Epoch 49/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 18s 143ms/step - loss: -11.4958 - loss/inference_loss: -11.9404 - loss/summary_loss: 0.4446
# Epoch 50/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 18s 137ms/step - loss: -11.3890 - loss/inference_loss: -11.8101 - loss/summary_loss: 0.4211
# Epoch 51/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 18s 141ms/step - loss: -10.4124 - loss/inference_loss: -10.8359 - loss/summary_loss: 0.4235
# Epoch 52/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 17s 136ms/step - loss: -11.6603 - loss/inference_loss: -12.0801 - loss/summary_loss: 0.4198
# Epoch 53/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 19s 145ms/step - loss: -11.9473 - loss/inference_loss: -12.3731 - loss/summary_loss: 0.4258
# Epoch 54/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 20s 159ms/step - loss: -11.3417 - loss/inference_loss: -11.7506 - loss/summary_loss: 0.4088
# Epoch 55/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 18s 143ms/step - loss: -11.0698 - loss/inference_loss: -11.4950 - loss/summary_loss: 0.4251
# Epoch 56/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 18s 138ms/step - loss: -11.9574 - loss/inference_loss: -12.3764 - loss/summary_loss: 0.4190
# Epoch 57/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 18s 138ms/step - loss: -11.9112 - loss/inference_loss: -12.3367 - loss/summary_loss: 0.4255
# Epoch 58/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 18s 141ms/step - loss: -12.1222 - loss/inference_loss: -12.5246 - loss/summary_loss: 0.4024
# Epoch 59/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 17s 136ms/step - loss: -11.6664 - loss/inference_loss: -12.0790 - loss/summary_loss: 0.4127
# Epoch 60/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 17s 134ms/step - loss: -12.3433 - loss/inference_loss: -12.7614 - loss/summary_loss: 0.4182
# Epoch 61/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 18s 139ms/step - loss: -12.4940 - loss/inference_loss: -12.9072 - loss/summary_loss: 0.4132
# Epoch 62/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 19s 148ms/step - loss: -12.5924 - loss/inference_loss: -13.0068 - loss/summary_loss: 0.4144
# Epoch 63/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 19s 145ms/step - loss: -12.5960 - loss/inference_loss: -13.0076 - loss/summary_loss: 0.4116
# Epoch 64/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 19s 151ms/step - loss: -12.0827 - loss/inference_loss: -12.4846 - loss/summary_loss: 0.4019
# Epoch 65/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 19s 145ms/step - loss: -13.5158 - loss/inference_loss: -13.9180 - loss/summary_loss: 0.4022
# Epoch 66/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 19s 147ms/step - loss: -12.8866 - loss/inference_loss: -13.2845 - loss/summary_loss: 0.3979
# Epoch 67/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 18s 138ms/step - loss: -13.3899 - loss/inference_loss: -13.8055 - loss/summary_loss: 0.4156
# Epoch 68/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 20s 154ms/step - loss: -12.9137 - loss/inference_loss: -13.3158 - loss/summary_loss: 0.4021
# Epoch 69/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 19s 149ms/step - loss: -12.9809 - loss/inference_loss: -13.3788 - loss/summary_loss: 0.3978
# Epoch 70/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 19s 149ms/step - loss: -13.3707 - loss/inference_loss: -13.7648 - loss/summary_loss: 0.3941
# Epoch 71/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 20s 156ms/step - loss: -12.8577 - loss/inference_loss: -13.2603 - loss/summary_loss: 0.4027
# Epoch 72/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 21s 166ms/step - loss: -13.4906 - loss/inference_loss: -13.9054 - loss/summary_loss: 0.4147
# Epoch 73/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 18s 141ms/step - loss: -13.2820 - loss/inference_loss: -13.7011 - loss/summary_loss: 0.4192
# Epoch 74/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 18s 144ms/step - loss: -12.8739 - loss/inference_loss: -13.2749 - loss/summary_loss: 0.4010
# Epoch 75/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 18s 142ms/step - loss: -13.6480 - loss/inference_loss: -14.0478 - loss/summary_loss: 0.3998
# Epoch 76/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 20s 153ms/step - loss: -14.0698 - loss/inference_loss: -14.4638 - loss/summary_loss: 0.3939
# Epoch 77/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 15s 117ms/step - loss: -13.0892 - loss/inference_loss: -13.4782 - loss/summary_loss: 0.3890
# Epoch 78/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 15s 120ms/step - loss: -13.4911 - loss/inference_loss: -13.8981 - loss/summary_loss: 0.4070
# Epoch 79/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 16s 124ms/step - loss: -14.1968 - loss/inference_loss: -14.5988 - loss/summary_loss: 0.4020
# Epoch 80/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 15s 114ms/step - loss: -13.7832 - loss/inference_loss: -14.1882 - loss/summary_loss: 0.4049
# Epoch 81/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 15s 115ms/step - loss: -14.0352 - loss/inference_loss: -14.4385 - loss/summary_loss: 0.4033
# Epoch 82/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 15s 115ms/step - loss: -14.4273 - loss/inference_loss: -14.8103 - loss/summary_loss: 0.3830
# Epoch 83/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 14s 113ms/step - loss: -14.2018 - loss/inference_loss: -14.5991 - loss/summary_loss: 0.3973
# Epoch 84/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 15s 114ms/step - loss: -13.9237 - loss/inference_loss: -14.3121 - loss/summary_loss: 0.3884
# Epoch 85/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 104ms/step - loss: -14.4237 - loss/inference_loss: -14.8055 - loss/summary_loss: 0.3817
# Epoch 86/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 14s 107ms/step - loss: -14.0404 - loss/inference_loss: -14.4270 - loss/summary_loss: 0.3866
# Epoch 87/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 14s 109ms/step - loss: -14.0429 - loss/inference_loss: -14.4393 - loss/summary_loss: 0.3964
# Epoch 88/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 104ms/step - loss: -14.0674 - loss/inference_loss: -14.4530 - loss/summary_loss: 0.3857
# Epoch 89/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 14s 108ms/step - loss: -14.3150 - loss/inference_loss: -14.6969 - loss/summary_loss: 0.3820
# Epoch 90/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 16s 122ms/step - loss: -13.5799 - loss/inference_loss: -13.9710 - loss/summary_loss: 0.3912
# Epoch 91/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 99ms/step - loss: -14.2563 - loss/inference_loss: -14.6518 - loss/summary_loss: 0.3955
# Epoch 92/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 11s 82ms/step - loss: -14.8656 - loss/inference_loss: -15.2641 - loss/summary_loss: 0.3985
# Epoch 93/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 11s 85ms/step - loss: -14.4457 - loss/inference_loss: -14.8464 - loss/summary_loss: 0.4007
# Epoch 94/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 11s 82ms/step - loss: -14.9917 - loss/inference_loss: -15.3866 - loss/summary_loss: 0.3949
# Epoch 95/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 10s 80ms/step - loss: -14.1243 - loss/inference_loss: -14.5113 - loss/summary_loss: 0.3870
# Epoch 96/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 11s 84ms/step - loss: -15.1650 - loss/inference_loss: -15.5436 - loss/summary_loss: 0.3786
# Epoch 97/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 10s 79ms/step - loss: -14.2415 - loss/inference_loss: -14.6298 - loss/summary_loss: 0.3882
# Epoch 98/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 10s 80ms/step - loss: -14.1679 - loss/inference_loss: -14.5646 - loss/summary_loss: 0.3966
# Epoch 99/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 10s 80ms/step - loss: -14.0594 - loss/inference_loss: -14.4521 - loss/summary_loss: 0.3927
# Epoch 100/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 11s 82ms/step - loss: -14.0059 - loss/inference_loss: -14.3992 - loss/summary_loss: 0.3933
# INFO:bayesflow:Training completed in 29.61 minutes.

# %%
f=bf.diagnostics.plots.loss(history)

# %%
# Generate test datasets and get posterior samples and perform diagnostics
num_samples = 1000 #number of posterior samples
val_sims = simulator.sample(200) # validation data
post_draws = workflow.sample(conditions=val_sims, num_samples=num_samples)
post_draws.keys()
# Out:
# INFO:bayesflow:Sampling completed in 8.69 seconds.
# dict_keys(['mu'])

# %%
# f1 = bf.diagnostics.plots.calibration_histogram(post_draws, val_sims)
f2 = bf.diagnostics.plots.calibration_ecdf(post_draws, val_sims,difference=True)
f3 = bf.diagnostics.plots.recovery(post_draws, val_sims)

# %%
# Save the trained approximator
filepath = Path("/Users/yimingzang/Documents/thesis/benchmark2/benchmark/examples/gaussian/networks") / "m2_s_20d_100n.keras"
filepath.parent.mkdir(exist_ok=True)
workflow.approximator.save(filepath=filepath)

# %%
# load approximator
filepath = Path("/Users/yimingzang/Documents/thesis/benchmark2/benchmark/examples/gaussian/networks") / "m2_s_20d_100n.keras"
approximator = keras.saving.load_model(filepath)

# %%
post_draws = approximator.sample(conditions=val_sims, num_samples=num_samples)
f3 = bf.diagnostics.plots.recovery(post_draws, val_sims)
