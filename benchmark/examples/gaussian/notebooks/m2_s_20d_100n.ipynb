# %% [markdown]
# M2: mu ~ N(3, I), y|mu ~ N(mu, I)
# with MMD summary space regularization
# D=20
# N=100

# %%
import numpy as np
import bayesflow as bf
import keras
from pathlib import Path

import pickle
import pandas as pd
import matplotlib.pyplot as plt
from benchmark.examples.gaussian.analysis import summry_diagnostic as sd
from benchmark.examples.gaussian.analysis import summry_diagnostic as sd
from benchmark.examples.gaussian.analytic.analytic import GaussianAnalytical
from benchmark.examples.gaussian.npe.estimation import MarginalLikelihoodEstimator
# Out:
# INFO:jax._src.xla_bridge:Unable to initialize backend 'rocm': module 'jaxlib.xla_extension' has no attribute 'GpuAllocatorConfig'
# INFO:jax._src.xla_bridge:Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: dlopen(libtpu.so, 0x0001): tried: 'libtpu.so' (no such file), '/System/Volumes/Preboot/Cryptexes/OSlibtpu.so' (no such file), '/opt/anaconda3/envs/benchmark2/bin/../lib/libtpu.so' (no such file), '/usr/lib/libtpu.so' (no such file, not in dyld cache), 'libtpu.so' (no such file), '/usr/local/lib/libtpu.so' (no such file), '/usr/lib/libtpu.so' (no such file, not in dyld cache)
# INFO:bayesflow:Using backend 'jax'

# %%
from tqdm.auto import tqdm as original_tqdm
import bayesflow.approximators.helpers.samplers as bf_samplers
import bayesflow.approximators.helpers.conditions as bf_conditions

def quiet_tqdm(*args, **kwargs):
    kwargs["disable"] = True
    return original_tqdm(*args, **kwargs)

bf_samplers.tqdm = quiet_tqdm
bf_conditions.tqdm = quiet_tqdm

# %%
RNG=np.random.default_rng(2025)
num_dims=20
num_obs=100
mu_prior_mean=3
mu_prior_std=1
likelihood_std=1

# %%
# simulator
def prior(mu=mu_prior_mean, sigma=mu_prior_std):
    mu = RNG.normal(loc=mu, scale=sigma, size=num_dims)
    return dict(mu=mu)
def likelihood(mu):
    x =RNG.normal(loc=mu, scale=likelihood_std, size=(num_obs, num_dims))
    return dict(x=x)
simulator=bf.make_simulator([prior,likelihood])

# %%
# adapter 
adapter = (bf.adapters.Adapter()
                        .convert_dtype("float64", "float32")
                        .rename('mu', 'inference_variables')
                        .rename('x', 'summary_variables')
                )

# %%
# networks
summary_net = bf.networks.DeepSet(
    summary_dim=6 * num_dims, base_distribution="normal"
)

inference_net = bf.networks.CouplingFlow()

# %%
workflow = bf.BasicWorkflow(simulator=simulator,
                                          adapter=adapter,
                                          summary_network=summary_net,
                                          inference_network=inference_net,
                                          standardize="all"
                                          )
epochs=100
batch_size=64
num_batches_per_epoch=128
learning_rate=keras.optimizers.schedules.CosineDecay(
            initial_learning_rate=1e-4, 
            decay_steps=epochs * num_batches_per_epoch
            )
workflow.approximator.compile(optimizer=keras.optimizers.Adam(learning_rate=learning_rate))

# %%
history = workflow.fit_online(epochs=epochs,batch_size=batch_size,num_batches_per_epoch=num_batches_per_epoch)
# Out:
# INFO:bayesflow:Fitting on dataset instance of OnlineDataset.
# INFO:bayesflow:Building on a test batch.
# Epoch 1/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 10s 49ms/step - loss: 21.3777 - loss/inference_loss: 20.6762 - loss/summary_loss: 0.7014
# Epoch 2/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - loss: 14.4415 - loss/inference_loss: 13.7889 - loss/summary_loss: 0.6526
# Epoch 3/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - loss: 10.1328 - loss/inference_loss: 9.5720 - loss/summary_loss: 0.5609
# Epoch 4/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 50ms/step - loss: 6.6482 - loss/inference_loss: 6.1535 - loss/summary_loss: 0.4947
# Epoch 5/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - loss: 3.6177 - loss/inference_loss: 3.1929 - loss/summary_loss: 0.4248
# Epoch 6/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 50ms/step - loss: 1.5174 - loss/inference_loss: 1.1454 - loss/summary_loss: 0.3720
# Epoch 7/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - loss: -0.3563 - loss/inference_loss: -0.7125 - loss/summary_loss: 0.3563
# Epoch 8/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 49ms/step - loss: -0.4572 - loss/inference_loss: -0.7865 - loss/summary_loss: 0.3293
# Epoch 9/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 50ms/step - loss: -0.8331 - loss/inference_loss: -1.1477 - loss/summary_loss: 0.3146
# Epoch 10/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 51ms/step - loss: -1.5782 - loss/inference_loss: -1.8790 - loss/summary_loss: 0.3008
# Epoch 11/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - loss: -0.7639 - loss/inference_loss: -1.0576 - loss/summary_loss: 0.2937
# Epoch 12/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 6s 51ms/step - loss: -3.8233 - loss/inference_loss: -4.1102 - loss/summary_loss: 0.2870
# Epoch 13/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 55ms/step - loss: -5.8019 - loss/inference_loss: -6.0951 - loss/summary_loss: 0.2932
# Epoch 14/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 56ms/step - loss: -4.0429 - loss/inference_loss: -4.3368 - loss/summary_loss: 0.2939
# Epoch 15/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - loss: -6.5213 - loss/inference_loss: -6.7964 - loss/summary_loss: 0.2751
# Epoch 16/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 9s 69ms/step - loss: -6.6486 - loss/inference_loss: -6.9212 - loss/summary_loss: 0.2726
# Epoch 17/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 64ms/step - loss: -5.2982 - loss/inference_loss: -5.5763 - loss/summary_loss: 0.2780
# Epoch 18/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 64ms/step - loss: -6.6311 - loss/inference_loss: -6.9011 - loss/summary_loss: 0.2699
# Epoch 19/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 64ms/step - loss: -6.3741 - loss/inference_loss: -6.6435 - loss/summary_loss: 0.2694
# Epoch 20/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 64ms/step - loss: -7.4124 - loss/inference_loss: -7.6875 - loss/summary_loss: 0.2751
# Epoch 21/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - loss: -6.8695 - loss/inference_loss: -7.1402 - loss/summary_loss: 0.2707
# Epoch 22/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - loss: -7.2662 - loss/inference_loss: -7.5400 - loss/summary_loss: 0.2738
# Epoch 23/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 9s 69ms/step - loss: -7.5977 - loss/inference_loss: -7.8681 - loss/summary_loss: 0.2704
# Epoch 24/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: -7.1132 - loss/inference_loss: -7.3912 - loss/summary_loss: 0.2780
# Epoch 25/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 9s 68ms/step - loss: -8.4938 - loss/inference_loss: -8.7679 - loss/summary_loss: 0.2741
# Epoch 26/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 9s 68ms/step - loss: -8.0320 - loss/inference_loss: -8.2993 - loss/summary_loss: 0.2673
# Epoch 27/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - loss: -9.1830 - loss/inference_loss: -9.4519 - loss/summary_loss: 0.2689
# Epoch 28/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 9s 66ms/step - loss: -8.7130 - loss/inference_loss: -8.9813 - loss/summary_loss: 0.2683
# Epoch 29/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: -10.1655 - loss/inference_loss: -10.4319 - loss/summary_loss: 0.2663
# Epoch 30/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - loss: -10.7138 - loss/inference_loss: -10.9776 - loss/summary_loss: 0.2638
# Epoch 31/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: -9.4523 - loss/inference_loss: -9.7237 - loss/summary_loss: 0.2714
# Epoch 32/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: -10.8436 - loss/inference_loss: -11.1095 - loss/summary_loss: 0.2658
# Epoch 33/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: -10.5321 - loss/inference_loss: -10.8010 - loss/summary_loss: 0.2688
# Epoch 34/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: -10.3213 - loss/inference_loss: -10.5833 - loss/summary_loss: 0.2620
# Epoch 35/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - loss: -11.1519 - loss/inference_loss: -11.4176 - loss/summary_loss: 0.2657
# Epoch 36/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: -11.4468 - loss/inference_loss: -11.7136 - loss/summary_loss: 0.2668
# Epoch 37/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - loss: -10.5991 - loss/inference_loss: -10.8657 - loss/summary_loss: 0.2665
# Epoch 38/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 9s 68ms/step - loss: -11.7522 - loss/inference_loss: -12.0154 - loss/summary_loss: 0.2632
# Epoch 39/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: -11.0268 - loss/inference_loss: -11.2875 - loss/summary_loss: 0.2607
# Epoch 40/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: -10.5697 - loss/inference_loss: -10.8319 - loss/summary_loss: 0.2622
# Epoch 41/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: -10.6028 - loss/inference_loss: -10.8697 - loss/summary_loss: 0.2669
# Epoch 42/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: -11.8617 - loss/inference_loss: -12.1202 - loss/summary_loss: 0.2585
# Epoch 43/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: -12.3403 - loss/inference_loss: -12.6037 - loss/summary_loss: 0.2634
# Epoch 44/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - loss: -11.2337 - loss/inference_loss: -11.4984 - loss/summary_loss: 0.2647
# Epoch 45/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: -12.0265 - loss/inference_loss: -12.2843 - loss/summary_loss: 0.2578
# Epoch 46/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: -11.8713 - loss/inference_loss: -12.1343 - loss/summary_loss: 0.2630
# Epoch 47/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - loss: -12.4613 - loss/inference_loss: -12.7253 - loss/summary_loss: 0.2641
# Epoch 48/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: -12.1981 - loss/inference_loss: -12.4587 - loss/summary_loss: 0.2605
# Epoch 49/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - loss: -12.0449 - loss/inference_loss: -12.3039 - loss/summary_loss: 0.2590
# Epoch 50/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: -12.2233 - loss/inference_loss: -12.4857 - loss/summary_loss: 0.2624
# Epoch 51/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: -11.2119 - loss/inference_loss: -11.4715 - loss/summary_loss: 0.2596
# Epoch 52/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: -11.6555 - loss/inference_loss: -11.9117 - loss/summary_loss: 0.2562
# Epoch 53/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: -12.1115 - loss/inference_loss: -12.3746 - loss/summary_loss: 0.2631
# Epoch 54/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: -12.2541 - loss/inference_loss: -12.5097 - loss/summary_loss: 0.2557
# Epoch 55/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: -11.5753 - loss/inference_loss: -11.8343 - loss/summary_loss: 0.2590
# Epoch 56/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: -12.4511 - loss/inference_loss: -12.7067 - loss/summary_loss: 0.2556
# Epoch 57/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: -12.7019 - loss/inference_loss: -12.9671 - loss/summary_loss: 0.2652
# Epoch 58/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: -11.9454 - loss/inference_loss: -12.2091 - loss/summary_loss: 0.2637
# Epoch 59/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 9s 68ms/step - loss: -12.4075 - loss/inference_loss: -12.6645 - loss/summary_loss: 0.2570
# Epoch 60/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: -13.3964 - loss/inference_loss: -13.6601 - loss/summary_loss: 0.2637
# Epoch 61/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - loss: -12.2584 - loss/inference_loss: -12.5140 - loss/summary_loss: 0.2556
# Epoch 62/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: -12.7863 - loss/inference_loss: -13.0460 - loss/summary_loss: 0.2598
# Epoch 63/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: -13.0563 - loss/inference_loss: -13.3122 - loss/summary_loss: 0.2558
# Epoch 64/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: -12.8871 - loss/inference_loss: -13.1486 - loss/summary_loss: 0.2614
# Epoch 65/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: -14.0611 - loss/inference_loss: -14.3238 - loss/summary_loss: 0.2627
# Epoch 66/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - loss: -13.4720 - loss/inference_loss: -13.7272 - loss/summary_loss: 0.2552
# Epoch 67/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: -13.5990 - loss/inference_loss: -13.8598 - loss/summary_loss: 0.2607
# Epoch 68/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: -12.7493 - loss/inference_loss: -13.0109 - loss/summary_loss: 0.2617
# Epoch 69/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: -13.5073 - loss/inference_loss: -13.7649 - loss/summary_loss: 0.2576
# Epoch 70/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: -13.8611 - loss/inference_loss: -14.1166 - loss/summary_loss: 0.2555
# Epoch 71/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: -12.9103 - loss/inference_loss: -13.1713 - loss/summary_loss: 0.2609
# Epoch 72/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: -13.6022 - loss/inference_loss: -13.8567 - loss/summary_loss: 0.2545
# Epoch 73/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - loss: -13.9967 - loss/inference_loss: -14.2508 - loss/summary_loss: 0.2541
# Epoch 74/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: -13.6564 - loss/inference_loss: -13.9135 - loss/summary_loss: 0.2570
# Epoch 75/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - loss: -13.8882 - loss/inference_loss: -14.1472 - loss/summary_loss: 0.2589
# Epoch 76/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 9s 66ms/step - loss: -14.2792 - loss/inference_loss: -14.5378 - loss/summary_loss: 0.2586
# Epoch 77/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 9s 66ms/step - loss: -13.9183 - loss/inference_loss: -14.1748 - loss/summary_loss: 0.2564
# Epoch 78/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: -14.4970 - loss/inference_loss: -14.7540 - loss/summary_loss: 0.2569
# Epoch 79/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - loss: -14.2707 - loss/inference_loss: -14.5329 - loss/summary_loss: 0.2622
# Epoch 80/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - loss: -14.1991 - loss/inference_loss: -14.4572 - loss/summary_loss: 0.2581
# Epoch 81/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - loss: -14.0290 - loss/inference_loss: -14.2858 - loss/summary_loss: 0.2568
# Epoch 82/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: -14.3392 - loss/inference_loss: -14.6025 - loss/summary_loss: 0.2633
# Epoch 83/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 9s 66ms/step - loss: -14.0032 - loss/inference_loss: -14.2600 - loss/summary_loss: 0.2568
# Epoch 84/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: -14.2058 - loss/inference_loss: -14.4601 - loss/summary_loss: 0.2542
# Epoch 85/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: -14.8393 - loss/inference_loss: -15.0984 - loss/summary_loss: 0.2591
# Epoch 86/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - loss: -14.0718 - loss/inference_loss: -14.3329 - loss/summary_loss: 0.2611
# Epoch 87/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: -14.6388 - loss/inference_loss: -14.8928 - loss/summary_loss: 0.2541
# Epoch 88/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 64ms/step - loss: -14.4583 - loss/inference_loss: -14.7198 - loss/summary_loss: 0.2615
# Epoch 89/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 56ms/step - loss: -14.7180 - loss/inference_loss: -14.9767 - loss/summary_loss: 0.2587
# Epoch 90/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - loss: -14.2713 - loss/inference_loss: -14.5207 - loss/summary_loss: 0.2494
# Epoch 91/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - loss: -15.1582 - loss/inference_loss: -15.4144 - loss/summary_loss: 0.2562
# Epoch 92/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - loss: -14.8842 - loss/inference_loss: -15.1443 - loss/summary_loss: 0.2601
# Epoch 93/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - loss: -14.3929 - loss/inference_loss: -14.6517 - loss/summary_loss: 0.2588
# Epoch 94/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - loss: -14.7514 - loss/inference_loss: -15.0065 - loss/summary_loss: 0.2551
# Epoch 95/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - loss: -14.4011 - loss/inference_loss: -14.6555 - loss/summary_loss: 0.2544
# Epoch 96/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - loss: -14.8226 - loss/inference_loss: -15.0788 - loss/summary_loss: 0.2562
# Epoch 97/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - loss: -14.4525 - loss/inference_loss: -14.7155 - loss/summary_loss: 0.2630
# Epoch 98/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - loss: -14.5494 - loss/inference_loss: -14.8064 - loss/summary_loss: 0.2570
# Epoch 99/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - loss: -14.3496 - loss/inference_loss: -14.6113 - loss/summary_loss: 0.2617
# Epoch 100/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - loss: -14.2697 - loss/inference_loss: -14.5319 - loss/summary_loss: 0.2622
# INFO:bayesflow:Training completed in 13.37 minutes.

# %%
f=bf.diagnostics.plots.loss(history)

# %%
# Generate test datasets and get posterior samples and perform diagnostics
num_samples = 1000 #number of posterior samples
val_sims = simulator.sample(200) # validation data
post_draws = workflow.sample(conditions=val_sims, num_samples=num_samples)
post_draws.keys()
# Out:
# INFO:bayesflow:Sampling completed in 1.82 seconds.
# dict_keys(['mu'])

# %%
# f1 = bf.diagnostics.plots.calibration_histogram(post_draws, val_sims)
f2 = bf.diagnostics.plots.calibration_ecdf(post_draws, val_sims,difference=True)
f3 = bf.diagnostics.plots.recovery(post_draws, val_sims)

# %%
# Save the trained approximator
filepath = Path("/Users/yimingzang/Documents/thesis/benchmark2/benchmark/examples/gaussian/networks") / "m2_s_20d_100n.keras"
filepath.parent.mkdir(exist_ok=True)
workflow.approximator.save(filepath=filepath)

# %%
# load approximator
filepath = Path("/Users/yimingzang/Documents/thesis/benchmark2/benchmark/examples/gaussian/networks") / "m2_s_20d_100n.keras"
approximator = keras.saving.load_model(filepath)

# %%
post_draws = approximator.sample(conditions=val_sims, num_samples=num_samples)
f3 = bf.diagnostics.plots.recovery(post_draws, val_sims)

# %%
model_path = Path("/Users/yimingzang/Documents/thesis/benchmark2/benchmark/examples/gaussian/networks/m2_s_20d_100n.keras")
dataset_dir = Path("/Users/yimingzang/Documents/thesis/benchmark2/benchmark/examples/gaussian/results/datasets")

approximator = sd.load_approximator(model_path)
ref = sd.fit_reference(approximator, simulator, n_ref=2000)

sd.plot_reference(ref)
# Out:
# (<Figure size 800x500 with 1 Axes>,
#  <Axes: title={'center': 'Reference distribution of summary-space Mahalanobis distance'}, xlabel='Mahalanobis distance $d_M$', ylabel='Density'>)

# %%
# df_logml = sd.collect_metric_relation(
#     approximator,
#     dataset_dir,
#     ref,
#     sources=["m1", "m2", "m3", "m4"],
#     metric_fn=sd.signed_logml_error("m1"),
#     metric_name="signed_logml_error_m1",
# )
# labels = {
#     "m1": "M1 (well_specified)",
#     "m2": "M2 (prior misspecification)",
#     "m3": "M3 (likelihood misspecification)",
#     "m4": "M4 (open_world)",
# }
# summary = sd.empirical_summary(df_logml, "signed_logml_error_m1", labels=labels)
# display(sd.format_summary(summary, "signed_logml_error_m1"))

# sd.plot_metric_relation(df_logml, summary, "signed_logml_error_m1", ref, labels=labels)
