# %% [markdown]
# M1: mu ~ N(0, I), y|mu ~ N(mu, I)
# with MMD summary space regularization
# D=20, N=100, S=4D

# %%
import numpy as np
import bayesflow as bf
import keras
from pathlib import Path
# Out:
# INFO:bayesflow:Using backend 'tensorflow'

# %%
from tqdm.auto import tqdm as original_tqdm
import bayesflow.approximators.helpers.samplers as bf_samplers
import bayesflow.approximators.helpers.conditions as bf_conditions

def quiet_tqdm(*args, **kwargs):
    kwargs["disable"] = True
    return original_tqdm(*args, **kwargs)

bf_samplers.tqdm = quiet_tqdm
bf_conditions.tqdm = quiet_tqdm

# %%
RNG=np.random.default_rng(2025)
num_dims=20
num_obs=100
mu_prior_mean=0
mu_prior_std=1
likelihood_std=1

# %%
# simulator
def prior(mu=mu_prior_mean, sigma=mu_prior_std):
    mu = RNG.normal(loc=mu, scale=sigma, size=num_dims)
    return dict(mu=mu)
def likelihood(mu):
    x =RNG.normal(loc=mu, scale=likelihood_std, size=(num_obs, num_dims))
    return dict(x=x)
simulator=bf.make_simulator([prior,likelihood])

# %%
# adapter 
adapter = (bf.adapters.Adapter()
                        .convert_dtype("float64", "float32")
                        .rename('mu', 'inference_variables')
                        .rename('x', 'summary_variables')
                )

# %%
# networks
summary_net = bf.networks.DeepSet(
    summary_dim=4*num_dims, base_distribution="normal"
)

inference_net = bf.networks.CouplingFlow()

# %%
workflow = bf.BasicWorkflow(simulator=simulator,
                                          adapter=adapter,
                                          summary_network=summary_net,
                                          inference_network=inference_net,
                                          standardize="all"
                                          )
epochs=100
batch_size=64
num_batches_per_epoch=128
learning_rate=keras.optimizers.schedules.CosineDecay(
            initial_learning_rate=1e-4, 
            decay_steps=epochs * num_batches_per_epoch
            )
workflow.approximator.compile(optimizer=keras.optimizers.Adam(learning_rate=learning_rate))

# %%
history = workflow.fit_online(epochs=epochs,batch_size=batch_size,num_batches_per_epoch=num_batches_per_epoch)
# Out:
# INFO:bayesflow:Fitting on dataset instance of OnlineDataset.
# INFO:bayesflow:Building on a test batch.
# Epoch 1/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 18s 62ms/step - CouplingFlow/loss: 26.0330 - DeepSet/loss: 0.3579 - loss: 26.3909
# Epoch 2/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 9s 69ms/step - CouplingFlow/loss: 14.9089 - DeepSet/loss: 0.3456 - loss: 15.2546
# Epoch 3/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 9s 72ms/step - CouplingFlow/loss: 5.3102 - DeepSet/loss: 0.3792 - loss: 5.6894
# Epoch 4/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 9s 70ms/step - CouplingFlow/loss: -0.2543 - DeepSet/loss: 0.3698 - loss: 0.1155
# Epoch 5/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 9s 73ms/step - CouplingFlow/loss: -3.1408 - DeepSet/loss: 0.3388 - loss: -2.8020
# Epoch 6/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 9s 73ms/step - CouplingFlow/loss: -5.1364 - DeepSet/loss: 0.3142 - loss: -4.8222
# Epoch 7/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 10s 75ms/step - CouplingFlow/loss: -6.5567 - DeepSet/loss: 0.3011 - loss: -6.2556
# Epoch 8/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 10s 74ms/step - CouplingFlow/loss: -7.7498 - DeepSet/loss: 0.2925 - loss: -7.4573
# Epoch 9/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 10s 75ms/step - CouplingFlow/loss: -9.1364 - DeepSet/loss: 0.2860 - loss: -8.8505
# Epoch 10/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 10s 80ms/step - CouplingFlow/loss: -9.8004 - DeepSet/loss: 0.2812 - loss: -9.5192
# Epoch 11/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 12s 90ms/step - CouplingFlow/loss: -10.2380 - DeepSet/loss: 0.2782 - loss: -9.9598
# Epoch 12/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 12s 97ms/step - CouplingFlow/loss: -10.4240 - DeepSet/loss: 0.2752 - loss: -10.1487
# Epoch 13/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 98ms/step - CouplingFlow/loss: -10.7119 - DeepSet/loss: 0.2744 - loss: -10.4375
# Epoch 14/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 15s 114ms/step - CouplingFlow/loss: -10.9535 - DeepSet/loss: 0.2741 - loss: -10.6794
# Epoch 15/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 14s 107ms/step - CouplingFlow/loss: -11.0847 - DeepSet/loss: 0.2729 - loss: -10.8119
# Epoch 16/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 14s
# Epoch 81/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 361s 3s/step - CouplingFlow/loss: -14.9901 - DeepSet/loss: 0.2734 - loss: -14.7167
# Epoch 82/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 145s 1s/step - CouplingFlow/loss: -15.0454 - DeepSet/loss: 0.2729 - loss: -14.7726
# Epoch 83/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 28s 223ms/step - CouplingFlow/loss: -15.0476 - DeepSet/loss: 0.2726 - loss: -14.7750
# Epoch 84/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 500s 4s/step - CouplingFlow/loss: -15.0910 - DeepSet/loss: 0.2729 - loss: -14.8181
# Epoch 85/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 468s 4s/step - CouplingFlow/loss: -15.2237 - DeepSet/loss: 0.2730 - loss: -14.9506
# Epoch 86/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 487s 4s/step - CouplingFlow/loss: -15.0758 - DeepSet/loss: 0.2728 - loss: -14.8030
# Epoch 87/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 283s 2s/step - CouplingFlow/loss: -15.1519 - DeepSet/loss: 0.2725 - loss: -14.8794
# Epoch 88/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 80s 632ms/step - CouplingFlow/loss: -15.1929 - DeepSet/loss: 0.2735 - loss: -14.9195
# Epoch 89/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 88s 684ms/step - CouplingFlow/loss: -15.2224 - DeepSet/loss: 0.2727 - loss: -14.9497
# Epoch 90/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 189s 1s/step - CouplingFlow/loss: -15.2183 - DeepSet/loss: 0.2728 - loss: -14.9455
# Epoch 91/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 32s 254ms/step - CouplingFlow/loss: -15.2509 - DeepSet/loss: 0.2726 - loss: -14.9783
# Epoch 92/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 101ms/step - CouplingFlow/loss: -15.3000 - DeepSet/loss: 0.2734 - loss: -15.0265
# Epoch 93/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 1411s 11s/step - CouplingFlow/loss: -15.2425 - DeepSet/loss: 0.2732 - loss: -14.9692
# Epoch 94/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 4091s 32s/step - CouplingFlow/loss: -15.2609 - DeepSet/loss: 0.2730 - loss: -14.9879
# Epoch 95/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 1716s 14s/step - CouplingFlow/loss: -15.2719 - DeepSet/loss: 0.2733 - loss: -14.9987
# Epoch 96/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 1958s 15s/step - CouplingFlow/loss: -15.3225 - DeepSet/loss: 0.2734 - loss: -15.0491
# Epoch 97/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2674s 21s/step - CouplingFlow/loss: -15.3357 - DeepSet/loss: 0.2731 - loss: -15.0626
# Epoch 98/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 1796s 14s/step - CouplingFlow/loss: -15.2824 - DeepSet/loss: 0.2725 - loss: -15.0099
# Epoch 99/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 892s 7s/step - CouplingFlow/loss: -15.3130 - DeepSet/loss: 0.2717 - loss: -15.0414
# Epoch 100/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 513s 4s/step - CouplingFlow/loss: -15.2576 - DeepSet/loss: 0.2724 - loss: -14.9852
# INFO:bayesflow:Training completed in 43.10 minutes.

# %%
f=bf.diagnostics.plots.loss(history)

# %%
# Generate test datasets and get posterior samples and perform diagnostics
num_samples = 1000 #number of posterior samples
val_sims = simulator.sample(200) # validation data
post_draws = workflow.sample(conditions=val_sims, num_samples=num_samples)
post_draws.keys()
# Out:
# INFO:bayesflow:Sampling completed in 12.03 seconds.
# dict_keys(['mu'])

# %%
# f1 = bf.diagnostics.plots.calibration_histogram(post_draws, val_sims)
f2 = bf.diagnostics.plots.calibration_ecdf(post_draws, val_sims,difference=True)
f3 = bf.diagnostics.plots.recovery(post_draws, val_sims)

# %%
# Save the trained approximator
filepath = Path("/Users/yimingzang/Documents/Project/benchmark2/benchmark/examples/gaussian/networks") / "m1_s_80d_100n.keras"
filepath.parent.mkdir(exist_ok=True)
workflow.approximator.save(filepath=filepath)

# %%
# load approximator
filepath = Path("/Users/yimingzang/Documents/Project/benchmark2/benchmark/examples/gaussian/networks") / "m1_s_80d_100n.keras"
approximator = keras.saving.load_model(filepath)

# %%
post_draws = approximator.sample(conditions=val_sims, num_samples=num_samples)
f3 = bf.diagnostics.plots.recovery(post_draws, val_sims)
