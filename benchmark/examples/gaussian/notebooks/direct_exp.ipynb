# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from numba import njit
import bayesflow as bf
from pathlib import Path

import pickle
import pandas as pd

from benchmark.examples.gaussian.config import (
    ASSUMED_MODELS,
    SOURCE_MODELS,
)
# Out:
# INFO:bayesflow:Using backend 'tensorflow'

# %%
rng = np.random.default_rng(seed=2026)

# %%
N_OBS = 10
N_DIM = 20
# Each dimension has an independent mean drawn from the model's prior.
PRIOR_PARAMS = [
    (0.0, 1.0),
    (3.0, 1.0),
    (0.0, 1.0),
    (0.1, 1.0),
]
LIKELIHOOD_STDS = [1.0, 1.0, 3.0, 1.0]

# %%
def prior_1():
    return dict(mu=rng.normal(*PRIOR_PARAMS[0], size=N_DIM))
def prior_2():
    return dict(mu=rng.normal(*PRIOR_PARAMS[1], size=N_DIM))
def prior_3():
    return dict(mu=rng.normal(*PRIOR_PARAMS[2], size=N_DIM))
def prior_4():
    return dict(mu=rng.normal(*PRIOR_PARAMS[3], size=N_DIM))

def likelihood_1(mu, **kwargs):
    x = rng.normal(loc=mu, scale=1.0, size=(N_OBS, N_DIM)).astype(np.float32)
    return dict(x=x)
def likelihood_2(mu, **kwargs):
    x = rng.normal(loc=mu, scale=3.0, size=(N_OBS, N_DIM)).astype(np.float32)
    return dict(x=x)

simulators = [
    bf.make_simulator([prior_1, likelihood_1]),
    bf.make_simulator([prior_2, likelihood_1]),
    bf.make_simulator([prior_3, likelihood_2]),
    bf.make_simulator([prior_4, likelihood_1]),
]

# %%
def log_marginal_likelihood(x, mu0, tau, sigma):
    x = np.asarray(x, dtype=np.float64)
    n = x.shape[0]
    sig2, tau2 = sigma**2, tau**2
    x_bar = x.mean(axis=0)
    ss_within = np.sum((x - x_bar)**2, axis=0)

    logdet = (n - 1) * np.log(sig2) + np.log(sig2 + n * tau2)
    quad = ss_within / sig2 + n * (x_bar - mu0)**2 / (sig2 + n * tau2)
    logp_per_dim = -0.5 * (n * np.log(2 * np.pi) + logdet + quad)
    return float(np.sum(logp_per_dim))


def compute_true_log_bfs(test_data, reference=0):
    x_batch = np.asarray(test_data["x"], dtype=np.float64)
    num_models = len(PRIOR_PARAMS)
    log_ml = np.empty((x_batch.shape[0], num_models), dtype=np.float64)

    for k, (mu0, tau) in enumerate(PRIOR_PARAMS):
        sigma = LIKELIHOOD_STDS[k]
        for b, x in enumerate(x_batch):
            log_ml[b, k] = log_marginal_likelihood(x, mu0, tau, sigma)

    competing = [k for k in range(num_models) if k != reference]
    return log_ml[:, competing] - log_ml[:, [reference]]

# %%
workflow = bf.ModelComparisonWorkflow(
    simulator=simulators,
    summary_variables="x",
    summary_network=bf.networks.DeepSet(summary_dim = 12),
    scoring_rules="exponential",
    initial_learning_rate=1e-3
)

# %%
val_data = workflow.simulate(1000)

# %%
history = workflow.fit_online(epochs=200, num_batches_per_epoch=64, batch_size=256, validation_data=val_data)
# Out:
# INFO:bayesflow:Fitting on dataset instance of OnlineDataset.
# INFO:bayesflow:Building on a test batch.
# Epoch 1/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 9s 44ms/step - ScoringRuleNetwork/scoring_rule: 1.6297 - loss: 1.6297 - val_ScoringRuleNetwork/scoring_rule: 0.8884 - val_loss: 0.8884
# Epoch 2/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - ScoringRuleNetwork/scoring_rule: 0.7020 - loss: 0.7020 - val_ScoringRuleNetwork/scoring_rule: 0.5560 - val_loss: 0.5560
# Epoch 3/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - ScoringRuleNetwork/scoring_rule: 0.5506 - loss: 0.5506 - val_ScoringRuleNetwork/scoring_rule: 0.5272 - val_loss: 0.5272
# Epoch 4/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - ScoringRuleNetwork/scoring_rule: 0.5146 - loss: 0.5146 - val_ScoringRuleNetwork/scoring_rule: 0.5211 - val_loss: 0.5211
# Epoch 5/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - ScoringRuleNetwork/scoring_rule: 0.5273 - loss: 0.5273 - val_ScoringRuleNetwork/scoring_rule: 0.5213 - val_loss: 0.5213
# Epoch 6/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - ScoringRuleNetwork/scoring_rule: 0.5074 - loss: 0.5074 - val_ScoringRuleNetwork/scoring_rule: 0.5042 - val_loss: 0.5042
# Epoch 7/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - ScoringRuleNetwork/scoring_rule: 0.5079 - loss: 0.5079 - val_ScoringRuleNetwork/scoring_rule: 0.5025 - val_loss: 0.5025
# Epoch 8/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - ScoringRuleNetwork/scoring_rule: 0.4941 - loss: 0.4941 - val_ScoringRuleNetwork/scoring_rule: 0.5122 - val_loss: 0.5122
# Epoch 9/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - ScoringRuleNetwork/scoring_rule: 0.5035 - loss: 0.5035 - val_ScoringRuleNetwork/scoring_rule: 0.5056 - val_loss: 0.5056
# Epoch 10/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - ScoringRuleNetwork/scoring_rule: 0.4990 - loss: 0.4990 - val_ScoringRuleNetwork/scoring_rule: 0.5099 - val_loss: 0.5099
# Epoch 11/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - ScoringRuleNetwork/scoring_rule: 0.4957 - loss: 0.4957 - val_ScoringRuleNetwork/scoring_rule: 0.5040 - val_loss: 0.5040
# Epoch 12/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - ScoringRuleNetwork/scoring_rule: 0.5254 - loss: 0.5254 - val_ScoringRuleNetwork/scoring_rule: 0.9654 - val_loss: 0.9654
# Epoch 13/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - ScoringRuleNetwork/scoring_rule: 0.5089 - loss: 0.5089 - val_ScoringRuleNetwork/scoring_rule: 0.5034 - val_loss: 0.5034
# Epoch 14/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - ScoringRuleNetwork/scoring_rule: 0.4993 - loss: 0.4993 - val_ScoringRuleNetwork/scoring_rule: 0.5020 - val_loss: 0.5020
# Epoch 15/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - ScoringRuleNetwork/scoring_rule: 0.4937 - loss: 0.4937 - val_ScoringRuleNetwork/scoring_rule: 0.5049 - val_loss: 0.5049
# Epoch 16/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - ScoringRuleNetwork/scoring_rule: 0.4890 - loss: 0.4890 - val_ScoringRuleNetwork/scoring_rule: 0.5097 - val_loss: 0.5097
# Epoch 17/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - ScoringRuleNetwork/scoring_rule: 0.4905 - loss: 0.4905 - val_ScoringRuleNetwork/scoring_rule: 0.5007 - val_loss: 0.5007
# Epoch 18/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - ScoringRuleNetwork/scoring_rule: 0.4929 - loss: 0.4929 - val_ScoringRuleNetwork/scoring_rule: 0.5038 - val_loss: 0.5038
# Epoch 19/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - ScoringRuleNetwork/scoring_rule: 0.4942 - loss: 0.4942 - val_ScoringRuleNetwork/scoring_rule: 0.4995 - val_loss: 0.4995
# Epoch 20/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - ScoringRuleNetwork/scoring_rule: 0.4949 - loss: 0.4949 - val_ScoringRuleNetwork/scoring_rule: 0.5042 - val_loss: 0.5042
# Epoch 21/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - ScoringRuleNetwork/scoring_rule: 0.4921 - loss: 0.4921 - val_ScoringRuleNetwork/scoring_rule: 0.5027 - val_loss: 0.5027
# Epoch 22/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - ScoringRuleNetwork/scoring_rule: 0.4956 - loss: 0.4956 - val_ScoringRuleNetwork/scoring_rule: 0.5037 - val_loss: 0.5037
# Epoch 23/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - ScoringRuleNetwork/scoring_rule: 0.4912 - loss: 0.4912 - val_ScoringRuleNetwork/scoring_rule: 0.5003 - val_loss: 0.5003
# Epoch 24/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - ScoringRuleNetwork/scoring_rule: 0.4947 - loss: 0.4947 - val_ScoringRuleNetwork/scoring_rule: 0.4991 - val_loss: 0.4991
# Epoch 25/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - ScoringRuleNetwork/scoring_rule: 0.5052 - loss: 0.5052 - val_ScoringRuleNetwork/scoring_rule: 0.5043 - val_loss: 0.5043
# Epoch 26/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - ScoringRuleNetwork/scoring_rule: 0.4954 - loss: 0.4954 - val_ScoringRuleNetwork/scoring_rule: 0.4991 - val_loss: 0.4991
# Epoch 27/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - ScoringRuleNetwork/scoring_rule: 0.4902 - loss: 0.4902 - val_ScoringRuleNetwork/scoring_rule: 0.5010 - val_loss: 0.5010
# Epoch 28/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - ScoringRuleNetwork/scoring_rule: 0.4934 - loss: 0.4934 - val_ScoringRuleNetwork/scoring_rule: 0.5030 - val_loss: 0.5030
# Epoch 29/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - ScoringRuleNetwork/scoring_rule: 0.5410 - loss: 0.5410 - val_ScoringRuleNetwork/scoring_rule: 0.5107 - val_loss: 0.5107
# Epoch 30/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - ScoringRuleNetwork/scoring_rule: 0.4950 - loss: 0.4950 - val_ScoringRuleNetwork/scoring_rule: 0.5010 - val_loss: 0.5010
# Epoch 31/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - ScoringRuleNetwork/scoring_rule: 0.4941 - loss: 0.4941 - val_ScoringRuleNetwork/scoring_rule: 0.5025 - val_loss: 0.5025
# Epoch 32/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - ScoringRuleNetwork/scoring_rule: 0.4950 - loss: 0.4950 - val_ScoringRuleNetwork/scoring_rule: 0.5021 - val_loss: 0.5021
# Epoch 33/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - ScoringRuleNetwork/scoring_rule: 0.4907 - loss: 0.4907 - val_ScoringRuleNetwork/scoring_rule: 0.5027 - val_loss: 0.5027
# Epoch 34/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - ScoringRuleNetwork/scoring_rule: 0.5000 - loss: 0.5000 - val_ScoringRuleNetwork/scoring_rule: 0.5008 - val_loss: 0.5008
# Epoch 35/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - ScoringRuleNetwork/scoring_rule: 0.4968 - loss: 0.4968 - val_ScoringRuleNetwork/scoring_rule: 0.5025 - val_loss: 0.5025
# Epoch 36/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - ScoringRuleNetwork/scoring_rule: 0.4929 - loss: 0.4929 - val_ScoringRuleNetwork/scoring_rule: 0.5013 - val_loss: 0.5013
# Epoch 37/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - ScoringRuleNetwork/scoring_rule: 0.4926 - loss: 0.4926 - val_ScoringRuleNetwork/scoring_rule: 0.5017 - val_loss: 0.5017
# Epoch 38/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - ScoringRuleNetwork/scoring_rule: 0.5151 - loss: 0.5151 - val_ScoringRuleNetwork/scoring_rule: 0.5194 - val_loss: 0.5194
# Epoch 39/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - ScoringRuleNetwork/scoring_rule: 0.5005 - loss: 0.5005 - val_ScoringRuleNetwork/scoring_rule: 0.5006 - val_loss: 0.5006
# Epoch 40/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - ScoringRuleNetwork/scoring_rule: 0.4953 - loss: 0.4953 - val_ScoringRuleNetwork/scoring_rule: 0.4989 - val_loss: 0.4989
# Epoch 41/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - ScoringRuleNetwork/scoring_rule: 0.4927 - loss: 0.4927 - val_ScoringRuleNetwork/scoring_rule: 0.5058 - val_loss: 0.5058
# Epoch 42/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - ScoringRuleNetwork/scoring_rule: 0.4924 - loss: 0.4924 - val_ScoringRuleNetwork/scoring_rule: 0.5009 - val_loss: 0.5009
# Epoch 43/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - ScoringRuleNetwork/scoring_rule: 0.4902 - loss: 0.4902 - val_ScoringRuleNetwork/scoring_rule: 0.5004 - val_loss: 0.5004
# Epoch 44/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - ScoringRuleNetwork/scoring_rule: 0.4951 - loss: 0.4951 - val_ScoringRuleNetwork/scoring_rule: 0.5025 - val_loss: 0.5025
# Epoch 45/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - ScoringRuleNetwork/scoring_rule: 0.4905 - loss: 0.4905 - val_ScoringRuleNetwork/scoring_rule: 0.4994 - val_loss: 0.4994
# Epoch 46/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - ScoringRuleNetwork/scoring_rule: 0.4893 - loss: 0.4893 - val_ScoringRuleNetwork/scoring_rule: 0.5030 - val_loss: 0.5030
# Epoch 47/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - ScoringRuleNetwork/scoring_rule: 0.4865 - loss: 0.4865 - val_ScoringRuleNetwork/scoring_rule: 0.4999 - val_loss: 0.4999
# Epoch 48/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - ScoringRuleNetwork/scoring_rule: 0.4923 - loss: 0.4923 - val_ScoringRuleNetwork/scoring_rule: 0.5009 - val_loss: 0.5009
# Epoch 49/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - ScoringRuleNetwork/scoring_rule: 0.4902 - loss: 0.4902 - val_ScoringRuleNetwork/scoring_rule: 0.5094 - val_loss: 0.5094
# Epoch 50/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - ScoringRuleNetwork/scoring_rule: 0.4872 - loss: 0.4872 - val_ScoringRuleNetwork/scoring_rule: 0.4992 - val_loss: 0.4992
# Epoch 51/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - ScoringRuleNetwork/scoring_rule: 0.4922 - loss: 0.4922 - val_ScoringRuleNetwork/scoring_rule: 0.5000 - val_loss: 0.5000
# Epoch 52/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - ScoringRuleNetwork/scoring_rule: 0.4988 - loss: 0.4988 - val_ScoringRuleNetwork/scoring_rule: 0.5014 - val_loss: 0.5014
# Epoch 53/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - ScoringRuleNetwork/scoring_rule: 0.4934 - loss: 0.4934 - val_ScoringRuleNetwork/scoring_rule: 0.5045 - val_loss: 0.5045
# Epoch 54/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - ScoringRuleNetwork/scoring_rule: 0.4983 - loss: 0.4983 - val_ScoringRuleNetwork/scoring_rule: 0.5032 - val_loss: 0.5032
# Epoch 55/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - ScoringRuleNetwork/scoring_rule: 0.4918 - loss: 0.4918 - val_ScoringRuleNetwork/scoring_rule: 0.5078 - val_loss: 0.5078
# Epoch 56/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - ScoringRuleNetwork/scoring_rule: 0.5027 - loss: 0.5027 - val_ScoringRuleNetwork/scoring_rule: 0.5017 - val_loss: 0.5017
# Epoch 57/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - ScoringRuleNetwork/scoring_rule: 0.4886 - loss: 0.4886 - val_ScoringRuleNetwork/scoring_rule: 0.5061 - val_loss: 0.5061
# Epoch 58/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - ScoringRuleNetwork/scoring_rule: 0.5007 - loss: 0.5007 - val_ScoringRuleNetwork/scoring_rule: 0.5004 - val_loss: 0.5004
# Epoch 59/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - ScoringRuleNetwork/scoring_rule: 0.4873 - loss: 0.4873 - val_ScoringRuleNetwork/scoring_rule: 0.5004 - val_loss: 0.5004
# Epoch 60/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - ScoringRuleNetwork/scoring_rule: 0.4871 - loss: 0.4871 - val_ScoringRuleNetwork/scoring_rule: 0.5018 - val_loss: 0.5018
# Epoch 61/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - ScoringRuleNetwork/scoring_rule: 0.4874 - loss: 0.4874 - val_ScoringRuleNetwork/scoring_rule: 0.5016 - val_loss: 0.5016
# Epoch 62/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - ScoringRuleNetwork/scoring_rule: 0.4901 - loss: 0.4901 - val_ScoringRuleNetwork/scoring_rule: 0.4997 - val_loss: 0.4997
# Epoch 63/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - ScoringRuleNetwork/scoring_rule: 0.4937 - loss: 0.4937 - val_ScoringRuleNetwork/scoring_rule: 0.5186 - val_loss: 0.5186
# Epoch 64/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - ScoringRuleNetwork/scoring_rule: 0.4968 - loss: 0.4968 - val_ScoringRuleNetwork/scoring_rule: 0.5007 - val_loss: 0.5007
# Epoch 65/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - ScoringRuleNetwork/scoring_rule: 0.4913 - loss: 0.4913 - val_ScoringRuleNetwork/scoring_rule: 0.5023 - val_loss: 0.5023
# Epoch 66/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - ScoringRuleNetwork/scoring_rule: 0.4900 - loss: 0.4900 - val_ScoringRuleNetwork/scoring_rule: 0.4997 - val_loss: 0.4997
# Epoch 67/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - ScoringRuleNetwork/scoring_rule: 0.4888 - loss: 0.4888 - val_ScoringRuleNetwork/scoring_rule: 0.4998 - val_loss: 0.4998
# Epoch 68/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - ScoringRuleNetwork/scoring_rule: 0.4901 - loss: 0.4901 - val_ScoringRuleNetwork/scoring_rule: 0.5010 - val_loss: 0.5010
# Epoch 69/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - ScoringRuleNetwork/scoring_rule: 0.4875 - loss: 0.4875 - val_ScoringRuleNetwork/scoring_rule: 0.5074 - val_loss: 0.5074
# Epoch 70/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - ScoringRuleNetwork/scoring_rule: 0.4863 - loss: 0.4863 - val_ScoringRuleNetwork/scoring_rule: 0.5005 - val_loss: 0.5005
# Epoch 71/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - ScoringRuleNetwork/scoring_rule: 0.9279 - loss: 0.9279 - val_ScoringRuleNetwork/scoring_rule: 0.5189 - val_loss: 0.5189
# Epoch 72/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - ScoringRuleNetwork/scoring_rule: 0.5163 - loss: 0.5163 - val_ScoringRuleNetwork/scoring_rule: 0.5205 - val_loss: 0.5205
# Epoch 73/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - ScoringRuleNetwork/scoring_rule: 0.5044 - loss: 0.5044 - val_ScoringRuleNetwork/scoring_rule: 0.5018 - val_loss: 0.5018
# Epoch 74/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - ScoringRuleNetwork/scoring_rule: 0.4907 - loss: 0.4907 - val_ScoringRuleNetwork/scoring_rule: 0.5025 - val_loss: 0.5025
# Epoch 75/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - ScoringRuleNetwork/scoring_rule: 0.4963 - loss: 0.4963 - val_ScoringRuleNetwork/scoring_rule: 0.5005 - val_loss: 0.5005
# Epoch 76/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - ScoringRuleNetwork/scoring_rule: 0.4862 - loss: 0.4862 - val_ScoringRuleNetwork/scoring_rule: 0.5086 - val_loss: 0.5086
# Epoch 77/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - ScoringRuleNetwork/scoring_rule: 0.4870 - loss: 0.4870 - val_ScoringRuleNetwork/scoring_rule: 0.5032 - val_loss: 0.5032
# Epoch 78/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - ScoringRuleNetwork/scoring_rule: 0.4942 - loss: 0.4942 - val_ScoringRuleNetwork/scoring_rule: 0.4988 - val_loss: 0.4988
# Epoch 79/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - ScoringRuleNetwork/scoring_rule: 0.4928 - loss: 0.4928 - val_ScoringRuleNetwork/scoring_rule: 0.4994 - val_loss: 0.4994
# Epoch 80/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - ScoringRuleNetwork/scoring_rule: 0.4877 - loss: 0.4877 - val_ScoringRuleNetwork/scoring_rule: 0.5027 - val_loss: 0.5027
# Epoch 81/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - ScoringRuleNetwork/scoring_rule: 0.4943 - loss: 0.4943 - val_ScoringRuleNetwork/scoring_rule: 0.5006 - val_loss: 0.5006
# Epoch 82/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - ScoringRuleNetwork/scoring_rule: 0.4914 - loss: 0.4914 - val_ScoringRuleNetwork/scoring_rule: 0.5001 - val_loss: 0.5001
# Epoch 83/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - ScoringRuleNetwork/scoring_rule: 0.4859 - loss: 0.4859 - val_ScoringRuleNetwork/scoring_rule: 0.4988 - val_loss: 0.4988
# Epoch 84/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - ScoringRuleNetwork/scoring_rule: 0.4922 - loss: 0.4922 - val_ScoringRuleNetwork/scoring_rule: 0.5013 - val_loss: 0.5013
# Epoch 85/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - ScoringRuleNetwork/scoring_rule: 0.4894 - loss: 0.4894 - val_ScoringRuleNetwork/scoring_rule: 0.5049 - val_loss: 0.5049
# Epoch 86/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - ScoringRuleNetwork/scoring_rule: 0.4883 - loss: 0.4883 - val_ScoringRuleNetwork/scoring_rule: 0.4993 - val_loss: 0.4993
# Epoch 87/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - ScoringRuleNetwork/scoring_rule: 0.4919 - loss: 0.4919 - val_ScoringRuleNetwork/scoring_rule: 0.5026 - val_loss: 0.5026
# Epoch 88/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - ScoringRuleNetwork/scoring_rule: 0.4933 - loss: 0.4933 - val_ScoringRuleNetwork/scoring_rule: 0.4996 - val_loss: 0.4996
# Epoch 89/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - ScoringRuleNetwork/scoring_rule: 0.4911 - loss: 0.4911 - val_ScoringRuleNetwork/scoring_rule: 0.4992 - val_loss: 0.4992
# Epoch 90/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - ScoringRuleNetwork/scoring_rule: 0.4908 - loss: 0.4908 - val_ScoringRuleNetwork/scoring_rule: 0.4998 - val_loss: 0.4998
# Epoch 91/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - ScoringRuleNetwork/scoring_rule: 0.5018 - loss: 0.5018 - val_ScoringRuleNetwork/scoring_rule: 0.5001 - val_loss: 0.5001
# Epoch 92/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - ScoringRuleNetwork/scoring_rule: 0.4934 - loss: 0.4934 - val_ScoringRuleNetwork/scoring_rule: 0.5005 - val_loss: 0.5005
# Epoch 93/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - ScoringRuleNetwork/scoring_rule: 0.4910 - loss: 0.4910 - val_ScoringRuleNetwork/scoring_rule: 0.5020 - val_loss: 0.5020
# Epoch 94/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - ScoringRuleNetwork/scoring_rule: 0.4918 - loss: 0.4918 - val_ScoringRuleNetwork/scoring_rule: 0.4993 - val_loss: 0.4993
# Epoch 95/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - ScoringRuleNetwork/scoring_rule: 0.4879 - loss: 0.4879 - val_ScoringRuleNetwork/scoring_rule: 0.4998 - val_loss: 0.4998
# Epoch 96/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - ScoringRuleNetwork/scoring_rule: 0.4907 - loss: 0.4907 - val_ScoringRuleNetwork/scoring_rule: 0.5040 - val_loss: 0.5040
# Epoch 97/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - ScoringRuleNetwork/scoring_rule: 0.4957 - loss: 0.4957 - val_ScoringRuleNetwork/scoring_rule: 0.5003 - val_loss: 0.5003
# Epoch 98/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - ScoringRuleNetwork/scoring_rule: 0.4882 - loss: 0.4882 - val_ScoringRuleNetwork/scoring_rule: 0.5046 - val_loss: 0.5046
# Epoch 99/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - ScoringRuleNetwork/scoring_rule: 0.4938 - loss: 0.4938 - val_ScoringRuleNetwork/scoring_rule: 0.4994 - val_loss: 0.4994
# Epoch 100/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - ScoringRuleNetwork/scoring_rule: 0.4853 - loss: 0.4853 - val_ScoringRuleNetwork/scoring_rule: 0.5008 - val_loss: 0.5008
# Epoch 101/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - ScoringRuleNetwork/scoring_rule: 0.4932 - loss: 0.4932 - val_ScoringRuleNetwork/scoring_rule: 0.4990 - val_loss: 0.4990
# Epoch 102/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - ScoringRuleNetwork/scoring_rule: 0.4887 - loss: 0.4887 - val_ScoringRuleNetwork/scoring_rule: 0.4991 - val_loss: 0.4991
# Epoch 103/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - ScoringRuleNetwork/scoring_rule: 0.4909 - loss: 0.4909 - val_ScoringRuleNetwork/scoring_rule: 0.4999 - val_loss: 0.4999
# Epoch 104/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - ScoringRuleNetwork/scoring_rule: 0.4930 - loss: 0.4930 - val_ScoringRuleNetwork/scoring_rule: 0.5012 - val_loss: 0.5012
# Epoch 105/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - ScoringRuleNetwork/scoring_rule: 0.4834 - loss: 0.4834 - val_ScoringRuleNetwork/scoring_rule: 0.4999 - val_loss: 0.4999
# Epoch 106/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - ScoringRuleNetwork/scoring_rule: 0.4940 - loss: 0.4940 - val_ScoringRuleNetwork/scoring_rule: 0.4996 - val_loss: 0.4996
# Epoch 107/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - ScoringRuleNetwork/scoring_rule: 0.4872 - loss: 0.4872 - val_ScoringRuleNetwork/scoring_rule: 0.5004 - val_loss: 0.5004
# Epoch 108/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - ScoringRuleNetwork/scoring_rule: 0.4967 - loss: 0.4967 - val_ScoringRuleNetwork/scoring_rule: 0.4997 - val_loss: 0.4997
# Epoch 109/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - ScoringRuleNetwork/scoring_rule: 0.4832 - loss: 0.4832 - val_ScoringRuleNetwork/scoring_rule: 0.5028 - val_loss: 0.5028
# Epoch 110/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - ScoringRuleNetwork/scoring_rule: 0.4843 - loss: 0.4843 - val_ScoringRuleNetwork/scoring_rule: 0.5006 - val_loss: 0.5006
# Epoch 111/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - ScoringRuleNetwork/scoring_rule: 0.4895 - loss: 0.4895 - val_ScoringRuleNetwork/scoring_rule: 0.4993 - val_loss: 0.4993
# Epoch 112/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - ScoringRuleNetwork/scoring_rule: 0.4908 - loss: 0.4908 - val_ScoringRuleNetwork/scoring_rule: 0.4995 - val_loss: 0.4995
# Epoch 113/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - ScoringRuleNetwork/scoring_rule: 0.4849 - loss: 0.4849 - val_ScoringRuleNetwork/scoring_rule: 0.4997 - val_loss: 0.4997
# Epoch 114/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - ScoringRuleNetwork/scoring_rule: 0.5192 - loss: 0.5192 - val_ScoringRuleNetwork/scoring_rule: 0.4994 - val_loss: 0.4994
# Epoch 115/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - ScoringRuleNetwork/scoring_rule: 0.4962 - loss: 0.4962 - val_ScoringRuleNetwork/scoring_rule: 0.5011 - val_loss: 0.5011
# Epoch 116/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - ScoringRuleNetwork/scoring_rule: 0.4884 - loss: 0.4884 - val_ScoringRuleNetwork/scoring_rule: 0.5043 - val_loss: 0.5043
# Epoch 117/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - ScoringRuleNetwork/scoring_rule: 0.4899 - loss: 0.4899 - val_ScoringRuleNetwork/scoring_rule: 0.5006 - val_loss: 0.5006
# Epoch 118/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - ScoringRuleNetwork/scoring_rule: 0.4891 - loss: 0.4891 - val_ScoringRuleNetwork/scoring_rule: 0.5000 - val_loss: 0.5000
# Epoch 119/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - ScoringRuleNetwork/scoring_rule: 0.4860 - loss: 0.4860 - val_ScoringRuleNetwork/scoring_rule: 0.5009 - val_loss: 0.5009
# Epoch 120/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - ScoringRuleNetwork/scoring_rule: 0.4892 - loss: 0.4892 - val_ScoringRuleNetwork/scoring_rule: 0.5008 - val_loss: 0.5008
# Epoch 121/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - ScoringRuleNetwork/scoring_rule: 0.4889 - loss: 0.4889 - val_ScoringRuleNetwork/scoring_rule: 0.4996 - val_loss: 0.4996
# Epoch 122/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - ScoringRuleNetwork/scoring_rule: 0.4941 - loss: 0.4941 - val_ScoringRuleNetwork/scoring_rule: 0.4998 - val_loss: 0.4998
# Epoch 123/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - ScoringRuleNetwork/scoring_rule: 0.4833 - loss: 0.4833 - val_ScoringRuleNetwork/scoring_rule: 0.4996 - val_loss: 0.4996
# Epoch 124/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - ScoringRuleNetwork/scoring_rule: 0.4868 - loss: 0.4868 - val_ScoringRuleNetwork/scoring_rule: 0.5000 - val_loss: 0.5000
# Epoch 125/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - ScoringRuleNetwork/scoring_rule: 0.4892 - loss: 0.4892 - val_ScoringRuleNetwork/scoring_rule: 0.4997 - val_loss: 0.4997
# Epoch 126/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - ScoringRuleNetwork/scoring_rule: 0.4955 - loss: 0.4955 - val_ScoringRuleNetwork/scoring_rule: 0.4997 - val_loss: 0.4997
# Epoch 127/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - ScoringRuleNetwork/scoring_rule: 0.4901 - loss: 0.4901 - val_ScoringRuleNetwork/scoring_rule: 0.4996 - val_loss: 0.4996
# Epoch 128/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - ScoringRuleNetwork/scoring_rule: 0.4903 - loss: 0.4903 - val_ScoringRuleNetwork/scoring_rule: 0.5012 - val_loss: 0.5012
# Epoch 129/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - ScoringRuleNetwork/scoring_rule: 0.4884 - loss: 0.4884 - val_ScoringRuleNetwork/scoring_rule: 0.4997 - val_loss: 0.4997
# Epoch 130/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - ScoringRuleNetwork/scoring_rule: 0.4914 - loss: 0.4914 - val_ScoringRuleNetwork/scoring_rule: 0.4999 - val_loss: 0.4999
# Epoch 131/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - ScoringRuleNetwork/scoring_rule: 0.4858 - loss: 0.4858 - val_ScoringRuleNetwork/scoring_rule: 0.4998 - val_loss: 0.4998
# Epoch 132/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - ScoringRuleNetwork/scoring_rule: 0.4848 - loss: 0.4848 - val_ScoringRuleNetwork/scoring_rule: 0.4995 - val_loss: 0.4995
# Epoch 133/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - ScoringRuleNetwork/scoring_rule: 0.4854 - loss: 0.4854 - val_ScoringRuleNetwork/scoring_rule: 0.5011 - val_loss: 0.5011
# Epoch 134/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - ScoringRuleNetwork/scoring_rule: 0.4892 - loss: 0.4892 - val_ScoringRuleNetwork/scoring_rule: 0.5006 - val_loss: 0.5006
# Epoch 135/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - ScoringRuleNetwork/scoring_rule: 0.4864 - loss: 0.4864 - val_ScoringRuleNetwork/scoring_rule: 0.5009 - val_loss: 0.5009
# Epoch 136/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - ScoringRuleNetwork/scoring_rule: 0.4860 - loss: 0.4860 - val_ScoringRuleNetwork/scoring_rule: 0.5000 - val_loss: 0.5000
# Epoch 137/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - ScoringRuleNetwork/scoring_rule: 0.4787 - loss: 0.4787 - val_ScoringRuleNetwork/scoring_rule: 0.5003 - val_loss: 0.5003
# Epoch 138/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - ScoringRuleNetwork/scoring_rule: 0.4940 - loss: 0.4940 - val_ScoringRuleNetwork/scoring_rule: 0.4993 - val_loss: 0.4993
# Epoch 139/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - ScoringRuleNetwork/scoring_rule: 0.4892 - loss: 0.4892 - val_ScoringRuleNetwork/scoring_rule: 0.4998 - val_loss: 0.4998
# Epoch 140/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - ScoringRuleNetwork/scoring_rule: 0.4928 - loss: 0.4928 - val_ScoringRuleNetwork/scoring_rule: 0.4997 - val_loss: 0.4997
# Epoch 141/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - ScoringRuleNetwork/scoring_rule: 0.4910 - loss: 0.4910 - val_ScoringRuleNetwork/scoring_rule: 0.5002 - val_loss: 0.5002
# Epoch 142/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - ScoringRuleNetwork/scoring_rule: 0.4867 - loss: 0.4867 - val_ScoringRuleNetwork/scoring_rule: 0.4994 - val_loss: 0.4994
# Epoch 143/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - ScoringRuleNetwork/scoring_rule: 0.4883 - loss: 0.4883 - val_ScoringRuleNetwork/scoring_rule: 0.4992 - val_loss: 0.4992
# Epoch 144/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - ScoringRuleNetwork/scoring_rule: 0.4932 - loss: 0.4932 - val_ScoringRuleNetwork/scoring_rule: 0.5000 - val_loss: 0.5000
# Epoch 145/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - ScoringRuleNetwork/scoring_rule: 0.4853 - loss: 0.4853 - val_ScoringRuleNetwork/scoring_rule: 0.5012 - val_loss: 0.5012
# Epoch 146/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - ScoringRuleNetwork/scoring_rule: 0.4954 - loss: 0.4954 - val_ScoringRuleNetwork/scoring_rule: 0.5024 - val_loss: 0.5024
# Epoch 147/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - ScoringRuleNetwork/scoring_rule: 0.4900 - loss: 0.4900 - val_ScoringRuleNetwork/scoring_rule: 0.4990 - val_loss: 0.4990
# Epoch 148/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - ScoringRuleNetwork/scoring_rule: 0.4863 - loss: 0.4863 - val_ScoringRuleNetwork/scoring_rule: 0.5002 - val_loss: 0.5002
# Epoch 149/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - ScoringRuleNetwork/scoring_rule: 0.4906 - loss: 0.4906 - val_ScoringRuleNetwork/scoring_rule: 0.4995 - val_loss: 0.4995
# Epoch 150/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - ScoringRuleNetwork/scoring_rule: 0.4877 - loss: 0.4877 - val_ScoringRuleNetwork/scoring_rule: 0.4994 - val_loss: 0.4994
# Epoch 151/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - ScoringRuleNetwork/scoring_rule: 0.4893 - loss: 0.4893 - val_ScoringRuleNetwork/scoring_rule: 0.5005 - val_loss: 0.5005
# Epoch 152/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - ScoringRuleNetwork/scoring_rule: 0.4867 - loss: 0.4867 - val_ScoringRuleNetwork/scoring_rule: 0.4991 - val_loss: 0.4991
# Epoch 153/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - ScoringRuleNetwork/scoring_rule: 0.4880 - loss: 0.4880 - val_ScoringRuleNetwork/scoring_rule: 0.5011 - val_loss: 0.5011
# Epoch 154/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - ScoringRuleNetwork/scoring_rule: 0.4850 - loss: 0.4850 - val_ScoringRuleNetwork/scoring_rule: 0.4995 - val_loss: 0.4995
# Epoch 155/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - ScoringRuleNetwork/scoring_rule: 0.4899 - loss: 0.4899 - val_ScoringRuleNetwork/scoring_rule: 0.5002 - val_loss: 0.5002
# Epoch 156/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - ScoringRuleNetwork/scoring_rule: 0.4920 - loss: 0.4920 - val_ScoringRuleNetwork/scoring_rule: 0.5012 - val_loss: 0.5012
# Epoch 157/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - ScoringRuleNetwork/scoring_rule: 0.4953 - loss: 0.4953 - val_ScoringRuleNetwork/scoring_rule: 0.5000 - val_loss: 0.5000
# Epoch 158/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - ScoringRuleNetwork/scoring_rule: 0.4864 - loss: 0.4864 - val_ScoringRuleNetwork/scoring_rule: 0.4997 - val_loss: 0.4997
# Epoch 159/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - ScoringRuleNetwork/scoring_rule: 0.4908 - loss: 0.4908 - val_ScoringRuleNetwork/scoring_rule: 0.5056 - val_loss: 0.5056
# Epoch 160/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - ScoringRuleNetwork/scoring_rule: 0.4953 - loss: 0.4953 - val_ScoringRuleNetwork/scoring_rule: 0.4999 - val_loss: 0.4999
# Epoch 161/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - ScoringRuleNetwork/scoring_rule: 0.4881 - loss: 0.4881 - val_ScoringRuleNetwork/scoring_rule: 0.5011 - val_loss: 0.5011
# Epoch 162/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - ScoringRuleNetwork/scoring_rule: 0.4875 - loss: 0.4875 - val_ScoringRuleNetwork/scoring_rule: 0.4996 - val_loss: 0.4996
# Epoch 163/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - ScoringRuleNetwork/scoring_rule: 0.4839 - loss: 0.4839 - val_ScoringRuleNetwork/scoring_rule: 0.5003 - val_loss: 0.5003
# Epoch 164/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - ScoringRuleNetwork/scoring_rule: 0.4921 - loss: 0.4921 - val_ScoringRuleNetwork/scoring_rule: 0.4994 - val_loss: 0.4994
# Epoch 165/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - ScoringRuleNetwork/scoring_rule: 0.5001 - loss: 0.5001 - val_ScoringRuleNetwork/scoring_rule: 0.5011 - val_loss: 0.5011
# Epoch 166/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - ScoringRuleNetwork/scoring_rule: 0.4868 - loss: 0.4868 - val_ScoringRuleNetwork/scoring_rule: 0.4998 - val_loss: 0.4998
# Epoch 167/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - ScoringRuleNetwork/scoring_rule: 0.4902 - loss: 0.4902 - val_ScoringRuleNetwork/scoring_rule: 0.5001 - val_loss: 0.5001
# Epoch 168/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - ScoringRuleNetwork/scoring_rule: 0.4917 - loss: 0.4917 - val_ScoringRuleNetwork/scoring_rule: 0.5003 - val_loss: 0.5003
# Epoch 169/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - ScoringRuleNetwork/scoring_rule: 0.4873 - loss: 0.4873 - val_ScoringRuleNetwork/scoring_rule: 0.4998 - val_loss: 0.4998
# Epoch 170/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - ScoringRuleNetwork/scoring_rule: 0.4909 - loss: 0.4909 - val_ScoringRuleNetwork/scoring_rule: 0.5003 - val_loss: 0.5003
# Epoch 171/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - ScoringRuleNetwork/scoring_rule: 0.4876 - loss: 0.4876 - val_ScoringRuleNetwork/scoring_rule: 0.5006 - val_loss: 0.5006
# Epoch 172/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - ScoringRuleNetwork/scoring_rule: 0.4912 - loss: 0.4912 - val_ScoringRuleNetwork/scoring_rule: 0.4994 - val_loss: 0.4994
# Epoch 173/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - ScoringRuleNetwork/scoring_rule: 0.4920 - loss: 0.4920 - val_ScoringRuleNetwork/scoring_rule: 0.4996 - val_loss: 0.4996
# Epoch 174/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - ScoringRuleNetwork/scoring_rule: 0.4941 - loss: 0.4941 - val_ScoringRuleNetwork/scoring_rule: 0.4997 - val_loss: 0.4997
# Epoch 175/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - ScoringRuleNetwork/scoring_rule: 0.4882 - loss: 0.4882 - val_ScoringRuleNetwork/scoring_rule: 0.4999 - val_loss: 0.4999
# Epoch 176/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - ScoringRuleNetwork/scoring_rule: 0.4918 - loss: 0.4918 - val_ScoringRuleNetwork/scoring_rule: 0.5003 - val_loss: 0.5003
# Epoch 177/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - ScoringRuleNetwork/scoring_rule: 0.4871 - loss: 0.4871 - val_ScoringRuleNetwork/scoring_rule: 0.5003 - val_loss: 0.5003
# Epoch 178/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - ScoringRuleNetwork/scoring_rule: 0.4935 - loss: 0.4935 - val_ScoringRuleNetwork/scoring_rule: 0.4997 - val_loss: 0.4997
# Epoch 179/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - ScoringRuleNetwork/scoring_rule: 0.4881 - loss: 0.4881 - val_ScoringRuleNetwork/scoring_rule: 0.4996 - val_loss: 0.4996
# Epoch 180/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - ScoringRuleNetwork/scoring_rule: 0.4885 - loss: 0.4885 - val_ScoringRuleNetwork/scoring_rule: 0.5002 - val_loss: 0.5002
# Epoch 181/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - ScoringRuleNetwork/scoring_rule: 0.4866 - loss: 0.4866 - val_ScoringRuleNetwork/scoring_rule: 0.5001 - val_loss: 0.5001
# Epoch 182/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - ScoringRuleNetwork/scoring_rule: 0.4877 - loss: 0.4877 - val_ScoringRuleNetwork/scoring_rule: 0.4994 - val_loss: 0.4994
# Epoch 183/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - ScoringRuleNetwork/scoring_rule: 0.4887 - loss: 0.4887 - val_ScoringRuleNetwork/scoring_rule: 0.4996 - val_loss: 0.4996
# Epoch 184/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - ScoringRuleNetwork/scoring_rule: 0.4842 - loss: 0.4842 - val_ScoringRuleNetwork/scoring_rule: 0.5004 - val_loss: 0.5004
# Epoch 185/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - ScoringRuleNetwork/scoring_rule: 0.4880 - loss: 0.4880 - val_ScoringRuleNetwork/scoring_rule: 0.4996 - val_loss: 0.4996
# Epoch 186/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - ScoringRuleNetwork/scoring_rule: 0.4843 - loss: 0.4843 - val_ScoringRuleNetwork/scoring_rule: 0.4998 - val_loss: 0.4998
# Epoch 187/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - ScoringRuleNetwork/scoring_rule: 0.4871 - loss: 0.4871 - val_ScoringRuleNetwork/scoring_rule: 0.4996 - val_loss: 0.4996
# Epoch 188/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - ScoringRuleNetwork/scoring_rule: 0.4843 - loss: 0.4843 - val_ScoringRuleNetwork/scoring_rule: 0.4997 - val_loss: 0.4997
# Epoch 189/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - ScoringRuleNetwork/scoring_rule: 0.4873 - loss: 0.4873 - val_ScoringRuleNetwork/scoring_rule: 0.4999 - val_loss: 0.4999
# Epoch 190/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - ScoringRuleNetwork/scoring_rule: 0.4890 - loss: 0.4890 - val_ScoringRuleNetwork/scoring_rule: 0.4996 - val_loss: 0.4996
# Epoch 191/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - ScoringRuleNetwork/scoring_rule: 0.4945 - loss: 0.4945 - val_ScoringRuleNetwork/scoring_rule: 0.4997 - val_loss: 0.4997
# Epoch 192/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - ScoringRuleNetwork/scoring_rule: 0.4870 - loss: 0.4870 - val_ScoringRuleNetwork/scoring_rule: 0.4996 - val_loss: 0.4996
# Epoch 193/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - ScoringRuleNetwork/scoring_rule: 0.4854 - loss: 0.4854 - val_ScoringRuleNetwork/scoring_rule: 0.4996 - val_loss: 0.4996
# Epoch 194/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - ScoringRuleNetwork/scoring_rule: 0.4840 - loss: 0.4840 - val_ScoringRuleNetwork/scoring_rule: 0.4997 - val_loss: 0.4997
# Epoch 195/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - ScoringRuleNetwork/scoring_rule: 0.4959 - loss: 0.4959 - val_ScoringRuleNetwork/scoring_rule: 0.4998 - val_loss: 0.4998
# Epoch 196/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - ScoringRuleNetwork/scoring_rule: 0.4895 - loss: 0.4895 - val_ScoringRuleNetwork/scoring_rule: 0.4998 - val_loss: 0.4998
# Epoch 197/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - ScoringRuleNetwork/scoring_rule: 0.4888 - loss: 0.4888 - val_ScoringRuleNetwork/scoring_rule: 0.4998 - val_loss: 0.4998
# Epoch 198/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - ScoringRuleNetwork/scoring_rule: 0.4794 - loss: 0.4794 - val_ScoringRuleNetwork/scoring_rule: 0.4997 - val_loss: 0.4997
# Epoch 199/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - ScoringRuleNetwork/scoring_rule: 0.4956 - loss: 0.4956 - val_ScoringRuleNetwork/scoring_rule: 0.4997 - val_loss: 0.4997
# Epoch 200/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - ScoringRuleNetwork/scoring_rule: 0.4786 - loss: 0.4786 - val_ScoringRuleNetwork/scoring_rule: 0.4997 - val_loss: 0.4997
# INFO:bayesflow:Training completed in 12.64 minutes.

# %%
figures = workflow.plot_default_diagnostics(test_data=2000, true_log_bfs_fn=compute_true_log_bfs)
# Out:
# Summarizing:   0%|          | 0/1 [00:00<?, ?batch/s]
# INFO:bayesflow:Estimating completed in 0.15 seconds.

# %%
# Save the trained approximator
filepath = Path("/Users/yimingzang/Documents/Project/benchmark2/benchmark/examples/gaussian/networks/direct_exponential.keras")
filepath.parent.mkdir(exist_ok=True)
workflow.approximator.save(filepath=filepath)

# %%
# Indirect S=4D caches supply the shared observations and reference PMPs.
# Direct predictions have their own output root, independent of this input path.
RESULTS_DIR = Path(
    "/Users/yimingzang/Documents/Project/benchmark2/"
    "benchmark/examples/gaussian/results"
)
INDIRECT_DATASET_DIR = RESULTS_DIR / "ood_80d_10n" / "datasets"
DIRECT_RESULTS_DIR = RESULTS_DIR / "direct"

# %%
all_items = []

for source in SOURCE_MODELS:
    with open(INDIRECT_DATASET_DIR / f"{source}_logml_pmp.pkl", "rb") as f:
        items = pickle.load(f)

    for item in items:
        all_items.append((source, item))

x_batch = np.stack(
    [item["x"] for source, item in all_items],
    axis=0,
).astype(np.float32)

print(x_batch.shape)

# %%
estimates = workflow.estimate(
    conditions={"x": x_batch}
)

p_direct = np.asarray(
    estimates["model_probs"]
)

# %%
# Export all 600 predictions together with the matching gold / indirect PMPs.
# Run the two preceding data-loading and prediction cells before this cell.
import json
import pathlib
from datetime import datetime, timezone
from scipy.special import softmax

model_order = tuple(ASSUMED_MODELS)
assert model_order == ("m1", "m2", "m3", "m4")
assert len(all_items) == 600
assert x_batch.shape == (600, 10, 20)
np.testing.assert_array_equal(
    x_batch,
    np.stack([item["x"] for source, item in all_items]).astype(np.float32),
)

p_gold = softmax(np.array([
    [item[f"gold_log_marginal_{model}"] for model in model_order]
    for source, item in all_items
], dtype=np.float64), axis=1)
p_indirect = softmax(np.array([
    [item[f"npe_log_marginal_{model}"] for model in model_order]
    for source, item in all_items
], dtype=np.float64), axis=1)
p_direct = np.asarray(p_direct, dtype=np.float64)

for method, probabilities in {
    "gold": p_gold, "indirect": p_indirect, "direct": p_direct
}.items():
    assert probabilities.shape == (600, 4), method
    assert np.isfinite(probabilities).all(), method
    assert ((probabilities >= 0) & (probabilities <= 1)).all(), method
    np.testing.assert_allclose(probabilities.sum(axis=1), 1.0, rtol=0, atol=1e-6)

comparison = pd.DataFrame({
    "source_model": [source for source, item in all_items],
    "id": [int(item["id"]) for source, item in all_items],
})
assert not comparison.duplicated(["source_model", "id"]).any()
source_counts = comparison.groupby("source_model").size().reindex(SOURCE_MODELS)
assert source_counts.eq(50).all()

for j, model in enumerate(model_order):
    comparison[f"p_gold_{model}"] = p_gold[:, j]
    comparison[f"p_indirect_{model}"] = p_indirect[:, j]
    comparison[f"p_direct_{model}"] = p_direct[:, j]
comparison["l1_indirect"] = np.abs(p_indirect - p_gold).sum(axis=1)
comparison["l1_direct"] = np.abs(p_direct - p_gold).sum(axis=1)

COMPARISON_DIR = DIRECT_RESULTS_DIR / "direct_exponential"
COMPARISON_DIR.mkdir(parents=True, exist_ok=True)
CSV_PATH = COMPARISON_DIR / "pmp_comparison.csv"
comparison.to_csv(CSV_PATH, index=False)
metadata = {
    "created_at_utc": datetime.now(timezone.utc).isoformat(),
    "num_datasets": len(comparison),
    "input_shape": list(x_batch.shape),
    "model_order": list(model_order),
    "model_prior": [0.25] * 4,
    "source_counts": {source: int(count) for source, count in source_counts.items()},
    "loss_function": "exponential",
    "direct_checkpoint": str(filepath.resolve()),
    "direct_source": "p_direct from the preceding workflow.estimate cell",
    "indirect_source": "S=4D: softmax of existing npe_log_marginal_m1..m4 in ood_80d_10n; NPE inference was not rerun",
    "indirect_summary_dimension": 80,
    "indirect_summary_multiplier": 4,
    "gold_source": "softmax of existing analytical gold_log_marginal_m1..m4",
    "dataset_directory": str(pathlib.Path(INDIRECT_DATASET_DIR).resolve()),
    "input_files": [f"{source}_logml_pmp.pkl" for source in SOURCE_MODELS],
}
CSV_PATH.with_suffix(".metadata.json").write_text(
    json.dumps(metadata, ensure_ascii=False, indent=2) + "\n",
    encoding="utf-8",
)
print(f"Saved {len(comparison)} datasets with four PMPs per method: {CSV_PATH}")
comparison.head()
