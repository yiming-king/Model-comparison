# %% [markdown]
# M4: mu ~ N(0.1, I), y|mu ~ N(mu, I)
# with MMD summary space regularization
# D=20, N=100, S=2D

# %%
import numpy as np
import bayesflow as bf
import keras
from pathlib import Path

# %%
from tqdm.auto import tqdm as original_tqdm
import bayesflow.approximators.helpers.samplers as bf_samplers
import bayesflow.approximators.helpers.conditions as bf_conditions

def quiet_tqdm(*args, **kwargs):
    kwargs["disable"] = True
    return original_tqdm(*args, **kwargs)

bf_samplers.tqdm = quiet_tqdm
bf_conditions.tqdm = quiet_tqdm

# %%
RNG=np.random.default_rng(2025)
num_dims=20
num_obs=100
mu_prior_mean=0.1
mu_prior_std=1
likelihood_std=1

# %%
# simulator
def prior(mu=mu_prior_mean, sigma=mu_prior_std):
    mu = RNG.normal(loc=mu, scale=sigma, size=num_dims)
    return dict(mu=mu)
def likelihood(mu):
    x =RNG.normal(loc=mu, scale=likelihood_std, size=(num_obs, num_dims))
    return dict(x=x)
simulator=bf.make_simulator([prior,likelihood])

# %%
# adapter 
adapter = (bf.adapters.Adapter()
                        .convert_dtype("float64", "float32")
                        .rename('mu', 'inference_variables')
                        .rename('x', 'summary_variables')
                )

# %%
# networks
summary_net = bf.networks.DeepSet(
    summary_dim=2*num_dims, base_distribution="normal"
)

inference_net = bf.networks.CouplingFlow(depth=8,
                                         subnet_kwargs={"widths":(256,256,256),
                                                        "norm": "layer",},
                                                        )

# %%
workflow = bf.BasicWorkflow(simulator=simulator,
                                          adapter=adapter,
                                          summary_network=summary_net,
                                          inference_network=inference_net,
                                          standardize="all"
                                          )
epochs=100
batch_size=64
num_batches_per_epoch=128
learning_rate=keras.optimizers.schedules.CosineDecay(
            initial_learning_rate=1e-4, 
            decay_steps=epochs * num_batches_per_epoch
            )
workflow.approximator.compile(optimizer=keras.optimizers.Adam(learning_rate=learning_rate))

# %%
history = workflow.fit_online(epochs=epochs,batch_size=batch_size,num_batches_per_epoch=num_batches_per_epoch)
# Out:
# INFO:bayesflow:Fitting on dataset instance of OnlineDataset.
# INFO:bayesflow:Building on a test batch.
# Epoch 1/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 31s 131ms/step - loss: 17.5094 - loss/inference_loss: 17.2024 - loss/summary_loss: 0.3070
# Epoch 2/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 17s 130ms/step - loss: 12.6664 - loss/inference_loss: 12.3392 - loss/summary_loss: 0.3272
# Epoch 3/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 17s 132ms/step - loss: 9.0675 - loss/inference_loss: 8.7445 - loss/summary_loss: 0.3231
# Epoch 4/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 17s 136ms/step - loss: 6.4328 - loss/inference_loss: 6.0842 - loss/summary_loss: 0.3485
# Epoch 5/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 19s 149ms/step - loss: 4.0291 - loss/inference_loss: 3.6853 - loss/summary_loss: 0.3437
# Epoch 6/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 21s 161ms/step - loss: 1.7518 - loss/inference_loss: 1.3964 - loss/summary_loss: 0.3554
# Epoch 7/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 21s 164ms/step - loss: -0.1744 - loss/inference_loss: -0.5373 - loss/summary_loss: 0.3629
# Epoch 8/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 22s 168ms/step - loss: -1.5446 - loss/inference_loss: -1.9118 - loss/summary_loss: 0.3672
# Epoch 9/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 22s 175ms/step - loss: -2.5897 - loss/inference_loss: -2.9613 - loss/summary_loss: 0.3716
# Epoch 10/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 22s 168ms/step - loss: -3.3732 - loss/inference_loss: -3.7487 - loss/summary_loss: 0.3755
# Epoch 11/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 24s 191ms/step - loss: -3.0584 - loss/inference_loss: -3.4448 - loss/summary_loss: 0.3864
# Epoch 12/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 24s 186ms/step - loss: -5.5778 - loss/inference_loss: -5.9497 - loss/summary_loss: 0.3719
# Epoch 13/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 19s 148ms/step - loss: -6.3408 - loss/inference_loss: -6.7096 - loss/summary_loss: 0.3688
# Epoch 14/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 20s 157ms/step - loss: -5.6980 - loss/inference_loss: -6.0811 - loss/summary_loss: 0.3831
# Epoch 15/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 19s 152ms/step - loss: -6.7341 - loss/inference_loss: -7.1162 - loss/summary_loss: 0.3821
# Epoch 16/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 19s 147ms/step - loss: -6.0542 - loss/inference_loss: -6.4466 - loss/summary_loss: 0.3924
# Epoch 17/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 19s 149ms/step - loss: -7.1396 - loss/inference_loss: -7.5299 - loss/summary_loss: 0.3903
# Epoch 18/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 19s 149ms/step - loss: -6.7281 - loss/inference_loss: -7.1229 - loss/summary_loss: 0.3947
# Epoch 19/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 22s 174ms/step - loss: -7.5406 - loss/inference_loss: -7.9404 - loss/summary_loss: 0.3998
# Epoch 20/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 21s 160ms/step - loss: -7.5866 - loss/inference_loss: -7.9695 - loss/summary_loss: 0.3828
# Epoch 21/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 21s 162ms/step - loss: -6.8164 - loss/inference_loss: -7.2094 - loss/summary_loss: 0.3930
# Epoch 22/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 21s 165ms/step - loss: -8.3187 - loss/inference_loss: -8.7129 - loss/summary_loss: 0.3942
# Epoch 23/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 21s 167ms/step - loss: -8.2485 - loss/inference_loss: -8.6308 - loss/summary_loss: 0.3824
# Epoch 24/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 24s 190ms/step - loss: -7.5372 - loss/inference_loss: -7.9354 - loss/summary_loss: 0.3982
# Epoch 25/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 19s 151ms/step - loss: -8.4174 - loss/inference_loss: -8.8223 - loss/summary_loss: 0.4049
# Epoch 26/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 20s 158ms/step - loss: -8.7723 - loss/inference_loss: -9.1832 - loss/summary_loss: 0.4109
# Epoch 27/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 19s 149ms/step - loss: -8.8050 - loss/inference_loss: -9.2085 - loss/summary_loss: 0.4034
# Epoch 28/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 19s 144ms/step - loss: -8.7139 - loss/inference_loss: -9.1140 - loss/summary_loss: 0.4000
# Epoch 29/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 18s 144ms/step - loss: -9.5783 - loss/inference_loss: -9.9977 - loss/summary_loss: 0.4194
# Epoch 30/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 18s 144ms/step - loss: -9.3661 - loss/inference_loss: -9.7745 - loss/summary_loss: 0.4084
# Epoch 31/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 19s 148ms/step - loss: -10.0738 - loss/inference_loss: -10.5018 - loss/summary_loss: 0.4280
# Epoch 32/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 20s 155ms/step - loss: -9.5257 - loss/inference_loss: -9.9552 - loss/summary_loss: 0.4296
# Epoch 33/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 19s 148ms/step - loss: -10.0851 - loss/inference_loss: -10.5201 - loss/summary_loss: 0.4351
# Epoch 34/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 19s 151ms/step - loss: -9.7553 - loss/inference_loss: -10.1784 - loss/summary_loss: 0.4231
# Epoch 35/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 18s 143ms/step - loss: -10.3461 - loss/inference_loss: -10.7732 - loss/summary_loss: 0.4271
# Epoch 36/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 19s 151ms/step - loss: -10.3418 - loss/inference_loss: -10.7413 - loss/summary_loss: 0.3995
# Epoch 37/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 19s 147ms/step - loss: -10.1592 - loss/inference_loss: -10.5830 - loss/summary_loss: 0.4238
# Epoch 38/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 20s 155ms/step - loss: -10.2962 - loss/inference_loss: -10.7122 - loss/summary_loss: 0.4160
# Epoch 39/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 18s 140ms/step - loss: -10.6030 - loss/inference_loss: -11.0143 - loss/summary_loss: 0.4114
# Epoch 40/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 18s 139ms/step - loss: -9.7040 - loss/inference_loss: -10.1260 - loss/summary_loss: 0.4219
# Epoch 41/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 18s 144ms/step - loss: -11.0926 - loss/inference_loss: -11.5014 - loss/summary_loss: 0.4087
# Epoch 42/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 18s 142ms/step - loss: -10.6088 - loss/inference_loss: -11.0316 - loss/summary_loss: 0.4228
# Epoch 43/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 18s 143ms/step - loss: -11.3351 - loss/inference_loss: -11.7512 - loss/summary_loss: 0.4161
# Epoch 44/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 19s 146ms/step - loss: -10.9412 - loss/inference_loss: -11.3712 - loss/summary_loss: 0.4300
# Epoch 45/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 19s 148ms/step - loss: -11.5893 - loss/inference_loss: -12.0149 - loss/summary_loss: 0.4256
# Epoch 46/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 18s 143ms/step - loss: -11.5515 - loss/inference_loss: -11.9814 - loss/summary_loss: 0.4299
# Epoch 47/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 17s 135ms/step - loss: -11.1252 - loss/inference_loss: -11.5575 - loss/summary_loss: 0.4323
# Epoch 48/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 18s 139ms/step - loss: -11.8601 - loss/inference_loss: -12.2813 - loss/summary_loss: 0.4213
# Epoch 49/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 17s 135ms/step - loss: -11.8406 - loss/inference_loss: -12.2695 - loss/summary_loss: 0.4289
# Epoch 50/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 18s 137ms/step - loss: -11.3755 - loss/inference_loss: -11.8014 - loss/summary_loss: 0.4259
# Epoch 51/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 21s 164ms/step - loss: -11.0494 - loss/inference_loss: -11.4860 - loss/summary_loss: 0.4365
# Epoch 52/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 19s 145ms/step - loss: -11.6117 - loss/inference_loss: -12.0452 - loss/summary_loss: 0.4335
# Epoch 53/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 18s 140ms/step - loss: -12.2065 - loss/inference_loss: -12.6264 - loss/summary_loss: 0.4199
# Epoch 54/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 17s 136ms/step - loss: -11.1724 - loss/inference_loss: -11.5873 - loss/summary_loss: 0.4149
# Epoch 55/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 18s 141ms/step - loss: -11.3720 - loss/inference_loss: -11.7995 - loss/summary_loss: 0.4276
# Epoch 56/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 17s 133ms/step - loss: -12.1676 - loss/inference_loss: -12.5766 - loss/summary_loss: 0.4090
# Epoch 57/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 17s 135ms/step - loss: -12.2219 - loss/inference_loss: -12.6399 - loss/summary_loss: 0.4180
# Epoch 58/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 18s 139ms/step - loss: -12.0241 - loss/inference_loss: -12.4355 - loss/summary_loss: 0.4114
# Epoch 59/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 18s 143ms/step - loss: -11.7712 - loss/inference_loss: -12.1867 - loss/summary_loss: 0.4155
# Epoch 60/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 19s 148ms/step - loss: -13.0164 - loss/inference_loss: -13.4403 - loss/summary_loss: 0.4239
# Epoch 61/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 19s 146ms/step - loss: -11.6650 - loss/inference_loss: -12.0799 - loss/summary_loss: 0.4149
# Epoch 62/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 18s 143ms/step - loss: -12.6106 - loss/inference_loss: -13.0353 - loss/summary_loss: 0.4247
# Epoch 63/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 18s 143ms/step - loss: -12.5621 - loss/inference_loss: -12.9744 - loss/summary_loss: 0.4123
# Epoch 64/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 18s 140ms/step - loss: -12.6932 - loss/inference_loss: -13.0942 - loss/summary_loss: 0.4009
# Epoch 65/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 19s 151ms/step - loss: -13.5300 - loss/inference_loss: -13.9384 - loss/summary_loss: 0.4084
# Epoch 66/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 19s 151ms/step - loss: -12.7243 - loss/inference_loss: -13.1293 - loss/summary_loss: 0.4050
# Epoch 67/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 19s 150ms/step - loss: -13.1448 - loss/inference_loss: -13.5565 - loss/summary_loss: 0.4116
# Epoch 68/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 19s 149ms/step - loss: -12.6338 - loss/inference_loss: -13.0473 - loss/summary_loss: 0.4135
# Epoch 69/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 22s 172ms/step - loss: -12.3560 - loss/inference_loss: -12.7796 - loss/summary_loss: 0.4236
# Epoch 70/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 18s 141ms/step - loss: -13.4460 - loss/inference_loss: -13.8539 - loss/summary_loss: 0.4079
# Epoch 71/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 18s 143ms/step - loss: -12.6697 - loss/inference_loss: -13.0666 - loss/summary_loss: 0.3969
# Epoch 72/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 18s 140ms/step - loss: -13.3845 - loss/inference_loss: -13.7936 - loss/summary_loss: 0.4091
# Epoch 73/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 20s 153ms/step - loss: -12.9422 - loss/inference_loss: -13.3466 - loss/summary_loss: 0.4045
# Epoch 74/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 16s 122ms/step - loss: -12.7387 - loss/inference_loss: -13.1384 - loss/summary_loss: 0.3997
# Epoch 75/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 15s 117ms/step - loss: -13.2196 - loss/inference_loss: -13.6208 - loss/summary_loss: 0.4013
# Epoch 76/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 15s 116ms/step - loss: -13.9151 - loss/inference_loss: -14.2993 - loss/summary_loss: 0.3842
# Epoch 77/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 16s 122ms/step - loss: -13.3658 - loss/inference_loss: -13.7564 - loss/summary_loss: 0.3906
# Epoch 78/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 15s 114ms/step - loss: -13.8245 - loss/inference_loss: -14.2289 - loss/summary_loss: 0.4044
# Epoch 79/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 15s 115ms/step - loss: -13.6876 - loss/inference_loss: -14.0849 - loss/summary_loss: 0.3972
# Epoch 80/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 15s 116ms/step - loss: -13.8306 - loss/inference_loss: -14.2289 - loss/summary_loss: 0.3983
# Epoch 81/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 14s 113ms/step - loss: -14.1314 - loss/inference_loss: -14.5188 - loss/summary_loss: 0.3875
# Epoch 82/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 106ms/step - loss: -14.3255 - loss/inference_loss: -14.7162 - loss/summary_loss: 0.3906
# Epoch 83/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 104ms/step - loss: -13.9926 - loss/inference_loss: -14.3848 - loss/summary_loss: 0.3922
# Epoch 84/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 14s 109ms/step - loss: -14.7019 - loss/inference_loss: -15.0874 - loss/summary_loss: 0.3855
# Epoch 85/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 14s 106ms/step - loss: -14.4254 - loss/inference_loss: -14.8125 - loss/summary_loss: 0.3871
# Epoch 86/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 13s 104ms/step - loss: -13.6380 - loss/inference_loss: -14.0302 - loss/summary_loss: 0.3922
# Epoch 87/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 15s 121ms/step - loss: -14.5987 - loss/inference_loss: -14.9922 - loss/summary_loss: 0.3934
# Epoch 88/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 15s 114ms/step - loss: -14.5309 - loss/inference_loss: -14.9149 - loss/summary_loss: 0.3841
# Epoch 89/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: -14.6295 - loss/inference_loss: -15.0190 - loss/summary_loss: 0.3895
# Epoch 90/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 10s 80ms/step - loss: -14.0490 - loss/inference_loss: -14.4473 - loss/summary_loss: 0.3983
# Epoch 91/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 10s 82ms/step - loss: -14.2578 - loss/inference_loss: -14.6550 - loss/summary_loss: 0.3971
# Epoch 92/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: -14.6586 - loss/inference_loss: -15.0363 - loss/summary_loss: 0.3777
# Epoch 93/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 10s 79ms/step - loss: -14.1713 - loss/inference_loss: -14.5501 - loss/summary_loss: 0.3787
# Epoch 94/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 11s 86ms/step - loss: -14.4289 - loss/inference_loss: -14.8227 - loss/summary_loss: 0.3938
# Epoch 95/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 10s 78ms/step - loss: -14.0477 - loss/inference_loss: -14.4392 - loss/summary_loss: 0.3915
# Epoch 96/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 10s 78ms/step - loss: -14.6499 - loss/inference_loss: -15.0399 - loss/summary_loss: 0.3900
# Epoch 97/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 10s 79ms/step - loss: -14.0713 - loss/inference_loss: -14.4558 - loss/summary_loss: 0.3845
# Epoch 98/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 11s 90ms/step - loss: -14.4662 - loss/inference_loss: -14.8608 - loss/summary_loss: 0.3946
# Epoch 99/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 11s 82ms/step - loss: -13.8907 - loss/inference_loss: -14.2883 - loss/summary_loss: 0.3977
# Epoch 100/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 9s 73ms/step - loss: -14.0469 - loss/inference_loss: -14.4433 - loss/summary_loss: 0.3964
# INFO:bayesflow:Training completed in 29.30 minutes.

# %%
f=bf.diagnostics.plots.loss(history)

# %%
# Generate test datasets and get posterior samples and perform diagnostics
num_samples = 1000 #number of posterior samples
val_sims = simulator.sample(200) # validation data
post_draws = workflow.sample(conditions=val_sims, num_samples=num_samples)
post_draws.keys()
# Out:
# INFO:bayesflow:Sampling completed in 7.47 seconds.
# dict_keys(['mu'])

# %%
# f1 = bf.diagnostics.plots.calibration_histogram(post_draws, val_sims)
f2 = bf.diagnostics.plots.calibration_ecdf(post_draws, val_sims,difference=True)
f3 = bf.diagnostics.plots.recovery(post_draws, val_sims)

# %%
# Save the trained approximator
filepath = Path("/Users/yimingzang/Documents/Project/benchmark2/benchmark/examples/gaussian/networks") / "m4_s_20d_100n.keras"
filepath.parent.mkdir(exist_ok=True)
workflow.approximator.save(filepath=filepath)

# %%
# load approximator
filepath = Path("/Users/yimingzang/Documents/Project/benchmark2/benchmark/examples/gaussian/networks") / "m4_s_20d_100n.keras"
approximator = keras.saving.load_model(filepath)

# %%
post_draws = approximator.sample(conditions=val_sims, num_samples=num_samples)
f3 = bf.diagnostics.plots.recovery(post_draws, val_sims)
