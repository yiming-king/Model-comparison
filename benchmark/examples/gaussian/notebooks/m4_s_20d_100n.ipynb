# %% [markdown]
# M4: mu ~ N(0.1, I), y|mu ~ N(mu, I)
# with MMD summary space regularization
# D=20, N=100, S=D

# %%
import numpy as np
import bayesflow as bf
import keras
from pathlib import Path
# Out:
# INFO:bayesflow:Using backend 'tensorflow'

# %%
from tqdm.auto import tqdm as original_tqdm
import bayesflow.approximators.helpers.samplers as bf_samplers
import bayesflow.approximators.helpers.conditions as bf_conditions

def quiet_tqdm(*args, **kwargs):
    kwargs["disable"] = True
    return original_tqdm(*args, **kwargs)

bf_samplers.tqdm = quiet_tqdm
bf_conditions.tqdm = quiet_tqdm

# %%
RNG=np.random.default_rng(2025)
num_dims=20
num_obs=100
mu_prior_mean=0.1
mu_prior_std=1
likelihood_std=1

# %%
# simulator
def prior(mu=mu_prior_mean, sigma=mu_prior_std):
    mu = RNG.normal(loc=mu, scale=sigma, size=num_dims)
    return dict(mu=mu)
def likelihood(mu):
    x =RNG.normal(loc=mu, scale=likelihood_std, size=(num_obs, num_dims))
    return dict(x=x)
simulator=bf.make_simulator([prior,likelihood])

# %%
# adapter 
adapter = (bf.adapters.Adapter()
                        .convert_dtype("float64", "float32")
                        .rename('mu', 'inference_variables')
                        .rename('x', 'summary_variables')
                )

# %%
# networks
summary_net = bf.networks.DeepSet(
    summary_dim=num_dims, base_distribution="normal"
)

inference_net = bf.networks.CouplingFlow()

# %%
workflow = bf.BasicWorkflow(simulator=simulator,
                                          adapter=adapter,
                                          summary_network=summary_net,
                                          inference_network=inference_net,
                                          standardize="all"
                                          )
epochs=100
batch_size=64
num_batches_per_epoch=128
learning_rate=keras.optimizers.schedules.CosineDecay(
            initial_learning_rate=1e-4, 
            decay_steps=epochs * num_batches_per_epoch
            )
workflow.approximator.compile(optimizer=keras.optimizers.Adam(learning_rate=learning_rate))

# %%
history = workflow.fit_online(epochs=epochs,batch_size=batch_size,num_batches_per_epoch=num_batches_per_epoch)
# Out:
# INFO:bayesflow:Fitting on dataset instance of OnlineDataset.
# INFO:bayesflow:Building on a test batch.
# Epoch 1/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 15s 49ms/step - CouplingFlow/loss: 26.9588 - DeepSet/loss: 0.3483 - loss: 27.3071
# Epoch 2/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 62ms/step - CouplingFlow/loss: 18.8055 - DeepSet/loss: 0.4349 - loss: 19.2404
# Epoch 3/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 60ms/step - CouplingFlow/loss: 10.2379 - DeepSet/loss: 0.4833 - loss: 10.7212
# Epoch 4/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 60ms/step - CouplingFlow/loss: 5.6016 - DeepSet/loss: 0.4836 - loss: 6.0852
# Epoch 5/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 8s 60ms/step - CouplingFlow/loss: 3.0129 - DeepSet/loss: 0.4405 - loss: 3.4533
# Epoch 6/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 9s 71ms/step - CouplingFlow/loss: 1.3031 - DeepSet/loss: 0.3997 - loss: 1.7028
# Epoch 7/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 9s 71ms/step - CouplingFlow/loss: -0.0427 - DeepSet/loss: 0.3774 - loss: 0.3346
# Epoch 8/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 9s 69ms/step - CouplingFlow/loss: -1.5554 - DeepSet/loss: 0.3596 - loss: -1.1958
# Epoch 9/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 9s 72ms/step - CouplingFlow/loss: -2.3766 - DeepSet/loss: 0.3434 - loss: -2.0332
# Epoch 10/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 9s 72ms/step - CouplingFlow/loss: -2.7143 - DeepSet/loss: 0.3290 - loss: -2.3853
# Epoch 11/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 9s 73ms/step - CouplingFlow/loss: -3.1022 - DeepSet/loss: 0.3176 - loss: -2.7846
# Epoch 12/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 9s 73ms/step - CouplingFlow/loss:
# Epoch 80/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 10s 75ms/step - CouplingFlow/loss: -14.8486 - DeepSet/loss: 0.2257 - loss: -14.6229
# Epoch 81/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 10s 75ms/step - CouplingFlow/loss: -14.8835 - DeepSet/loss: 0.2250 - loss: -14.6585
# Epoch 82/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 10s 76ms/step - CouplingFlow/loss: -14.9838 - DeepSet/loss: 0.2236 - loss: -14.7601
# Epoch 83/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - CouplingFlow/loss: -14.9503 - DeepSet/loss: 0.2254 - loss: -14.7249
# Epoch 84/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 10s 75ms/step - CouplingFlow/loss: -14.9609 - DeepSet/loss: 0.2253 - loss: -14.7356
# Epoch 85/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 9s 73ms/step - CouplingFlow/loss: -15.0633 - DeepSet/loss: 0.2244 - loss: -14.8388
# Epoch 86/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 9s 74ms/step - CouplingFlow/loss: -14.9320 - DeepSet/loss: 0.2244 - loss: -14.7076
# Epoch 87/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 10s 76ms/step - CouplingFlow/loss: -15.0180 - DeepSet/loss: 0.2260 - loss: -14.7920
# Epoch 88/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 10s 78ms/step - CouplingFlow/loss: -15.0692 - DeepSet/loss: 0.2246 - loss: -14.8446
# Epoch 89/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 10s 78ms/step - CouplingFlow/loss: -15.0796 - DeepSet/loss: 0.2253 - loss: -14.8543
# Epoch 90/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 9s 73ms/step - CouplingFlow/loss: -15.0533 - DeepSet/loss: 0.2249 - loss: -14.8284
# Epoch 91/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 10s 77ms/step - CouplingFlow/loss: -15.1442 - DeepSet/loss: 0.2253 - loss: -14.9189
# Epoch 92/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 10s 78ms/step - CouplingFlow/loss: -15.1136 - DeepSet/loss: 0.2252 - loss: -14.8884
# Epoch 93/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - CouplingFlow/loss: -15.0628 - DeepSet/loss: 0.2247 - loss: -14.8381
# Epoch 94/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 9s 73ms/step - CouplingFlow/loss: -15.1722 - DeepSet/loss: 0.2252 - loss: -14.9470
# Epoch 95/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 10s 75ms/step - CouplingFlow/loss: -15.1022 - DeepSet/loss: 0.2251 - loss: -14.8772
# Epoch 96/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 10s 78ms/step - CouplingFlow/loss: -15.1794 - DeepSet/loss: 0.2246 - loss: -14.9548
# Epoch 97/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 10s 79ms/step - CouplingFlow/loss: -15.1952 - DeepSet/loss: 0.2251 - loss: -14.9701
# Epoch 98/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 10s 78ms/step - CouplingFlow/loss: -15.1190 - DeepSet/loss: 0.2246 - loss: -14.8944
# Epoch 99/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 10s 79ms/step - CouplingFlow/loss: -15.1459 - DeepSet/loss: 0.2244 - loss: -14.9214
# Epoch 100/100
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 11s 83ms/step - CouplingFlow/loss: -15.1267 - DeepSet/loss: 0.2256 - loss: -14.9011
# INFO:bayesflow:Training completed in 16.01 minutes.

# %%
f=bf.diagnostics.plots.loss(history)

# %%
# Generate test datasets and get posterior samples and perform diagnostics
num_samples = 1000 #number of posterior samples
val_sims = simulator.sample(200) # validation data
post_draws = workflow.sample(conditions=val_sims, num_samples=num_samples)
post_draws.keys()
# Out:
# INFO:bayesflow:Sampling completed in 1.10 seconds.
# dict_keys(['mu'])

# %%
# f1 = bf.diagnostics.plots.calibration_histogram(post_draws, val_sims)
f2 = bf.diagnostics.plots.calibration_ecdf(post_draws, val_sims,difference=True)
f3 = bf.diagnostics.plots.recovery(post_draws, val_sims)

# %%
# Save the trained approximator
filepath = Path("/Users/yimingzang/Documents/Project/benchmark2/benchmark/examples/gaussian/networks") / "m4_s_20d_100n.keras"
filepath.parent.mkdir(exist_ok=True)
workflow.approximator.save(filepath=filepath)

# %%
# load approximator
filepath = Path("/Users/yimingzang/Documents/Project/benchmark2/benchmark/examples/gaussian/networks") / "m4_s_20d_100n.keras"
approximator = keras.saving.load_model(filepath)

# %%
post_draws = approximator.sample(conditions=val_sims, num_samples=num_samples)
f3 = bf.diagnostics.plots.recovery(post_draws, val_sims)
