# %% [markdown]
# # Compare configurable S=kD networks with and without summary-MMD loss
#
# Set `SUMMARY_MULTIPLIER` to `1`, `2`, `4`, or `6`. Columns represent assumed models M0–M3, while the two rows compare networks trained with and without summary-MMD loss. Posterior MMD is shown on its raw scale; calibrated thresholds are handled by the separate calibration workflow.

# %%
import os
import sys
from pathlib import Path

os.environ.setdefault("KERAS_BACKEND", "tensorflow")
os.environ.setdefault("MPLCONFIGDIR", "/private/tmp/matplotlib")

PROJECT_ROOT = next(
    path for path in (Path.cwd(), *Path.cwd().parents)
    if (path / "benchmark").is_dir()
)
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from IPython.display import display

from benchmark.examples.diffusion.results.summary_dimension_comparison import (
    display_training_variant_suite,
    run_training_variant_suite,
)

# %% [markdown]
# ## Generate the comparison figures

# %%
SUMMARY_MULTIPLIER = 6

comparisons = run_training_variant_suite(
    summary_multiplier=SUMMARY_MULTIPLIER,
)
for metric, comparison in comparisons.items():
    display(comparison["manifest"])

# %% [markdown]
# ## Display the generated figures

# %%
display_training_variant_suite(comparisons)
