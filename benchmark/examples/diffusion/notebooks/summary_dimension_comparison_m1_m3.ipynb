# %% [markdown]
# # Diffusion Summary-Dimension Comparison — M1/M3 — Mahalanobis Reference
#
# All plotting and data-shaping logic is shared in `results/summary_dimension_comparison.py`.
# The same figure suite is generated separately for simulated and empirical datasets.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = next(path for path in (Path.cwd(), *Path.cwd().parents) if (path / "benchmark").is_dir())
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from benchmark.examples.diffusion.results.summary_dimension_comparison import (
    display_summary_dimension_comparison,
    run_summary_dimension_comparison,
)

MODELS = ("m1", "m3")
METRIC = "l2"
PAIR_KEY = "m1_m3"
# Out:
# INFO:jax._src.xla_bridge:Unable to initialize backend 'rocm': module 'jaxlib.xla_extension' has no attribute 'GpuAllocatorConfig'
# INFO:jax._src.xla_bridge:Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: dlopen(libtpu.so, 0x0001): tried: 'libtpu.so' (no such file), '/System/Volumes/Preboot/Cryptexes/OSlibtpu.so' (no such file), '/opt/anaconda3/envs/benchmark2/bin/../lib/libtpu.so' (no such file), '/usr/lib/libtpu.so' (no such file, not in dyld cache), 'libtpu.so' (no such file), '/usr/local/lib/libtpu.so' (no such file), '/usr/lib/libtpu.so' (no such file, not in dyld cache)
# INFO:bayesflow:Using backend 'jax'

# %%
comparison = run_summary_dimension_comparison(
    models=MODELS,
    metric=METRIC,
    pair_key=PAIR_KEY,
)

display_summary_dimension_comparison(comparison)
comparison["manifest"]
# Out:
# ## Simulated datasets
# ## Empirical datasets
#    source_group    kind                                               path
# 0     simulated  figure  /Users/yimingzang/Documents/Project/benchmark2...
# 1     simulated  figure  /Users/yimingzang/Documents/Project/benchmark2...
# 2     simulated  figure  /Users/yimingzang/Documents/Project/benchmark2...
# 3     simulated  figure  /Users/yimingzang/Documents/Project/benchmark2...
# 4     simulated  figure  /Users/yimingzang/Documents/Project/benchmark2...
# 5     simulated  figure  /Users/yimingzang/Documents/Project/benchmark2...
# 6     simulated  figure  /Users/yimingzang/Documents/Project/benchmark2...
# 7     simulated  figure  /Users/yimingzang/Documents/Project/benchmark2...
# 8     simulated  figure  /Users/yimingzang/Documents/Project/benchmark2...
# 9     simulated   table  /Users/yimingzang/Documents/Project/benchmark2...
# 10    simulated   table  /Users/yimingzang/Documents/Project/benchmark2...
# ...

# %%
print(comparison["output_root"])
# Out:
# /Users/yimingzang/Documents/Project/benchmark2/benchmark/examples/diffusion/results/model_pairs/m1_m3/plots/summary_dimension_comparison
