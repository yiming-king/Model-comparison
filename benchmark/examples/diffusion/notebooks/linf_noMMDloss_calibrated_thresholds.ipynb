# %%
import os
import sys
from pathlib import Path

os.environ.setdefault("KERAS_BACKEND", "tensorflow")
os.environ.setdefault("MPLCONFIGDIR", "/private/tmp/matplotlib")

PROJECT_ROOT = next(
    path for path in (Path.cwd(), *Path.cwd().parents) if (path / "benchmark").is_dir()
)
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from benchmark.examples.diffusion.results.summary_dimension_comparison import (
    run_diagnostic_notebook,
    display_diagnostic_notebook,
)
# Out:
# INFO:bayesflow:Using backend 'tensorflow'

# %%
# Plot controls; y scales can be changed independently for each result type.
METRIC = "linf"
VARIANT = "noMMD"  # withMMD, noMMD, or noMMD_rerun1
XSCALE = "symlog"
YSCALE = {"posterior_mmd": "linear", "logml": "symlog", "pmp": "linear"}
Y_SYMLOG_LINTHRESH = 0.1
NORMALIZE_METRICS = False  # Posterior MMD/logML only; PMP remains raw.

# Calibration uses the matching variant's 100-dataset D/2D/4D results.
POSTERIOR_MMD_QUANTILE = 0.95
SIGNED_ERROR_COVERAGE = 0.90
EXPECTED_CALIBRATION_DATASETS = 100

# LOESS controls for the combined simulated-and-empirical figures.
SHOW_LOESS = True
SHOW_EMPIRICAL_ONLY_LOESS = True
EMPIRICAL_LEGEND_ALPHA = 0.45
INCLUDE_EMPIRICAL_IN_LOESS = True
LOESS_FRAC_BY_FIT_SOURCE = {
    "simulated_only": 1.0,
    "simulated_and_empirical": 1.0,
}

# %%
# Reuse the existing error thresholds and redraw the cached diagnostics.
# Set refresh_thresholds=True below only when the error calibration itself changes.
result = run_diagnostic_notebook(
    METRIC,
    variant=VARIANT,
    xscale=XSCALE,
    yscale=YSCALE,
    normalize_metrics=NORMALIZE_METRICS,
    y_symlog_linthresh=Y_SYMLOG_LINTHRESH,
    posterior_mmd_quantile=POSTERIOR_MMD_QUANTILE,
    signed_error_coverage=SIGNED_ERROR_COVERAGE,
    expected_calibration_datasets=EXPECTED_CALIBRATION_DATASETS,
    refresh_thresholds=False,
    show_loess=SHOW_LOESS,
    show_empirical_only_loess=SHOW_EMPIRICAL_ONLY_LOESS,
    empirical_legend_alpha=EMPIRICAL_LEGEND_ALPHA,
    include_empirical_in_loess=INCLUDE_EMPIRICAL_IN_LOESS,
    loess_frac_by_fit_source=LOESS_FRAC_BY_FIT_SOURCE,
)
# Out:
# 100-dataset thresholds refreshed: /Users/yimingzang/Documents/Project/benchmark2/benchmark/examples/diffusion/calibration_outputs_100_noMMD/thresholds.csv

# %%
display_diagnostic_notebook(result)
